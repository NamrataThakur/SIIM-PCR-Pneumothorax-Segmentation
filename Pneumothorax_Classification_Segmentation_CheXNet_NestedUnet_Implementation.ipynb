# %% [markdown]
# # SIIM PCR Pneumothorax Classification and Segmentation Problem

# %% [markdown]
# ***This notebook contain the following solution :***
#
# ***Approach 1 :***
#
# ***A)*** First we classify the Chest X-Rays as either No Pneumothorax Present (Label:0) or Pneumothorax Present (Label:1). This part is the image classification part where we are applying transfer learning technique using the pre-trained model CheXNet (a 121 layer DenseNet model that is fine-tuned on Chest X-Ray images) to classify the images.
#
# ***B)*** Then, we build the segmentation part where we apply different segmentation models (Unet and Nested Unet) to predict the masks.
#
#
# ***C)*** Finally, we build the end pipeline where given an image we predict the label (0/1) and if the label is 1 we pass the image through the segmentation model to get the mask.

# %% [markdown]
# ***Mounting the Drive and installing the needed packages :***

# %%
# Mounting the Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
train_png_dest = '/content/Pneumothorax/Train Dataset/siim'
#test_png_dest = 'Train Dataset/siim/test_png_images'

if not os.path.isdir(train_png_dest):
    os.makedirs(train_png_dest)
'''if not os.path.isdir(test_png_dest):
    os.makedirs(test_png_dest)'''
# Out:
# 'if not os.path.isdir(test_png_dest):\n    os.makedirs(test_png_dest)'

# %%
# %cd /content/drive/MyDrive/Self \Case \Study \2/DATASET
# Out:
# /content/drive/MyDrive/Self Case Study 2/DATASET

# %%
# !ls
# Out:
#  Airbnb_EDA_FE.ipynb			  'test_png_images (1).zip'
#  DATASET				   test_png_images.zip
#  Final_pipeline_Pneumothorax.ipynb	   train_dicom_images.zip
#  harshjadhav100_Model_PneumoThorax.ipynb   train_mask_png_images.zip
#  test_dicom_images.zip			   train_png_images.zip

# %%
# !unzip train_png_images.zip -d /content/Pneumothorax/Train_Dataset/siim/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2301.1517875172.7308.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31902.1517875157.405933.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32761.1517875162.229147.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32307.1517875159.806079.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5228.1517875187.95605.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12753.1517875241.648215.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6107.1517875196.576812.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12799.1517875241.909479.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5677.1517875189.456187.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1819.1517875169.730327.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14536.1517875252.591963.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32682.1517875161.771426.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4196.1517875181.664956.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32068.1517875158.260753.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4851.1517875185.112037.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11251.1517875231.983178.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5662.1517875189.377067.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2530.1517875173.232098.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32767.1517875162.258059.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2850.1517875175.70142.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1395.1517875167.535037.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11410.1517875232.807205.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11713.1517875234.421582.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.452.1517875162.2142.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1667.1517875168.835418.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5536.1517875188.697339.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12980.1517875242.860674.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4913.1517875185.426119.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11961.1517875236.648500.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1988.1517875170.573020.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12466.1517875239.238077.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6468.1517875198.422051.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4517.1517875183.263954.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4065.1517875180.940515.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11437.1517875232.932286.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32006.1517875157.976665.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11213.1517875231.756707.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2130.1517875171.288778.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14396.1517875251.895730.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12688.1517875241.189406.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2282.1517875171.924888.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10544.1517875224.213810.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13399.1517875245.150266.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11751.1517875234.597378.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14352.1517875251.484657.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32756.1517875162.204444.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4659.1517875184.19019.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6766.1517875200.47126.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5474.1517875188.361438.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11260.1517875232.18469.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31943.1517875157.597608.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32566.1517875161.229116.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5233.1517875187.106905.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2834.1517875174.974983.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4275.1517875182.100527.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13846.1517875248.267206.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4620.1517875183.778580.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3014.1517875175.659762.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13629.1517875246.933174.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2807.1517875174.822497.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5813.1517875191.178523.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5790.1517875190.692754.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.309.1517875162.328197.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32665.1517875161.704387.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11064.1517875230.816470.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6706.1517875199.622555.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11348.1517875232.513857.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2551.1517875173.343485.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11008.1517875229.467452.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2779.1517875174.661823.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14123.1517875249.723199.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2090.1517875171.126753.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11645.1517875234.99311.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10266.1517875222.906294.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5917.1517875192.538017.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14198.1517875250.193891.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10110.1517875222.142071.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5425.1517875188.40071.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6857.1517875201.561042.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32108.1517875158.473836.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6501.1517875198.625338.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10910.1517875227.856845.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10287.1517875222.997107.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32593.1517875161.386457.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10074.1517875221.856200.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3477.1517875178.7766.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10363.1517875223.368553.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5457.1517875188.251538.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1374.1517875167.438882.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4144.1517875181.337594.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4568.1517875183.526303.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1926.1517875170.276641.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3469.1517875177.977952.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1466.1517875167.941720.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.666.1517875163.960792.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31993.1517875157.911549.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2088.1517875171.99802.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3057.1517875175.830484.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10534.1517875224.166224.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10810.1517875225.727416.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11907.1517875236.406200.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2722.1517875174.265677.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13551.1517875246.584534.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13646.1517875247.26591.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13214.1517875244.169305.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2715.1517875174.209467.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14028.1517875249.222200.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2073.1517875171.24615.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6964.1517875202.125199.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11408.1517875232.802439.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1166.1517875166.578202.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1393.1517875167.516965.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4962.1517875185.711627.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5821.1517875191.246350.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5175.1517875186.809979.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11580.1517875233.717684.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11219.1517875231.788729.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5686.1517875189.611807.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1019.1517875165.936673.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3454.1517875177.911414.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32134.1517875158.614035.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12178.1517875237.850151.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1752.1517875169.253566.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2460.1517875172.851039.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13212.1517875244.151789.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.333.1517875162.422915.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6379.1517875197.888352.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5123.1517875186.520735.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5877.1517875192.85942.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5553.1517875188.778825.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3030.1517875175.721335.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32623.1517875161.537934.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10475.1517875223.869933.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3515.1517875178.184100.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31691.1517875156.352314.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3164.1517875176.389727.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12328.1517875238.615185.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14366.1517875251.770073.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4224.1517875181.811289.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6036.1517875194.138959.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2706.1517875174.145188.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3624.1517875178.725347.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32267.1517875159.302372.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32116.1517875158.507259.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12846.1517875242.141253.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6686.1517875199.541895.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4079.1517875181.3810.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1745.1517875169.230352.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14431.1517875252.82936.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10968.1517875228.787245.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1686.1517875168.924189.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1383.1517875167.478352.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3763.1517875179.334004.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10335.1517875223.204485.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5703.1517875189.669594.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4688.1517875184.119380.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11076.1517875230.932012.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31782.1517875156.802710.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13034.1517875243.206323.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6585.1517875199.37328.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11421.1517875232.860080.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4115.1517875181.193258.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3738.1517875179.226404.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32572.1517875161.269398.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31701.1517875156.392542.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6127.1517875196.644318.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1549.1517875168.367445.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14377.1517875251.815822.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3060.1517875175.837425.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6613.1517875199.205018.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12819.1517875241.996304.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.523.1517875163.307359.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10260.1517875222.880220.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12945.1517875242.653722.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.7007.1517875202.322827.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10428.1517875223.681255.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11918.1517875236.464118.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31964.1517875157.738104.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3002.1517875175.620479.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6485.1517875198.529405.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11397.1517875232.774703.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10460.1517875223.812334.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13072.1517875243.412100.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32375.1517875160.279919.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12938.1517875242.614757.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31820.1517875157.38187.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10270.1517875222.923370.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6974.1517875202.181748.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1372.1517875167.438116.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10944.1517875228.378826.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10849.1517875225.943179.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2476.1517875172.955439.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14264.1517875250.479366.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2439.1517875172.754421.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1712.1517875169.64732.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5730.1517875189.841538.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4380.1517875182.577377.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1407.1517875167.596214.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11712.1517875234.423987.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6248.1517875197.287087.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3279.1517875177.61101.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6532.1517875198.780552.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13492.1517875245.551967.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4914.1517875185.432022.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5906.1517875192.410470.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4992.1517875185.874863.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5636.1517875189.261820.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10061.1517875221.812925.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5870.1517875191.961685.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3532.1517875178.263210.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11378.1517875232.686579.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4945.1517875185.597128.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12339.1517875238.662876.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32676.1517875161.751758.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12538.1517875239.635004.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32685.1517875161.799706.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4094.1517875181.100674.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4280.1517875182.93581.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11874.1517875236.126341.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6004.1517875193.802651.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5802.1517875190.919441.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11131.1517875231.325914.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3810.1517875179.573150.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2019.1517875170.727326.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6200.1517875196.988814.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32762.1517875162.235692.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1417.1517875167.659001.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4001.1517875180.587008.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.7034.1517875202.438663.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.673.1517875164.12208.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13031.1517875243.197108.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13476.1517875245.497154.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6533.1517875198.781947.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6125.1517875196.647899.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4088.1517875181.58608.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2683.1517875174.33199.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10868.1517875226.40003.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4809.1517875184.913708.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11515.1517875233.298791.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4354.1517875182.433930.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32254.1517875159.256888.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5395.1517875187.912180.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5574.1517875188.853227.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1034.1517875166.8504.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11132.1517875231.326148.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.442.1517875162.952364.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4778.1517875184.718992.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1399.1517875167.554758.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4769.1517875184.680441.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6224.1517875197.167581.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10881.1517875226.95814.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3151.1517875176.339182.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10005.1517875220.958951.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10917.1517875227.910300.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4062.1517875180.912469.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12196.1517875237.918426.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10535.1517875224.169960.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6069.1517875195.931485.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5515.1517875188.600942.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5456.1517875188.241959.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1053.1517875166.78060.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6135.1517875196.685123.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2733.1517875174.322850.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6892.1517875201.804776.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10126.1517875222.228168.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5891.1517875192.271624.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11861.1517875236.75447.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10768.1517875225.579291.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6754.1517875199.970404.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1336.1517875167.288379.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31716.1517875156.446429.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31939.1517875157.577949.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12361.1517875238.784537.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12091.1517875237.326942.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13364.1517875244.847615.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14241.1517875250.406499.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5446.1517875188.185475.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2474.1517875172.944514.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5809.1517875191.181226.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13445.1517875245.347813.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11958.1517875236.641169.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1949.1517875170.390589.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12829.1517875242.57475.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5680.1517875189.523496.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10625.1517875224.590629.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11508.1517875233.253248.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10716.1517875225.244163.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11488.1517875233.182549.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10531.1517875224.152338.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.7011.1517875202.344418.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11803.1517875234.931932.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10369.1517875223.403784.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10481.1517875223.892191.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4781.1517875184.743287.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2107.1517875171.207598.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13477.1517875245.501552.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4456.1517875182.950922.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3940.1517875180.237661.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6157.1517875196.782799.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6343.1517875197.715116.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6757.1517875199.983390.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10699.1517875225.148311.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2311.1517875172.108189.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10774.1517875225.583514.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1999.1517875170.634380.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32300.1517875159.768445.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11031.1517875230.4520.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1735.1517875169.165453.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32348.1517875160.153066.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14045.1517875249.317258.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12129.1517875237.568450.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5076.1517875186.299948.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12475.1517875239.287746.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13582.1517875246.724132.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13314.1517875244.629309.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4643.1517875183.951741.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6816.1517875201.337765.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14603.1517875252.996914.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2886.1517875175.225303.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5391.1517875187.895961.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31840.1517875157.98618.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10368.1517875223.398829.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2550.1517875173.343751.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11099.1517875231.7777.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6348.1517875197.741356.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10690.1517875225.99194.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10286.1517875222.997479.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13041.1517875243.254920.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32164.1517875158.794557.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3199.1517875176.555631.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3215.1517875176.644195.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10517.1517875224.67179.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11111.1517875231.215341.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13161.1517875243.952848.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4452.1517875182.931326.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14466.1517875252.239817.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1567.1517875168.435203.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11414.1517875232.830824.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5897.1517875192.347294.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4890.1517875185.287098.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32269.1517875159.313308.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3721.1517875179.153058.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11409.1517875232.812814.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1713.1517875169.64948.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10819.1517875225.772223.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4774.1517875184.701711.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5845.1517875191.702488.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5639.1517875189.256121.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3214.1517875176.634616.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11721.1517875234.471809.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13891.1517875248.508586.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6018.1517875194.45959.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14240.1517875250.406252.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10180.1517875222.496195.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3292.1517875177.122329.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13728.1517875247.428221.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32224.1517875159.89807.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5085.1517875186.344997.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32551.1517875161.139373.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5112.1517875186.463466.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4581.1517875183.607111.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4782.1517875184.764135.png
# ...
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2508.1517875173.87332.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4401.1517875182.657346.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10388.1517875223.479249.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11624.1517875233.973107.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11736.1517875234.529048.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2392.1517875172.508462.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6180.1517875196.895756.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2667.1517875173.957745.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14233.1517875250.356652.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6953.1517875202.105566.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31720.1517875156.469363.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1637.1517875168.681016.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5871.1517875191.986435.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4064.1517875180.919110.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4350.1517875182.418199.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31757.1517875156.645713.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3917.1517875180.112906.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2633.1517875173.805125.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1873.1517875170.3342.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10211.1517875222.639355.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10755.1517875225.483674.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3935.1517875180.205912.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5467.1517875188.321035.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12979.1517875242.846655.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3926.1517875180.155131.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4000.1517875180.584919.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32115.1517875158.498184.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1649.1517875168.754818.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4510.1517875183.215005.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2233.1517875171.743462.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32407.1517875160.446447.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10476.1517875223.875757.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12043.1517875237.79940.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5579.1517875188.878457.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14484.1517875252.318328.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10161.1517875222.410822.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13528.1517875246.468876.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31878.1517875157.283410.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4374.1517875182.563252.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2155.1517875171.400839.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14126.1517875249.742940.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11010.1517875229.498545.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11480.1517875233.143118.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12465.1517875239.237836.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3455.1517875177.916697.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4636.1517875183.890406.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5666.1517875189.384510.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6658.1517875199.424204.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4242.1517875181.862335.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6207.1517875197.39635.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2126.1517875171.269922.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31821.1517875157.36889.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11640.1517875234.57061.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2372.1517875172.409638.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10888.1517875226.128268.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14529.1517875252.558470.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1947.1517875170.376982.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6840.1517875201.471080.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4298.1517875182.165414.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13611.1517875246.854664.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10777.1517875225.586461.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13019.1517875243.119630.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13088.1517875243.537157.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12162.1517875237.788063.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13401.1517875245.151502.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4017.1517875180.678585.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13076.1517875243.444620.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1951.1517875170.395427.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1972.1517875170.492058.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2027.1517875170.775601.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31777.1517875156.793054.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11919.1517875236.467047.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5324.1517875187.613002.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13325.1517875244.657556.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12084.1517875237.281809.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31852.1517875157.144945.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31685.1517875156.329584.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11549.1517875233.561988.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1857.1517875169.948465.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32561.1517875161.229897.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3643.1517875178.799075.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12867.1517875242.262831.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12598.1517875240.34872.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.2118.1517875171.244042.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.31988.1517875157.881392.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.1219.1517875166.835208.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12143.1517875237.684007.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10210.1517875222.631015.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11541.1517875233.516884.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11360.1517875232.583238.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10251.1517875222.833349.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6873.1517875201.655705.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4192.1517875181.642220.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5226.1517875187.81111.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.5994.1517875193.658844.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10669.1517875224.969281.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3767.1517875179.331936.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.518.1517875163.282007.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14520.1517875252.506179.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.4965.1517875185.733113.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6340.1517875197.696624.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11391.1517875232.744682.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11977.1517875236.716995.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10930.1517875228.110133.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32395.1517875160.396775.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.14008.1517875249.107636.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12017.1517875236.916922.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.12095.1517875237.355858.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3297.1517875177.149805.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10623.1517875224.585561.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32060.1517875158.251634.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6904.1517875201.850819.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11444.1517875232.977506.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10016.1517875220.992175.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11405.1517875232.807474.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.3514.1517875178.176496.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.10366.1517875223.393986.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.11028.1517875229.983789.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.32219.1517875159.70802.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.13666.1517875247.117800.png

# %%
# !unzip train_mask_png_images.zip -d /content/Pneumothorax/Train_Dataset/siim/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2653.1517875173.887747_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4978.1517875185.811736_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5763.1517875190.209859_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2686.1517875174.57880_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13322.1517875244.666217_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14019.1517875249.167451_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3137.1517875176.273163_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6870.1517875201.638094_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6514.1517875198.681192_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14079.1517875249.532356_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11535.1517875233.453088_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32581.1517875161.310877_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11817.1517875235.158071_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5760.1517875190.212218_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31784.1517875156.807062_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4433.1517875182.844574_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3824.1517875179.661783_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13490.1517875245.556432_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6794.1517875201.199439_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13318.1517875244.629617_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10245.1517875222.792596_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6612.1517875199.190395_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5849.1517875191.722828_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2003.1517875170.654196_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6813.1517875201.320440_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32124.1517875158.567263_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5892.1517875192.282733_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6610.1517875199.182154_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10196.1517875222.580181_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3616.1517875178.693961_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13416.1517875245.214218_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13184.1517875244.51511_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5633.1517875189.211170_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2713.1517875174.188646_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31865.1517875157.209292_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31822.1517875157.34706_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10155.1517875222.388500_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5224.1517875187.63036_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1830.1517875169.795471_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3872.1517875179.922962_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6270.1517875197.383864_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31719.1517875156.463113_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2230.1517875171.729020_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10953.1517875228.455240_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3674.1517875178.946576_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.643.1517875163.850678_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6489.1517875198.546876_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2270.1517875171.880924_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13247.1517875244.345650_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6938.1517875202.22045_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3849.1517875179.768477_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31894.1517875157.356829_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1755.1517875169.266542_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10207.1517875222.629380_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4439.1517875182.866025_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12558.1517875239.714420_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3900.1517875180.32003_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12355.1517875238.747383_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3345.1517875177.396598_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14504.1517875252.424057_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2213.1517875171.675000_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32569.1517875161.255037_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3979.1517875180.481738_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10584.1517875224.421886_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12156.1517875237.748784_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11994.1517875236.799616_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1774.1517875169.362466_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.573.1517875163.501062_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2633.1517875173.805125_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13569.1517875246.653878_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5805.1517875190.971203_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5549.1517875188.756192_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3715.1517875179.123946_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11061.1517875230.518452_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11812.1517875235.139557_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3757.1517875179.298182_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13172.1517875243.989932_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11119.1517875231.251990_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10314.1517875223.121149_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3115.1517875176.168624_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12771.1517875241.748036_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3052.1517875175.792463_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2049.1517875170.872989_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3514.1517875178.176496_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3058.1517875175.831767_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12516.1517875239.506732_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3237.1517875176.815455_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2909.1517875175.315690_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6717.1517875199.779271_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.638.1517875163.828825_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31985.1517875157.852312_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13737.1517875247.647555_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10340.1517875223.231245_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14126.1517875249.742940_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14587.1517875252.862304_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1776.1517875169.376665_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32174.1517875158.880539_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12632.1517875240.731265_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12697.1517875241.227751_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12090.1517875237.322816_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11277.1517875232.103158_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3063.1517875175.853944_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6796.1517875201.207193_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11270.1517875232.61641_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6005.1517875193.803666_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13231.1517875244.244657_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10157.1517875222.388499_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14322.1517875251.293898_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3505.1517875178.142219_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10150.1517875222.349174_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13991.1517875249.15427_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10482.1517875223.902106_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10136.1517875222.272303_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13307.1517875244.601038_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2609.1517875173.711430_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31786.1517875156.825026_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6011.1517875193.677_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5659.1517875189.344935_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3445.1517875177.869688_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5393.1517875187.914278_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4796.1517875184.852693_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1982.1517875170.541372_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1906.1517875170.186622_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5367.1517875187.797938_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12171.1517875237.820077_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2010.1517875170.681524_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13488.1517875245.545341_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12410.1517875238.126_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3413.1517875177.732414_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4621.1517875183.773661_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3582.1517875178.554437_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14162.1517875249.928732_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11824.1517875235.295912_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4313.1517875182.236132_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10374.1517875223.421330_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12711.1517875241.270317_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14112.1517875249.686238_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6383.1517875197.906377_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3042.1517875175.771607_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10981.1517875229.52278_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13831.1517875248.167238_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10551.1517875224.237339_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6478.1517875198.493740_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13287.1517875244.515721_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3569.1517875178.464947_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32066.1517875158.253836_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.552.1517875163.403094_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4016.1517875180.661280_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1432.1517875167.741209_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12765.1517875241.698422_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13290.1517875244.527622_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.671.1517875163.997213_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12106.1517875237.411853_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1140.1517875166.465295_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12102.1517875237.394438_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1280.1517875167.98621_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13702.1517875247.287688_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1008.1517875165.893982_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14064.1517875249.454414_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5497.1517875188.507266_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4683.1517875184.107041_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2104.1517875171.201284_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5432.1517875188.91693_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11390.1517875232.747228_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4461.1517875182.971843_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13969.1517875248.904560_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13836.1517875248.203390_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12231.1517875238.106665_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1598.1517875168.538782_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4892.1517875185.287260_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12867.1517875242.262831_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.377.1517875162.629482_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1065.1517875166.126456_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32334.1517875160.114739_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2827.1517875174.927076_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5671.1517875189.420662_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32698.1517875161.880118_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3628.1517875178.729701_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10094.1517875221.969850_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3903.1517875180.51591_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11540.1517875233.498485_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.687.1517875164.69886_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2432.1517875172.703045_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11054.1517875230.504403_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3574.1517875178.507179_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2540.1517875173.274504_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12392.1517875238.932059_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1302.1517875167.175613_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1009.1517875165.901384_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4101.1517875181.137001_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14199.1517875250.218349_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2079.1517875171.48583_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13189.1517875244.63387_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10019.1517875220.2752_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2638.1517875173.830303_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2494.1517875173.39806_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13451.1517875245.370775_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4126.1517875181.236991_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3036.1517875175.747028_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2611.1517875173.712574_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12166.1517875237.793760_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13807.1517875248.38413_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10447.1517875223.762334_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13581.1517875246.719860_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11425.1517875232.878035_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4240.1517875181.865048_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14424.1517875252.51668_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5812.1517875191.165822_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5255.1517875187.194565_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14001.1517875249.67755_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12733.1517875241.532020_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12731.1517875241.528430_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10642.1517875224.699591_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12052.1517875237.127254_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12922.1517875242.556517_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13648.1517875247.45426_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1943.1517875170.352273_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1415.1517875167.650493_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2224.1517875171.711028_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4976.1517875185.816730_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4293.1517875182.150957_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4109.1517875181.155638_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1379.1517875167.457720_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12220.1517875238.33367_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11726.1517875234.501393_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12125.1517875237.502474_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11687.1517875234.313007_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32001.1517875157.950380_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2329.1517875172.201810_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.519.1517875163.296150_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6624.1517875199.270628_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10976.1517875228.970426_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32121.1517875158.535511_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4975.1517875185.809916_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10518.1517875224.70348_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2054.1517875170.924026_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12845.1517875242.143333_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3113.1517875176.161862_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13704.1517875247.297857_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32498.1517875160.877894_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5010.1517875185.946125_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12290.1517875238.398022_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5827.1517875191.350766_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.304.1517875162.301989_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13787.1517875247.920918_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.365.1517875162.574178_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11582.1517875233.727952_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31864.1517875157.206838_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1928.1517875170.284765_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1740.1517875169.196588_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2428.1517875172.652980_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11966.1517875236.674331_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.428.1517875162.885664_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2442.1517875172.767884_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5030.1517875186.48207_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13543.1517875246.544790_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11337.1517875232.467234_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.7006.1517875202.324929_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4676.1517875184.83091_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2006.1517875170.660159_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14026.1517875249.199039_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1676.1517875168.871500_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11071.1517875230.871839_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2770.1517875174.619644_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1441.1517875167.793636_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13878.1517875248.449865_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1301.1517875167.171925_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10637.1517875224.673167_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4849.1517875185.108947_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5889.1517875192.229258_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6213.1517875197.84267_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32469.1517875160.766227_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1453.1517875167.861719_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32517.1517875160.967178_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.593.1517875163.595805_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32514.1517875160.961839_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2835.1517875174.981398_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2749.1517875174.450094_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2076.1517875171.36210_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1303.1517875167.181459_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11640.1517875234.57061_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3251.1517875176.885463_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31766.1517875156.717754_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4916.1517875185.441357_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1002.1517875165.878183_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10142.1517875222.309665_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32053.1517875158.214452_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3308.1517875177.184271_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4129.1517875181.250442_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4330.1517875182.317774_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.7025.1517875202.410790_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12585.1517875239.895323_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1308.1517875167.201116_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13893.1517875248.522451_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11816.1517875235.159060_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2297.1517875171.995032_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5579.1517875188.878457_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32070.1517875158.272331_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12189.1517875237.884971_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2594.1517875173.644933_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11229.1517875231.823685_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3091.1517875176.53567_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3801.1517875179.547074_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.413.1517875162.829730_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1746.1517875169.230417_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3843.1517875179.736412_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6529.1517875198.776044_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2202.1517875171.620051_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14379.1517875251.833992_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13743.1517875247.687747_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10638.1517875224.671320_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6353.1517875197.766354_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6220.1517875197.172313_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10864.1517875226.16468_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.7024.1517875202.397477_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5464.1517875188.288367_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1860.1517875169.957015_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6068.1517875195.901526_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13081.1517875243.480848_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32740.1517875162.113811_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6848.1517875201.515650_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32232.1517875159.152931_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10874.1517875226.70346_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11389.1517875232.737833_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.382.1517875162.655491_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32641.1517875161.583657_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4172.1517875181.498459_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14446.1517875252.151854_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10675.1517875225.3610_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.499.1517875163.196230_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12148.1517875237.694692_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3466.1517875177.957769_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12853.1517875242.182185_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13134.1517875243.822077_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3970.1517875180.400485_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13667.1517875247.125535_mask.png
# ...
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32739.1517875162.92963_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13654.1517875247.63820_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5779.1517875190.520566_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6024.1517875194.37124_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10023.1517875221.9111_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14391.1517875251.878297_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3243.1517875176.845181_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4664.1517875184.31466_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4318.1517875182.269746_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14235.1517875250.364895_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11684.1517875234.296718_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6414.1517875198.57641_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13183.1517875244.36014_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5168.1517875186.763362_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10396.1517875223.523722_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6001.1517875193.804351_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32515.1517875160.961341_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11161.1517875231.466761_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13148.1517875243.884043_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10530.1517875224.151248_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6427.1517875198.121527_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4153.1517875181.395374_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5145.1517875186.632816_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3496.1517875178.91885_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14193.1517875250.171400_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31921.1517875157.503832_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2535.1517875173.254390_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12937.1517875242.613661_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2984.1517875175.554718_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4893.1517875185.298621_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6285.1517875197.447481_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5934.1517875192.944204_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1868.1517875169.993529_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4170.1517875181.492614_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11238.1517875231.905900_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1942.1517875170.355538_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10461.1517875223.818458_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11841.1517875235.970217_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4792.1517875184.825666_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32237.1517875159.179297_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2629.1517875173.783758_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6098.1517875196.532890_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4424.1517875182.788031_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31759.1517875156.671103_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4098.1517875181.106050_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5144.1517875186.626695_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3833.1517875179.704201_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.31753.1517875156.623360_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5250.1517875187.172161_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3885.1517875179.979789_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.579.1517875163.536413_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1386.1517875167.491794_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13339.1517875244.703028_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4615.1517875183.748198_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5833.1517875191.476556_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12464.1517875239.236433_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5044.1517875186.118298_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13206.1517875244.135749_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32120.1517875158.529277_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11123.1517875231.282790_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1112.1517875166.353030_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10194.1517875222.571179_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10162.1517875222.412421_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10912.1517875227.879546_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11343.1517875232.501543_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32574.1517875161.273095_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4056.1517875180.905483_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5443.1517875188.145780_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13275.1517875244.461931_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13186.1517875244.52215_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13966.1517875248.888551_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3852.1517875179.788111_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.2324.1517875172.174627_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1511.1517875168.177851_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4609.1517875183.720039_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13353.1517875244.792721_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12381.1517875238.874299_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6138.1517875196.696592_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4705.1517875184.241893_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13899.1517875248.568207_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13980.1517875248.951117_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10807.1517875225.709130_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3104.1517875176.145329_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10217.1517875222.658165_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10839.1517875225.891591_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.14383.1517875251.836882_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32531.1517875161.20885_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6384.1517875197.905964_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.437.1517875162.943042_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6859.1517875201.577556_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10503.1517875223.988998_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10405.1517875223.560524_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5189.1517875186.892329_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4784.1517875184.787324_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10759.1517875225.505048_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5612.1517875189.55165_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5774.1517875190.424185_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4655.1517875184.5256_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.12571.1517875239.805554_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.4653.1517875183.2034_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13769.1517875247.833210_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13285.1517875244.514517_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.11106.1517875231.182166_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32354.1517875160.188972_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3986.1517875180.525733_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.10442.1517875223.738807_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.3543.1517875178.326382_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.1544.1517875168.315001_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.32191.1517875158.948493_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.6140.1517875196.697884_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.13892.1517875248.512973_mask.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/train_mask_png_images/1.2.276.0.7230010.3.1.4.8323329.5329.1517875187.650847_mask.png

# %%
# !unzip test_png_images.zip -d /content/Pneumothorax/Train_Dataset/siim/
# Out:
# Archive:  test_png_images.zip
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f4f13fb70.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_462c2c75d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bd4fa896c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_30aa587f1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f1b5e5378.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3addad7e1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_01fe90211.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5dc70172e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fa9d76d07.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a41a547f0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7ad4150f5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e42b91d9a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bf424e85b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_481514c41.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_293b74bdf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_33fe19a17.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0f5f33d71.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74441d7a9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d95032c6b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ae193130d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ba7f28dac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9c263c738.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f75b0a065.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_77ab447a1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a9cc917b4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_716f1b2fd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_266fb1c4b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f1608470d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f8045f816.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bc099e59c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_abc98e29b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8285fbfb8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_caa357a32.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_50980a76e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5052f1380.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b6b6cb61b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ac49f5dc6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_603140287.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_63d21f927.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_161a365dd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ed27afbe0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74fd4f81d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b342cfb90.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4919b6257.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fcd69071e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bb2462608.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7b44b1373.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0159b1d59.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8e8f0897d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c7494c0c7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4a27ba50c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_609806ebc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_53d28c963.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3c84549c7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ed3c71fcc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a6baf4a05.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_79fb9ddfb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e1dd2c5a4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d00254218.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_607cef738.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9b1f32617.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_922a06f72.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bac88d7eb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fbd5200f2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_44e8b2bbe.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f49ebac6f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c5386398b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_66132c9be.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_48ce0567e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5c1e2c5cb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f7e69cafe.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6cb7a16ef.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9b8c18cc9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d5f71b720.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d516250bf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d5b74e985.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_54a22f0b5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_376655698.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2e6cc6327.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_40499afe0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c232524de.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bc0333d51.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fdedf0fda.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_213b7e68f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_997936489.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2d182c4cc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d0e88c4b1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5bcb64090.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1c4663da2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_645045b46.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5718ac973.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2d2014968.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_452a9f159.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_12001c3b8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bce13b50d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b4427a13c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_659507e49.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_24200de76.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5b64e3f13.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7ed740c24.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3788378f1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4dd67814f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5dab8bf3f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4a1c7c057.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_15a2ba2ad.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7fd823827.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0e44bcf40.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_95bff7cc4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d942225bc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d622e1732.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bf0650b32.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3e30da528.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_46bb707b7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d4ce7422d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e1098d41c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_81dd08780.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2d815500b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cafbf4ffb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e47b5b407.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f558b58df.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6a454a7d2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_de91f07ca.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7379ac13e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4d0747a3a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5c1ec76a0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bcf2b826b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e23b04ef4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_64254a84b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c34862e6e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2e19cd93f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_27b10663e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5f4591bd2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5ec492fb0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_154ea7826.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bcf1d5e0f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_463d5303f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_769a91d0a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3ea0896b8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4f4892229.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ce72d089c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9aefb2452.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cd49e24fb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_debcba6d1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2892d816e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c02e8f06e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fe8b405db.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fde13147b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d787fc2cb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5f73ec11e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0f90911fc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_93a1ddcc8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_10ec8ac36.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3ccc88aac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8cfd09e73.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_08d4ab891.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2b78b9db7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2e6f2c0c0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b585f718f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_42a855846.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_062b2fc91.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e155d1669.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d0bc3f440.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_02607293d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2d51924ac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f49f5003e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e181a1fb7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8aa328c2b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5053e626d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f1f019751.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d966d30d0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_947e01a8a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_37e33fec7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bf7714c72.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3deeb06af.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a8e783896.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6a5d4ba9f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_475a526d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3db850eb8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a34aa6e3d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f941f7671.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_04a007bfe.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_73f87fa1f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1a34524c8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_94a70bfd8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f67649fec.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8ec67a6fe.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_82854d73d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_218fef0ac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c94a314e5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fbe05c8ad.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e7d7249bc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e4c171acc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c34375d26.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7c8f1914a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2614cfb59.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a7e017c2a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_31301f382.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f04420ea2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ef98edafc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4701704ff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a2e1a2725.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b9c935e99.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b2377177f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4d6269d79.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bd20a4fde.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7fa7f97d6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_609bd3d55.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c12ca7fcf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ccee49d80.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4fdbc71c3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5902681f6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5f349fe0f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1c37ada9b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c4cb8bdb8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b2968ac5e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a8d8d5883.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0f9f39182.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5b6868bb6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b86e6019c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_997cb0243.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_13ac32769.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_108f720d5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_dbefe3bcd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2eee18ee9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_95510ba73.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_614532397.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fa6577b7a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_06c102168.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_810e718aa.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_151baf14c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e27a49f27.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_09bd4a6ee.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7bcf6cae3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f616537c9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6413d7e3d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9d95e40c8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_75e362858.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b54b23fb0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a7a6d16c4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_de9c79df6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_39be2b75b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4a84eea99.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2ab0f02e1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ec1aca5c7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b7c364a30.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ccd773a4e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_08c522a6a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0316f7423.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9fdfcdade.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_23b8f58c8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7f709adac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_78405548f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a9200ec06.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9c183b680.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b44ca6d6f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_827158fe6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4b28feec0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b54261c7a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2cd74640b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8345037d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0547b1b48.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4e4b8c7be.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e8e71ecc7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_35a3c7bbd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a5fd93eaa.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2905ec2c8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3520cac75.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9a405da27.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_81616622c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3b83260ac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_73ba71d77.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f6848f70f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b4480fd55.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_23e9f32c1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_56ed6fd40.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_72b92e3ed.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_86242dc04.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0384db7e7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e91882771.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_66ff09b0b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1ade52ca4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8430c1b99.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2e0ecf452.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c832ccaba.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0a50c0cc7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_65ed7cd88.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9461367b2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b05761cc2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4bb3444f7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f90b26a5f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_35a9e2842.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_eb38b9286.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c08647bca.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_98e0955ba.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e8debf94c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4b7d301cf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_860419ac2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1cc5fd66e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_18f381898.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_70983b552.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fb568afd7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e9b63c13f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_404f71ba3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_15d00344c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f1b4321ad.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7eb916342.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4c7d2d93f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_10d251799.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6d2293032.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_84178d4c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_329895150.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3c8f29852.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2b6985849.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fda4b28bd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_978a42ed8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_67e3a8d60.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7c11eb18b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74c4616b2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_44d7d4f95.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_031afe49c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_873b60ff5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6687bd6dc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_db3569c6d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_546f8c282.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5913b680d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_048fa82d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3b157e6a9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c26ea5144.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_31e6f6822.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d9f19e671.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_676c6782f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fe05f97b6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5203ed4d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1204c37ff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b920655cb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d6e77c9a8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c045fd9aa.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1afb2dbed.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_87b1f8969.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ab07ae1d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_025297e5a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_17b368d63.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_59eb0b671.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b1d52a2ad.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_055cf45a9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_76153de31.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0acfa68b1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_873251b45.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f67aed1de.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b04f57b1b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7aef3400f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_299845485.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4a70f010c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1c982f819.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4a3bf7a6f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e70c911f5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8a496a33d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5db18e931.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c6f1e3697.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f99a4e422.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0650141b9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1bc3a231f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_728643116.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_08a11a438.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d57a0efae.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8ba09bfb9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_410aab8cc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_32f7337e0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fc36bce24.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bb82f46b2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8991a8019.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5a3467c6a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a77ae9ac1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cb9e11d78.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_69956179f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0ee261579.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_04d839ffd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c0d933396.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_58e942158.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d6d359ce7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2a31832a6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3f1fcfa8c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_382d0c9a8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74a0c7910.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_af8eb43f4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f0ae2d923.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_326578859.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1b256a41b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_922854217.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9e92cd2ee.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_73a1e1767.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_da32d80c5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ed6199ec4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2889e369e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b0a946e3d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7e9956ae5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4240dfc4e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_aed40316a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ac4362f2c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_679dbae51.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a02ed5ef2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_53817868f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c90bae61c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_522de60a3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_19a145ae2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b5ce4ce4d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f5992fbad.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_33a4f80a3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d5c531918.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_83caac9b1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b7439a34c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_92342f58e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_136a37334.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2167a1256.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_07cf867d4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b7483ca5b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_287f17df8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_82218bf69.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_87148c960.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_820a93b22.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3940a2716.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7979f0f5d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fd212b378.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b14354ef4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8528020ee.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b975b9cec.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ef0c0ea4c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_20078c31b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d9d444971.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1bea07570.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b83121823.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7268da6ed.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_54f1a9009.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2dabddf44.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4d0c23642.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f482fe1b6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_af9abf371.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_922430d53.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_332e3e1c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cf152830c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5c804a4ac.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_76caced8d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_854e4c91f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_80a0d2c2b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0bbbdda07.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_796d80276.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c3a6c6e22.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_63e85c616.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fc9937a91.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d44b12219.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_47c126c9b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0a4674064.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74d466365.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_51fd8beff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e0d7193ab.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_206db31d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b86340baf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_854c6545e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_dd124b3cc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5fc3e24ab.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d7aa53932.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2789414f2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ac10bd05e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bba715807.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_53937be9a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_72951779b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_123e2f5b7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cb62dd5df.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c1b0b6c24.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_aa23f6db9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_916b07ba2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1019203d2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5a4d6ffd5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cc871e88c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f8220a993.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fa500ccb3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_16dfebefc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2ee0505fb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_871394273.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7f973d8e9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_32c9cbfea.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_232af247c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_51b713bb5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bcfdd7470.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ec622071b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4321058d1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a35bdb888.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f9dc47504.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_072ddc16f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_439ad477b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ad1033343.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fef36dee6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c75c2fb2d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_180d4ac3e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_229e2f704.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b3e181d41.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_62fc1254f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e2d010511.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_446d61478.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5d55f1cb7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_14c2b7220.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_529d0f5c9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_388886cff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_09cec6977.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fa48253f3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d29f764c1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_876fcd7a1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0c026cd43.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a1201e23e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6310b1ed2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7825d8473.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e983817c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fbd206df8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b1eb15d06.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_921b419a9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_54f9ce58a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f1deda2bb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7e773894d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2c87f564e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fb2cf31c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e1d95e489.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c18e25a0c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4b25e54e5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0fdb495f1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_91bca8f21.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7b1892cc8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_075f1e561.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_eed266e78.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d0be4282c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1a1e18998.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bad0e5893.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5a25b3947.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5a3b26fe0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e16a4b4c3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_33fdb1d7c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7f2d87c50.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9381515b9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0b2da875a.png
# ...
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4fcca8f01.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ff721017d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c243137d7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5772a0aec.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a142167c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_05af0c7a9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7e534f1f1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a54fe20f8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ee21e8977.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ddbb30ada.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9c69539f7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5632a3cbf.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d74726330.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ef5d7509a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fdfc4e448.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_01a3312da.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8b3036ab4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8218aef6b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8d66c7870.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5bc8d0e03.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_62799819a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f4e7c0515.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fd688ac04.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bd87a735d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bccc6c700.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d4c02ae56.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e148a5f62.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_71d106e5e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c089234df.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9d0810beb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_48a13efb9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_bf11f5cc4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9ca06e9b9.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f646cf921.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_69f6699cd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ec436eb1c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6eae22a23.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3abec8675.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e2bb1fa29.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_17f900cf7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e7895ee6f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_02de558c5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_afd8ca667.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8e630c26a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5cd49901c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_61112ffda.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b31966684.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3c67f9bb3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_08810a8ef.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_29f27ad9a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3b8049563.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b67d56d59.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_379f11bfd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a3a484742.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fabefbfd6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_dcf287d5e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3a1c00f7d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cc1e6a4dc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_38bead868.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1c1354525.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6a3de302a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8b62a483c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_80d5a8a25.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2f2945871.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_632caaffd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4849f1c95.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7a0b05acb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9af3ce2cb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2d637e6ce.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_65bbff157.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_598de4f8d.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8b9cced64.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8749840a0.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_61d2c1390.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9960135ea.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3742a1c91.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9a9780865.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a38723017.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0e70e5aff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_077d314a7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_07ee731bc.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3e864e059.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d232b47ec.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5e44d47c7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f6ed1dbd4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_7851a97e3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3162decfe.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b3f5a9135.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5718f09a3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_748c01d93.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9898c31b2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_285913054.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9d49f7111.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3ece7031b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4e53873be.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_452bb04a5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ca86daf2e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_441c8e536.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_042101d37.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_fe0b3567f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c684308ba.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6d3d85279.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b096455fb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_125b5a6cb.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_6befb7852.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ec372e098.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ea574bf28.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9f619d31b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2b77a5ee2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_e6c1cf23a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_087f48d7f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_624cfae81.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_31d35197c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_062f144f1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d2a2a21e2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ba3b20c00.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_46bd45e56.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3e21a5fa7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_62f72dab1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8ba814eea.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a62aa50d4.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0fd217c85.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_56d1a1376.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c9c723b64.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_42c53be82.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a0eaa5279.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_428b04d67.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_78348c46e.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_37ea11a56.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_703cd030b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3a54ce0ea.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_8c4d3587c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_63b41ef72.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_4ef0eef31.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1f76e60c6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c30e7e79c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1017e641a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2fcd95da8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_168b4a66c.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_88cbcd3a5.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0ef5f7fd7.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1f6f74795.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f0f692d23.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a2e7da171.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_a3c1d78d3.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3693ffb90.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_ce3be3911.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_0bb960c48.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9a873299b.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3ac04fff8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d926151e2.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9d84ab5e8.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_07ad91cce.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_9979c1b39.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_cdf1df19a.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_1b7cfb077.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f3a101963.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_5face2763.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f5f2bb4dd.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_f83ca5886.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_435111c89.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_994550706.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_490a04f54.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_2e2105281.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d147c8dee.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_91144dc39.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_300962430.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_3e7faf52f.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_87a258052.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_74c6d7131.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_d2ce0f2ff.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_22b5cff08.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_df5017c89.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_823ca20e1.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_183d9cac6.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_54b1c8c92.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_c68e114ba.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_b5a797789.png
#   inflating: /content/Pneumothorax/Train_Dataset/siim/test_png_images/ID_32b4fa7ee.png

# %%
# !cp "/content/drive/MyDrive/Self Case Study 2/DATASET/Train Dataset/siim/final_train_data.csv" "/content/Pneumothorax/Train_Dataset/siim/"

# %%
# Installing pydicom

# !pip install pydicom
# Out:
# Collecting pydicom
#   Downloading https://files.pythonhosted.org/packages/f4/15/df16546bc59bfca390cf072d473fb2c8acd4231636f64356593a63137e55/pydicom-2.1.2-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 12.9MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.1.2

# %%
#installing the libraries:

import pandas as pd
import numpy as np
import pydicom
from glob import glob
import glob2
from tqdm import tqdm
import shutil
import os
import pydicom
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image
import warnings
from joblib import Parallel, delayed
warnings.filterwarnings("ignore")
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
import keras
# tf.enable_eager_execution()
import os
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
# from hilbert import hilbertCurve
import imgaug.augmenters as iaa
import numpy as np
import random as rn
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau, Callback
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# import tensorflow.keras.applications.efficientnet as efn
from tensorflow.keras import Sequential
from keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications import densenet
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, AveragePooling2D

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Mar 25 10:34:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# %cd /content/Pneumothorax/
# Out:
# /content/Pneumothorax

# %% [markdown]
# ***Loading the Train CSV file :***

# %%
final_train_df = pd.read_csv('Train Dataset/siim/final_train_data.csv')
final_train_df.head(2)
# Out:
#                                              ImageId  ...                                      ImagePath_Png
# 0  1.2.276.0.7230010.3.1.4.8323329.6904.151787520...  ...  Train Dataset/siim/train_png_images/1.2.276.0....
# 1  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...  ...  Train Dataset/siim/train_png_images/1.2.276.0....
#
# [2 rows x 5 columns]

# %%
imagePath = 'Train Dataset/siim/train_png_images/'
maskPath = 'Train Dataset/siim/train_mask_png_images/'

# %% [markdown]
# ***Creating the binary labels for the classification model :***

# %%
final_train_df['Target'] = final_train_df[' EncodedPixels'].apply(lambda x : 0 if x == '-1' else 1)

# %%
final_train_df.head(2)
# Out:
#                                              ImageId  ... Target
# 0  1.2.276.0.7230010.3.1.4.8323329.6904.151787520...  ...      0
# 1  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...  ...      1
#
# [2 rows x 6 columns]

# %% [markdown]
# If no RLE value is present, i.e. if EncodedPixel column has value '-1' we are assigning it a label 0 else label 1.

# %%
#Getting all the paths of the train png images:

imagePath = final_train_df['ImagePath_Png']

# %%
imagePath
# Out:
# 0        Train Dataset/siim/train_png_images/1.2.276.0....
# 1        Train Dataset/siim/train_png_images/1.2.276.0....
# 2        Train Dataset/siim/train_png_images/1.2.276.0....
# 3        Train Dataset/siim/train_png_images/1.2.276.0....
# 4        Train Dataset/siim/train_png_images/1.2.276.0....
#                                ...
# 12042    Train Dataset/siim/train_png_images/1.2.276.0....
# 12043    Train Dataset/siim/train_png_images/1.2.276.0....
# 12044    Train Dataset/siim/train_png_images/1.2.276.0....
# 12045    Train Dataset/siim/train_png_images/1.2.276.0....
# 12046    Train Dataset/siim/train_png_images/1.2.276.0....
# Name: ImagePath_Png, Length: 12047, dtype: object

# %%
load_dir = os.getcwd()
print(load_dir)
# Out:
# /content/drive/My Drive/Self Case Study 2/DATASET

# %%
# Getting the labels :
labels = final_train_df["Target"]

# %%
labels
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 12042    0
# 12043    1
# 12044    1
# 12045    0
# 12046    0
# Name: Target, Length: 12047, dtype: int64

# %%
labels.shape
# Out:
# (12047,)

# %% [markdown]
# We have total 12,047 records in train dataset.

# %% [markdown]
# ***Loading the Test Dataset :***

# %%
test_df = pd.read_csv('/content/drive/MyDrive/Self Case Study 2/DATASET/Train Dataset/siim/test_dicom_images.csv')
test_df.head(2)
# Out:
#         ImageId                                          ImagePath
# 0  ID_c68e114ba  Train Dataset/siim/test_dicom_images/ID_c68e11...
# 1  ID_b5a797789  Train Dataset/siim/test_dicom_images/ID_b5a797...

# %% [markdown]
# ***Converting the Dicom images to PNG format to be used later :***

# %%
##https://www.kaggle.com/onealbao/dicom-to-jpeg-conversion-kernel

def dicom2png(file):
    '''
    This function inputs the path of the image to be read
    and create a .png format for the same image and store in the path created.
    '''
    ds = pydicom.read_file(str(file))
    img = ds.pixel_array
    # formatting the image to make training the network faster.
    img = cv2.resize(img, (256,256) )
    fname = file.replace('.dcm','.png')
    fname = fname.replace('_dicom','_png')
    cv2.imwrite(fname, img)

# %%
for file in tqdm(test_df['ImagePath']):
    dicom2png(file)
# Out:
# 100%|██████████| 3205/3205 [27:38<00:00,  1.93it/s]

# %%
print(os.listdir('Train Dataset/siim/test_png_images/')[10])
# Out:
# ID_6daeaec68.png

# %%
#Saving the PNG image paths in the Test Dataframe :

test_df['ImagePath_Png'] = 'Train Dataset/siim/test_png_images/'+ test_df['ImageId']+'.png'
test_df.head(2)
# Out:
#         ImageId  ...                                      ImagePath_Png
# 0  ID_c68e114ba  ...  Train Dataset/siim/test_png_images/ID_c68e114b...
# 1  ID_b5a797789  ...  Train Dataset/siim/test_png_images/ID_b5a79778...
#
# [2 rows x 3 columns]

# %%
#Getting the paths of the png images:
imagePath_test = test_df['ImagePath_Png']

# %%
imagePath_test
# Out:
# 0       Train Dataset/siim/test_png_images/ID_c68e114b...
# 1       Train Dataset/siim/test_png_images/ID_b5a79778...
# 2       Train Dataset/siim/test_png_images/ID_490a04f5...
# 3       Train Dataset/siim/test_png_images/ID_823ca20e...
# 4       Train Dataset/siim/test_png_images/ID_5face276...
#                               ...
# 3200    Train Dataset/siim/test_png_images/ID_a9cc917b...
# 3201    Train Dataset/siim/test_png_images/ID_5dc70172...
# 3202    Train Dataset/siim/test_png_images/ID_f1b5e537...
# 3203    Train Dataset/siim/test_png_images/ID_ba7f28da...
# 3204    Train Dataset/siim/test_png_images/ID_77ab447a...
# Name: ImagePath_Png, Length: 3205, dtype: object

# %% [markdown]
# ***Splitting the Train Dataset into Train and CV Dataset:***

# %%
trainPath, validPath, trainLabels, validLabels = train_test_split(imagePath, labels, test_size = 0.1, random_state = 27, stratify=labels)

# %%
print('Total Train Dataset Size : ', trainPath.shape[0])
print('Total Valid Dataset Size : ', validPath.shape[0])
# Out:
# Total Train Dataset Size :  10842
# Total Valid Dataset Size :  1205

# %% [markdown]
# We have a total of 10,842 records in the Train Portion and the remaining 1205 records are to be treated as CV or test data for checking model performance.

# %%
trainLabels
# Out:
# 5943     0
# 1455     0
# 1631     0
# 10874    0
# 727      0
#         ..
# 2574     1
# 4568     0
# 9675     0
# 10061    0
# 335      0
# Name: Target, Length: 10842, dtype: int64

# %% [markdown]
# ***Handling the Data Imbalance Problem :***

# %%
#Getting the count of the records present in train and cv dataset:
trainCount=trainLabels.value_counts()
validCount = validLabels.value_counts()

# %%
#Getting the count of individual classes:

totalTrainCount = trainLabels.shape[0]
totalPosCount = trainCount[1]
totalNegCount = trainCount[0]

print('Total Train Labels : ', totalTrainCount)
print('Total Train Positive Labels : ', totalPosCount)
print('Total Train Negative Labels : ', totalNegCount)
# Out:
# Total Train Labels :  10842
# Total Train Positive Labels :  2402
# Total Train Negative Labels :  8440

# %% [markdown]
# We have imbalance data as the count of the Positve class far outdo the count for the negative class. This is a pretty common incident in the medical domain.
#
# We need to handle this data imbalance problem so that the model doesnt become too biased for the majority class. To make sure that both the classes contribute to the loss equally, we give weights to each class. ***This weight is inversely proportional to the frequency of the class.***

# %%
#Finding the frequency of each class: Freq = count_of_class/total_records_present

posFreq = round((totalPosCount/totalTrainCount),2)
negFreq = round((totalNegCount/totalTrainCount),2)

print('Frequency Of Positive Class : ', posFreq)
print('Frequency Of Negataive Class : ', negFreq)
# Out:
# Frequency Of Positive Class :  0.22
# Frequency Of Negataive Class :  0.78

# %% [markdown]
# As expected, the frequency of the positive class is only 0.22 and the negative class has frequency of 0.78.

# %%
#Assigning the weights of each class : 

pos_weights = negFreq
neg_weights = posFreq

# %%
type(pos_weights)
# Out:
# numpy.float64

# %% [markdown]
# We need to check the contribution of each class on the loss so that the model remain unbiased to either class.
#
# We calculate this ***contribution of each class as the product of the class_weight and the class_frequency***.

# %%
#Getting the contribution of individual class :

pos_contribution = posFreq * pos_weights
neg_contribution = negFreq * neg_weights

# %%
#Plotting the count of individual class:

classes = ['Not Affected', 'Affected']
count = [totalNegCount,totalPosCount]
plt.bar(classes,count)
plt.xlabel('Target Classes')
plt.ylabel('Number of Images')
plt.title('Count of Train Classes')
plt.show()

# %% [markdown]
# Without the class weight assignment, the loss would have been more effected by the negative (majority) class.

# %%
#Plotting the contribution of each class after assigning the class weights:

classes = ['Not Affected', 'Affected']
count = [neg_contribution,pos_contribution]
plt.bar(classes,count)
plt.xlabel('Target Classes')
plt.ylabel('Count')
plt.title('Contribution of Different Train Classes on Loss Function ')
plt.show()

# %% [markdown]
# When given the weights properly, both classes effect the loss similarly.
#
# We have thus solved the data imbalance problem.

# %% [markdown]
# ***Data Augmentaion Problem:***

# %%
import random

# %%
#https://www.kaggle.com/danofer/ranzcr-chexnet-starter
#https://www.tensorflow.org/tutorials/images/data_augmentation

def build_decoder(with_labels=True, target_size=(300, 300)):
    def decode(path):
        file_bytes = tf.io.read_file(path)
        img = tf.image.decode_png(file_bytes, channels=3)
        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, target_size)

        return img
    
    def decode_with_labels(path, label):
        return decode(path), label
    
    return decode_with_labels if with_labels else decode

def build_augmenter(with_labels=True):
    def augment(img):
        number = random.randint(1,5)
        seed = (1, 5)
        if number == 1:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_contrast(img,0.2, 0.5,seed)
        if number == 2:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_brightness(img, 0.2,seed)
        if number == 3:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_saturation(img, 0.2, 0.5,seed)
        if number == 4:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_hue(img, 0.2,seed)
        if number == 5:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.adjust_gamma(img, 0.2)
        return img
    
    def augment_with_labels(img, label):
        return augment(img), label
    
    return augment_with_labels if with_labels else augment

def build_dataset(paths, labels=None, bsize=32, cache=True,
                  decode_fn=None, augment_fn=None,
                  augment=True, repeat=True, shuffle=1024,cache_dir=""):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)

    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)
    
    if augment_fn is None:
        augment_fn = build_augmenter(labels is not None)
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(augment_fn, num_parallel_calls=AUTO) if augment else dset
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    
    return dset

# %%
#Building the decoder for building the Train and Valid Dataset:

decoder = build_decoder(with_labels=True, target_size=(256, 256))
print(decoder)
# Out:
# <function build_decoder.<locals>.decode_with_labels at 0x7f4fdd515560>

# %%
#Creating the Augmented Train and Valid Datasets:

dtrain = build_dataset(
    trainPath, trainLabels, bsize=16, decode_fn=decoder,cache_dir='Kaggle/tf_cache'
)

dvalid = build_dataset(
    validPath, validLabels, bsize=16, 
    repeat=False, shuffle=False, augment=False, decode_fn=decoder,cache_dir='Kaggle/tf_cache'
)

# %%
print('Train Dataset : ',dtrain)
print('Valid Dataset : ',dvalid)
# Out:
# Train Dataset :  <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>
# Valid Dataset :  <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>

# %%
#Assigning the necessary class weights
class_weight = {0: neg_weights, 1: pos_weights}

# %% [markdown]
# ***Creating the Classification Model using Pre-Trained CheXNet model :***

# %%
##https://www.kaggle.com/danofer/ranzcr-chexnet-starter
#Creating the model:

#Defining the model:
base_model = densenet.DenseNet121(weights = None, include_top=False, input_shape=(256,256,3))

#Adding a dummy layer so that pre-trained weights can be loaded properly. This dummy layer is removed later
predictions = tf.keras.layers.Dense(14,activation='sigmoid', name='predictions')(base_model.output)

base_model2 = tf.keras.Model(inputs = base_model.input, outputs = predictions)

#Loading the pre-trained chexnet weights
base_model2.load_weights('/content/drive/MyDrive/Self Case Study 2/DATASET/brucechou1983_CheXNet_Keras_0.3.0_weights.h5')

#Removing the dummy layer
base_model2.layers.pop()

#Freezing the model
#base_model2.trainable = False

#Adding a pooling layer 
new_base_model = tf.keras.layers.GlobalAveragePooling2D()(base_model2.layers[-3].output)

new_base_model = tf.keras.layers.Dense(1024, activation='relu')(new_base_model)
new_base_model = tf.keras.layers.BatchNormalization()(new_base_model)
new_base_model = tf.keras.layers.Dropout(0.4)(new_base_model)

new_base_model = tf.keras.layers.Dense(512, activation='relu')(new_base_model)
new_base_model = tf.keras.layers.BatchNormalization()(new_base_model)
new_base_model = tf.keras.layers.Dropout(0.4)(new_base_model)

new_base_model = tf.keras.layers.Dense(64, activation='relu')(new_base_model)

#Adding the final Dense layer for prediction
new_base_model = tf.keras.layers.Dense(1, activation='sigmoid')(new_base_model)

#Model built
final_new_model = tf.keras.Model(base_model2.input, new_base_model)

# %%
##https://www.kaggle.com/danofer/ranzcr-chexnet-starter
#Creating the model:

#Defining the model:
base_model = densenet.DenseNet121(weights = None, include_top=False, input_shape=(256,256,3))

#Adding a dummy layer so that pre-trained weights can be loaded properly. This dummy layer is removed later
predictions = tf.keras.layers.Dense(14,activation='sigmoid', name='predictions')(base_model.output)

base_model2 = tf.keras.Model(inputs = base_model.input, outputs = predictions)

#Loading the pre-trained chexnet weights
base_model2.load_weights('brucechou1983_CheXNet_Keras_0.3.0_weights.h5')

#Removing the dummy layer
base_model2.layers.pop()

#Freezing the model
base_model2.trainable = False

#Adding a pooling layer 
new_base_model = tf.keras.layers.GlobalAveragePooling2D()(base_model2.layers[-3].output)

#Adding a dropout layer
#new_base_model = tf.keras.layers.Dropout(0.2)(new_base_model)

#Adding the final Dense layer for prediction
new_base_model = tf.keras.layers.Dense(1, activation='sigmoid')(new_base_model)

#Model built
final_new_model = tf.keras.Model(base_model2.input, new_base_model)

# %%
#Displaying the Last 6 layers
final_new_model.layers[-6:]
# Out:
# [<tensorflow.python.keras.layers.core.Activation at 0x7f6cfa08bed0>,
#  <tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f6cfa095290>,
#  <tensorflow.python.keras.layers.merge.Concatenate at 0x7f6cfa0f04d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f6cfa080e90>,
#  <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D at 0x7f6cfa289750>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f6cfa0d6a50>]

# %%
#Displaying the Last 6 layers
final_new_model.layers[-6:]
# Out:
# [<tensorflow.python.keras.layers.core.Dropout at 0x7f505e823650>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f505e7fb610>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f505e7ab910>,
#  <tensorflow.python.keras.layers.core.Dropout at 0x7f4fdd855590>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f505e7a7490>,
#  <tensorflow.python.keras.layers.core.Dense at 0x7f505e7f75d0>]

# %%
#Displaying the last few layer of the original pre-trained chexnet model
base_model2.layers[-5:-1]
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f452038ff50>,
#  <tensorflow.python.keras.layers.merge.Concatenate at 0x7f4520394a50>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f45203d9350>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f452032b450>]

# %%
#Displaying the last few layer of the original pre-trained chexnet model
base_model2.layers[-5:-1]
# Out:
# [<tensorflow.python.keras.layers.convolutional.Conv2D at 0x7f505e8a6710>,
#  <tensorflow.python.keras.layers.merge.Concatenate at 0x7f505e8b50d0>,
#  <tensorflow.python.keras.layers.normalization_v2.BatchNormalization at 0x7f505e89f210>,
#  <tensorflow.python.keras.layers.core.Activation at 0x7f505e848750>]

# %%
#Displaying the model:

final_new_model.summary(line_length = 150)
# Out:
# Model: "model_5"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_3 (InputLayer)                             [(None, 256, 256, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D)                 (None, 262, 262, 3)              0                 input_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/conv (Conv2D)                              (None, 128, 128, 64)             9408              zero_padding2d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/bn (BatchNormalization)                    (None, 128, 128, 64)             256               conv1/conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/relu (Activation)                          (None, 128, 128, 64)             0                 conv1/bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D)                 (None, 130, 130, 64)             0                 conv1/relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                             (None, 64, 64, 64)               0                 zero_padding2d_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormalization)           (None, 64, 64, 64)               256               pool1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_0_relu (Activation)                 (None, 64, 64, 64)               0                 conv2_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)                     (None, 64, 64, 128)              8192              conv2_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_concat (Concatenate)                (None, 64, 64, 96)               0                 pool1[0][0]
#                                                                                                     conv2_block1_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormalization)           (None, 64, 64, 96)               384               conv2_block1_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_0_relu (Activation)                 (None, 64, 64, 96)               0                 conv2_block2_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)                     (None, 64, 64, 128)              12288             conv2_block2_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block2_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block2_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block2_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_concat (Concatenate)                (None, 64, 64, 128)              0                 conv2_block1_concat[0][0]
#                                                                                                     conv2_block2_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block2_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_0_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block3_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)                     (None, 64, 64, 128)              16384             conv2_block3_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block3_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block3_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block3_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_concat (Concatenate)                (None, 64, 64, 160)              0                 conv2_block2_concat[0][0]
#                                                                                                     conv2_block3_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormalization)           (None, 64, 64, 160)              640               conv2_block3_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_0_relu (Activation)                 (None, 64, 64, 160)              0                 conv2_block4_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)                     (None, 64, 64, 128)              20480             conv2_block4_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block4_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block4_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block4_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_concat (Concatenate)                (None, 64, 64, 192)              0                 conv2_block3_concat[0][0]
#                                                                                                     conv2_block4_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormalization)           (None, 64, 64, 192)              768               conv2_block4_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_0_relu (Activation)                 (None, 64, 64, 192)              0                 conv2_block5_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)                     (None, 64, 64, 128)              24576             conv2_block5_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block5_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block5_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block5_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_concat (Concatenate)                (None, 64, 64, 224)              0                 conv2_block4_concat[0][0]
#                                                                                                     conv2_block5_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormalization)           (None, 64, 64, 224)              896               conv2_block5_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_0_relu (Activation)                 (None, 64, 64, 224)              0                 conv2_block6_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)                     (None, 64, 64, 128)              28672             conv2_block6_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block6_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block6_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block6_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_concat (Concatenate)                (None, 64, 64, 256)              0                 conv2_block5_concat[0][0]
#                                                                                                     conv2_block6_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_bn (BatchNormalization)                    (None, 64, 64, 256)              1024              conv2_block6_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_relu (Activation)                          (None, 64, 64, 256)              0                 pool2_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_conv (Conv2D)                              (None, 64, 64, 128)              32768             pool2_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)                    (None, 32, 32, 128)              0                 pool2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormalization)           (None, 32, 32, 128)              512               pool2_pool[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_0_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)                     (None, 32, 32, 128)              16384             conv3_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_concat (Concatenate)                (None, 32, 32, 160)              0                 pool2_pool[0][0]
#                                                                                                     conv3_block1_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormalization)           (None, 32, 32, 160)              640               conv3_block1_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_0_relu (Activation)                 (None, 32, 32, 160)              0                 conv3_block2_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)                     (None, 32, 32, 128)              20480             conv3_block2_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block2_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block2_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block2_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_concat (Concatenate)                (None, 32, 32, 192)              0                 conv3_block1_concat[0][0]
#                                                                                                     conv3_block2_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormalization)           (None, 32, 32, 192)              768               conv3_block2_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_0_relu (Activation)                 (None, 32, 32, 192)              0                 conv3_block3_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)                     (None, 32, 32, 128)              24576             conv3_block3_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block3_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block3_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block3_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_concat (Concatenate)                (None, 32, 32, 224)              0                 conv3_block2_concat[0][0]
#                                                                                                     conv3_block3_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormalization)           (None, 32, 32, 224)              896               conv3_block3_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_0_relu (Activation)                 (None, 32, 32, 224)              0                 conv3_block4_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)                     (None, 32, 32, 128)              28672             conv3_block4_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block4_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block4_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block4_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_concat (Concatenate)                (None, 32, 32, 256)              0                 conv3_block3_concat[0][0]
#                                                                                                     conv3_block4_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormalization)           (None, 32, 32, 256)              1024              conv3_block4_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_0_relu (Activation)                 (None, 32, 32, 256)              0                 conv3_block5_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)                     (None, 32, 32, 128)              32768             conv3_block5_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block5_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block5_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block5_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_concat (Concatenate)                (None, 32, 32, 288)              0                 conv3_block4_concat[0][0]
#                                                                                                     conv3_block5_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormalization)           (None, 32, 32, 288)              1152              conv3_block5_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_0_relu (Activation)                 (None, 32, 32, 288)              0                 conv3_block6_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)                     (None, 32, 32, 128)              36864             conv3_block6_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block6_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block6_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block6_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_concat (Concatenate)                (None, 32, 32, 320)              0                 conv3_block5_concat[0][0]
#                                                                                                     conv3_block6_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormalization)           (None, 32, 32, 320)              1280              conv3_block6_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_0_relu (Activation)                 (None, 32, 32, 320)              0                 conv3_block7_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)                     (None, 32, 32, 128)              40960             conv3_block7_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block7_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block7_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block7_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_concat (Concatenate)                (None, 32, 32, 352)              0                 conv3_block6_concat[0][0]
#                                                                                                     conv3_block7_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormalization)           (None, 32, 32, 352)              1408              conv3_block7_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_0_relu (Activation)                 (None, 32, 32, 352)              0                 conv3_block8_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)                     (None, 32, 32, 128)              45056             conv3_block8_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block8_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block8_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block8_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_concat (Concatenate)                (None, 32, 32, 384)              0                 conv3_block7_concat[0][0]
#                                                                                                     conv3_block8_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormalization)           (None, 32, 32, 384)              1536              conv3_block8_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_0_relu (Activation)                 (None, 32, 32, 384)              0                 conv3_block9_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)                     (None, 32, 32, 128)              49152             conv3_block9_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block9_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block9_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block9_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_concat (Concatenate)                (None, 32, 32, 416)              0                 conv3_block8_concat[0][0]
#                                                                                                     conv3_block9_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormalization)          (None, 32, 32, 416)              1664              conv3_block9_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_0_relu (Activation)                (None, 32, 32, 416)              0                 conv3_block10_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)                    (None, 32, 32, 128)              53248             conv3_block10_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block10_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block10_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block10_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_concat (Concatenate)               (None, 32, 32, 448)              0                 conv3_block9_concat[0][0]
#                                                                                                     conv3_block10_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormalization)          (None, 32, 32, 448)              1792              conv3_block10_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_0_relu (Activation)                (None, 32, 32, 448)              0                 conv3_block11_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)                    (None, 32, 32, 128)              57344             conv3_block11_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block11_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block11_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block11_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_concat (Concatenate)               (None, 32, 32, 480)              0                 conv3_block10_concat[0][0]
#                                                                                                     conv3_block11_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormalization)          (None, 32, 32, 480)              1920              conv3_block11_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_0_relu (Activation)                (None, 32, 32, 480)              0                 conv3_block12_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)                    (None, 32, 32, 128)              61440             conv3_block12_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block12_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block12_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block12_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_concat (Concatenate)               (None, 32, 32, 512)              0                 conv3_block11_concat[0][0]
#                                                                                                     conv3_block12_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_bn (BatchNormalization)                    (None, 32, 32, 512)              2048              conv3_block12_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_relu (Activation)                          (None, 32, 32, 512)              0                 pool3_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_conv (Conv2D)                              (None, 32, 32, 256)              131072            pool3_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)                    (None, 16, 16, 256)              0                 pool3_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormalization)           (None, 16, 16, 256)              1024              pool3_pool[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_0_relu (Activation)                 (None, 16, 16, 256)              0                 conv4_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)                     (None, 16, 16, 128)              32768             conv4_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormalization)           (None, 16, 16, 128)              512               conv4_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_relu (Activation)                 (None, 16, 16, 128)              0                 conv4_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)                     (None, 16, 16, 32)               36864             conv4_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_concat (Concatenate)                (None, 16, 16, 288)              0                 pool3_pool[0][0]
#                                                                                                     conv4_block1_2_conv[0][0]
# ...
# ______________________________________________________________________________________________________________________________________________________
# conv5_block10_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block10_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block10_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block10_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block10_concat (Concatenate)               (None, 8, 8, 832)                0                 conv5_block9_concat[0][0]
#                                                                                                     conv5_block10_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_0_bn (BatchNormalization)          (None, 8, 8, 832)                3328              conv5_block10_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_0_relu (Activation)                (None, 8, 8, 832)                0                 conv5_block11_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_1_conv (Conv2D)                    (None, 8, 8, 128)                106496            conv5_block11_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block11_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block11_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block11_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_concat (Concatenate)               (None, 8, 8, 864)                0                 conv5_block10_concat[0][0]
#                                                                                                     conv5_block11_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormalization)          (None, 8, 8, 864)                3456              conv5_block11_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_0_relu (Activation)                (None, 8, 8, 864)                0                 conv5_block12_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)                    (None, 8, 8, 128)                110592            conv5_block12_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block12_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block12_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block12_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_concat (Concatenate)               (None, 8, 8, 896)                0                 conv5_block11_concat[0][0]
#                                                                                                     conv5_block12_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormalization)          (None, 8, 8, 896)                3584              conv5_block12_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_0_relu (Activation)                (None, 8, 8, 896)                0                 conv5_block13_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)                    (None, 8, 8, 128)                114688            conv5_block13_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block13_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block13_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block13_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_concat (Concatenate)               (None, 8, 8, 928)                0                 conv5_block12_concat[0][0]
#                                                                                                     conv5_block13_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormalization)          (None, 8, 8, 928)                3712              conv5_block13_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_0_relu (Activation)                (None, 8, 8, 928)                0                 conv5_block14_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)                    (None, 8, 8, 128)                118784            conv5_block14_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block14_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block14_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block14_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_concat (Concatenate)               (None, 8, 8, 960)                0                 conv5_block13_concat[0][0]
#                                                                                                     conv5_block14_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormalization)          (None, 8, 8, 960)                3840              conv5_block14_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_0_relu (Activation)                (None, 8, 8, 960)                0                 conv5_block15_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)                    (None, 8, 8, 128)                122880            conv5_block15_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block15_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block15_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block15_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_concat (Concatenate)               (None, 8, 8, 992)                0                 conv5_block14_concat[0][0]
#                                                                                                     conv5_block15_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormalization)          (None, 8, 8, 992)                3968              conv5_block15_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_0_relu (Activation)                (None, 8, 8, 992)                0                 conv5_block16_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)                    (None, 8, 8, 128)                126976            conv5_block16_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block16_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block16_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block16_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_concat (Concatenate)               (None, 8, 8, 1024)               0                 conv5_block15_concat[0][0]
#                                                                                                     conv5_block16_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# bn (BatchNormalization)                          (None, 8, 8, 1024)               4096              conv5_block16_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d_2 (GlobalAveragePooling (None, 1024)                     0                 bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                  (None, 1)                        1025              global_average_pooling2d_2[0][0]
# ======================================================================================================================================================
# Total params: 7,038,529
# Trainable params: 1,025
# Non-trainable params: 7,037,504
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# There are a total of 1025 trainable parameters in the Dense layer. These are divided between two tf.Variable objects, the weights and biases.

# %%
len(final_new_model.trainable_variables)
# Out:
# 2

# %%
#Displaying the model:

final_new_model.summary(line_length = 150)
# Out:
# Model: "model_3"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_2 (InputLayer)                             [(None, 256, 256, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)                   (None, 262, 262, 3)              0                 input_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/conv (Conv2D)                              (None, 128, 128, 64)             9408              zero_padding2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/bn (BatchNormalization)                    (None, 128, 128, 64)             256               conv1/conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv1/relu (Activation)                          (None, 128, 128, 64)             0                 conv1/bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D)                 (None, 130, 130, 64)             0                 conv1/relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool1 (MaxPooling2D)                             (None, 64, 64, 64)               0                 zero_padding2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormalization)           (None, 64, 64, 64)               256               pool1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_0_relu (Activation)                 (None, 64, 64, 64)               0                 conv2_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)                     (None, 64, 64, 128)              8192              conv2_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block1_concat (Concatenate)                (None, 64, 64, 96)               0                 pool1[0][0]
#                                                                                                     conv2_block1_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormalization)           (None, 64, 64, 96)               384               conv2_block1_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_0_relu (Activation)                 (None, 64, 64, 96)               0                 conv2_block2_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)                     (None, 64, 64, 128)              12288             conv2_block2_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block2_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block2_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block2_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block2_concat (Concatenate)                (None, 64, 64, 128)              0                 conv2_block1_concat[0][0]
#                                                                                                     conv2_block2_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block2_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_0_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block3_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)                     (None, 64, 64, 128)              16384             conv2_block3_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block3_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block3_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block3_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block3_concat (Concatenate)                (None, 64, 64, 160)              0                 conv2_block2_concat[0][0]
#                                                                                                     conv2_block3_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormalization)           (None, 64, 64, 160)              640               conv2_block3_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_0_relu (Activation)                 (None, 64, 64, 160)              0                 conv2_block4_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)                     (None, 64, 64, 128)              20480             conv2_block4_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block4_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block4_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block4_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block4_concat (Concatenate)                (None, 64, 64, 192)              0                 conv2_block3_concat[0][0]
#                                                                                                     conv2_block4_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormalization)           (None, 64, 64, 192)              768               conv2_block4_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_0_relu (Activation)                 (None, 64, 64, 192)              0                 conv2_block5_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)                     (None, 64, 64, 128)              24576             conv2_block5_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block5_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block5_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block5_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block5_concat (Concatenate)                (None, 64, 64, 224)              0                 conv2_block4_concat[0][0]
#                                                                                                     conv2_block5_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormalization)           (None, 64, 64, 224)              896               conv2_block5_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_0_relu (Activation)                 (None, 64, 64, 224)              0                 conv2_block6_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)                     (None, 64, 64, 128)              28672             conv2_block6_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormalization)           (None, 64, 64, 128)              512               conv2_block6_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_1_relu (Activation)                 (None, 64, 64, 128)              0                 conv2_block6_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)                     (None, 64, 64, 32)               36864             conv2_block6_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2_block6_concat (Concatenate)                (None, 64, 64, 256)              0                 conv2_block5_concat[0][0]
#                                                                                                     conv2_block6_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_bn (BatchNormalization)                    (None, 64, 64, 256)              1024              conv2_block6_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_relu (Activation)                          (None, 64, 64, 256)              0                 pool2_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_conv (Conv2D)                              (None, 64, 64, 128)              32768             pool2_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)                    (None, 32, 32, 128)              0                 pool2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormalization)           (None, 32, 32, 128)              512               pool2_pool[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_0_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)                     (None, 32, 32, 128)              16384             conv3_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block1_concat (Concatenate)                (None, 32, 32, 160)              0                 pool2_pool[0][0]
#                                                                                                     conv3_block1_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormalization)           (None, 32, 32, 160)              640               conv3_block1_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_0_relu (Activation)                 (None, 32, 32, 160)              0                 conv3_block2_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)                     (None, 32, 32, 128)              20480             conv3_block2_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block2_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block2_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block2_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block2_concat (Concatenate)                (None, 32, 32, 192)              0                 conv3_block1_concat[0][0]
#                                                                                                     conv3_block2_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormalization)           (None, 32, 32, 192)              768               conv3_block2_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_0_relu (Activation)                 (None, 32, 32, 192)              0                 conv3_block3_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)                     (None, 32, 32, 128)              24576             conv3_block3_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block3_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block3_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block3_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block3_concat (Concatenate)                (None, 32, 32, 224)              0                 conv3_block2_concat[0][0]
#                                                                                                     conv3_block3_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormalization)           (None, 32, 32, 224)              896               conv3_block3_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_0_relu (Activation)                 (None, 32, 32, 224)              0                 conv3_block4_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)                     (None, 32, 32, 128)              28672             conv3_block4_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block4_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block4_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block4_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block4_concat (Concatenate)                (None, 32, 32, 256)              0                 conv3_block3_concat[0][0]
#                                                                                                     conv3_block4_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormalization)           (None, 32, 32, 256)              1024              conv3_block4_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_0_relu (Activation)                 (None, 32, 32, 256)              0                 conv3_block5_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)                     (None, 32, 32, 128)              32768             conv3_block5_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block5_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block5_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block5_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block5_concat (Concatenate)                (None, 32, 32, 288)              0                 conv3_block4_concat[0][0]
#                                                                                                     conv3_block5_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormalization)           (None, 32, 32, 288)              1152              conv3_block5_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_0_relu (Activation)                 (None, 32, 32, 288)              0                 conv3_block6_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)                     (None, 32, 32, 128)              36864             conv3_block6_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block6_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block6_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block6_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block6_concat (Concatenate)                (None, 32, 32, 320)              0                 conv3_block5_concat[0][0]
#                                                                                                     conv3_block6_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormalization)           (None, 32, 32, 320)              1280              conv3_block6_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_0_relu (Activation)                 (None, 32, 32, 320)              0                 conv3_block7_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)                     (None, 32, 32, 128)              40960             conv3_block7_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block7_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block7_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block7_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block7_concat (Concatenate)                (None, 32, 32, 352)              0                 conv3_block6_concat[0][0]
#                                                                                                     conv3_block7_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormalization)           (None, 32, 32, 352)              1408              conv3_block7_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_0_relu (Activation)                 (None, 32, 32, 352)              0                 conv3_block8_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)                     (None, 32, 32, 128)              45056             conv3_block8_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block8_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block8_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block8_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block8_concat (Concatenate)                (None, 32, 32, 384)              0                 conv3_block7_concat[0][0]
#                                                                                                     conv3_block8_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormalization)           (None, 32, 32, 384)              1536              conv3_block8_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_0_relu (Activation)                 (None, 32, 32, 384)              0                 conv3_block9_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)                     (None, 32, 32, 128)              49152             conv3_block9_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormalization)           (None, 32, 32, 128)              512               conv3_block9_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_1_relu (Activation)                 (None, 32, 32, 128)              0                 conv3_block9_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)                     (None, 32, 32, 32)               36864             conv3_block9_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block9_concat (Concatenate)                (None, 32, 32, 416)              0                 conv3_block8_concat[0][0]
#                                                                                                     conv3_block9_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormalization)          (None, 32, 32, 416)              1664              conv3_block9_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_0_relu (Activation)                (None, 32, 32, 416)              0                 conv3_block10_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)                    (None, 32, 32, 128)              53248             conv3_block10_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block10_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block10_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block10_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block10_concat (Concatenate)               (None, 32, 32, 448)              0                 conv3_block9_concat[0][0]
#                                                                                                     conv3_block10_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormalization)          (None, 32, 32, 448)              1792              conv3_block10_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_0_relu (Activation)                (None, 32, 32, 448)              0                 conv3_block11_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)                    (None, 32, 32, 128)              57344             conv3_block11_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block11_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block11_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block11_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block11_concat (Concatenate)               (None, 32, 32, 480)              0                 conv3_block10_concat[0][0]
#                                                                                                     conv3_block11_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormalization)          (None, 32, 32, 480)              1920              conv3_block11_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_0_relu (Activation)                (None, 32, 32, 480)              0                 conv3_block12_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)                    (None, 32, 32, 128)              61440             conv3_block12_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormalization)          (None, 32, 32, 128)              512               conv3_block12_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_1_relu (Activation)                (None, 32, 32, 128)              0                 conv3_block12_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)                    (None, 32, 32, 32)               36864             conv3_block12_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv3_block12_concat (Concatenate)               (None, 32, 32, 512)              0                 conv3_block11_concat[0][0]
#                                                                                                     conv3_block12_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_bn (BatchNormalization)                    (None, 32, 32, 512)              2048              conv3_block12_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_relu (Activation)                          (None, 32, 32, 512)              0                 pool3_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_conv (Conv2D)                              (None, 32, 32, 256)              131072            pool3_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)                    (None, 16, 16, 256)              0                 pool3_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormalization)           (None, 16, 16, 256)              1024              pool3_pool[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_0_relu (Activation)                 (None, 16, 16, 256)              0                 conv4_block1_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)                     (None, 16, 16, 128)              32768             conv4_block1_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormalization)           (None, 16, 16, 128)              512               conv4_block1_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_1_relu (Activation)                 (None, 16, 16, 128)              0                 conv4_block1_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)                     (None, 16, 16, 32)               36864             conv4_block1_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv4_block1_concat (Concatenate)                (None, 16, 16, 288)              0                 pool3_pool[0][0]
#                                                                                                     conv4_block1_2_conv[0][0]
# ...
# conv5_block11_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block11_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block11_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block11_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block11_concat (Concatenate)               (None, 8, 8, 864)                0                 conv5_block10_concat[0][0]
#                                                                                                     conv5_block11_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_0_bn (BatchNormalization)          (None, 8, 8, 864)                3456              conv5_block11_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_0_relu (Activation)                (None, 8, 8, 864)                0                 conv5_block12_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_conv (Conv2D)                    (None, 8, 8, 128)                110592            conv5_block12_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block12_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block12_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block12_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block12_concat (Concatenate)               (None, 8, 8, 896)                0                 conv5_block11_concat[0][0]
#                                                                                                     conv5_block12_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_0_bn (BatchNormalization)          (None, 8, 8, 896)                3584              conv5_block12_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_0_relu (Activation)                (None, 8, 8, 896)                0                 conv5_block13_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_conv (Conv2D)                    (None, 8, 8, 128)                114688            conv5_block13_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block13_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block13_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block13_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block13_concat (Concatenate)               (None, 8, 8, 928)                0                 conv5_block12_concat[0][0]
#                                                                                                     conv5_block13_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_0_bn (BatchNormalization)          (None, 8, 8, 928)                3712              conv5_block13_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_0_relu (Activation)                (None, 8, 8, 928)                0                 conv5_block14_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_conv (Conv2D)                    (None, 8, 8, 128)                118784            conv5_block14_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block14_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block14_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block14_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block14_concat (Concatenate)               (None, 8, 8, 960)                0                 conv5_block13_concat[0][0]
#                                                                                                     conv5_block14_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_0_bn (BatchNormalization)          (None, 8, 8, 960)                3840              conv5_block14_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_0_relu (Activation)                (None, 8, 8, 960)                0                 conv5_block15_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_conv (Conv2D)                    (None, 8, 8, 128)                122880            conv5_block15_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block15_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block15_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block15_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block15_concat (Concatenate)               (None, 8, 8, 992)                0                 conv5_block14_concat[0][0]
#                                                                                                     conv5_block15_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_0_bn (BatchNormalization)          (None, 8, 8, 992)                3968              conv5_block15_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_0_relu (Activation)                (None, 8, 8, 992)                0                 conv5_block16_0_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_conv (Conv2D)                    (None, 8, 8, 128)                126976            conv5_block16_0_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_bn (BatchNormalization)          (None, 8, 8, 128)                512               conv5_block16_1_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_1_relu (Activation)                (None, 8, 8, 128)                0                 conv5_block16_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_2_conv (Conv2D)                    (None, 8, 8, 32)                 36864             conv5_block16_1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv5_block16_concat (Concatenate)               (None, 8, 8, 1024)               0                 conv5_block15_concat[0][0]
#                                                                                                     conv5_block16_2_conv[0][0]
# ______________________________________________________________________________________________________________________________________________________
# bn (BatchNormalization)                          (None, 8, 8, 1024)               4096              conv5_block16_concat[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d (GlobalAveragePooling2D (None, 1024)                     0                 bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense (Dense)                                    (None, 1024)                     1049600           global_average_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)         (None, 1024)                     4096              dense[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dropout (Dropout)                                (None, 1024)                     0                 batch_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense_1 (Dense)                                  (None, 512)                      524800            dropout[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)       (None, 512)                      2048              dense_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dropout_1 (Dropout)                              (None, 512)                      0                 batch_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense_2 (Dense)                                  (None, 64)                       32832             dropout_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense_3 (Dense)                                  (None, 1)                        65                dense_2[0][0]
# ======================================================================================================================================================
# Total params: 8,650,945
# Trainable params: 8,564,225
# Non-trainable params: 86,720
# ______________________________________________________________________________________________________________________________________________________

# %%
final_new_model.inputs, final_new_model.outputs
# Out:
# ([<KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_2')>],
#  [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_3')>])

# %% [markdown]
# Checking the input and output of the model created:

# %%
final_new_model.inputs, final_new_model.outputs
# Out:
# ([<KerasTensor: shape=(None, 256, 256, 3) dtype=float32 (created by layer 'input_4')>],
#  [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'dense_3')>])

# %%
#Count of the total records in train:
trainPath.shape[0]
# Out:
# 10842

# %% [markdown]
# ***Creating the Callbacks :***

# %%
'/content/drive/MyDrive/Self Case Study 2/DATASET/

# %%
BATCH_SIZE = 16
#total number of datapooints that should be passed through the network in individual epochs. This is used when we are generating data through augmentations
weighted_steps_per_epoch = trainPath.shape[0] // BATCH_SIZE

#Callback for saving the weights 
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'chexnet_model_new.h5', save_best_only=True, monitor='val_auc', mode='max',restore_best_weights=True)

#Callback for the ReduceLROnPlateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_auc", patience=3, min_lr=1e-6, mode='max')

#Callback to stop training if the metric value doesnt change for 6 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_auc', min_delta=0.0001, patience=6, mode='max',restore_best_weights=True)

# %% [markdown]
# ***Defining the Metrics:***

# %%
METRICS = [
      tf.keras.metrics.TruePositives(name='tp'),
      tf.keras.metrics.FalsePositives(name='fp'),
      tf.keras.metrics.TrueNegatives(name='tn'),
      tf.keras.metrics.FalseNegatives(name='fn'), 
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),
      tf.keras.metrics.AUC(name='auc'),
]

#Adam optimizer
optim = tf.keras.optimizers.Adam(0.0001)

# %%
  #Compile the model:
  final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
#Compile the model:
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
dtrain,dvalid
# Out:
# (<PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>,
#  <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>)

# %%
dtrain,dvalid
# Out:
# (<PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>,
#  <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int64)>)

# %% [markdown]
# ***Training the model :***

# %% [markdown]
# Training the model for shorter duration at a time because the colab is getting disconnected very randomly and very quickly.
#
# Also, most of the time we didnt get GPU and had to be trained on CPU so time taken for each epoch is very long (approx 35 mins/epoch).

# %%
history = final_new_model.fit(
    dtrain, 
    epochs=50, # training for smaller epochs at a time because kernel is getting disconnected very easily.
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    
    #Giving the class weights here:
    class_weight=class_weight)
# Out:
# Epoch 1/50
# 677/677 [==============================] - 132s 173ms/step - loss: 0.1886 - tp: 976.7581 - fp: 1104.4425 - tn: 3132.9912 - fn: 217.7847 - accuracy: 0.7278 - precision: 0.4422 - recall: 0.8028 - auc: 0.8323 - val_loss: 0.3224 - val_tp: 233.0000 - val_fp: 138.0000 - val_tn: 805.0000 - val_fn: 40.0000 - val_accuracy: 0.8536 - val_precision: 0.6280 - val_recall: 0.8535 - val_auc: 0.9242
# Epoch 2/50
# 677/677 [==============================] - 117s 173ms/step - loss: 0.1400 - tp: 1025.1903 - fp: 855.5973 - tn: 3381.0413 - fn: 170.1475 - accuracy: 0.8099 - precision: 0.5412 - recall: 0.8560 - auc: 0.8989 - val_loss: 0.3458 - val_tp: 247.0000 - val_fp: 162.0000 - val_tn: 781.0000 - val_fn: 26.0000 - val_accuracy: 0.8454 - val_precision: 0.6039 - val_recall: 0.9048 - val_auc: 0.9351
# Epoch 3/50
# 677/677 [==============================] - 117s 173ms/step - loss: 0.1243 - tp: 1047.4823 - fp: 782.6991 - tn: 3455.5841 - fn: 146.2109 - accuracy: 0.8283 - precision: 0.5724 - recall: 0.8804 - auc: 0.9165 - val_loss: 0.2982 - val_tp: 237.0000 - val_fp: 135.0000 - val_tn: 808.0000 - val_fn: 36.0000 - val_accuracy: 0.8594 - val_precision: 0.6371 - val_recall: 0.8681 - val_auc: 0.9406
# Epoch 4/50
# 677/677 [==============================] - 114s 168ms/step - loss: 0.1187 - tp: 1052.4631 - fp: 746.0147 - tn: 3500.3319 - fn: 133.1667 - accuracy: 0.8339 - precision: 0.5752 - recall: 0.8855 - auc: 0.9230 - val_loss: 0.2835 - val_tp: 249.0000 - val_fp: 132.0000 - val_tn: 811.0000 - val_fn: 24.0000 - val_accuracy: 0.8717 - val_precision: 0.6535 - val_recall: 0.9121 - val_auc: 0.9504
# Epoch 5/50
# 677/677 [==============================] - 108s 160ms/step - loss: 0.1099 - tp: 1071.6873 - fp: 720.2596 - tn: 3528.4853 - fn: 111.5442 - accuracy: 0.8459 - precision: 0.5947 - recall: 0.9071 - auc: 0.9343 - val_loss: 0.2239 - val_tp: 229.0000 - val_fp: 83.0000 - val_tn: 860.0000 - val_fn: 44.0000 - val_accuracy: 0.8956 - val_precision: 0.7340 - val_recall: 0.8388 - val_auc: 0.9556
# Epoch 6/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.1019 - tp: 1096.9558 - fp: 673.8938 - tn: 3567.7080 - fn: 93.4189 - accuracy: 0.8541 - precision: 0.6120 - recall: 0.9204 - auc: 0.9403 - val_loss: 0.2460 - val_tp: 265.0000 - val_fp: 129.0000 - val_tn: 814.0000 - val_fn: 8.0000 - val_accuracy: 0.8873 - val_precision: 0.6726 - val_recall: 0.9707 - val_auc: 0.9643
# Epoch 7/50
# 677/677 [==============================] - 105s 154ms/step - loss: 0.0915 - tp: 1102.6770 - fp: 607.5147 - tn: 3639.2389 - fn: 82.5457 - accuracy: 0.8698 - precision: 0.6373 - recall: 0.9338 - auc: 0.9481 - val_loss: 0.1878 - val_tp: 262.0000 - val_fp: 85.0000 - val_tn: 858.0000 - val_fn: 11.0000 - val_accuracy: 0.9211 - val_precision: 0.7550 - val_recall: 0.9597 - val_auc: 0.9729
# Epoch 8/50
# 677/677 [==============================] - 105s 154ms/step - loss: 0.0823 - tp: 1131.5103 - fp: 540.1770 - tn: 3692.3319 - fn: 67.9572 - accuracy: 0.8875 - precision: 0.6742 - recall: 0.9459 - auc: 0.9591 - val_loss: 0.1941 - val_tp: 265.0000 - val_fp: 89.0000 - val_tn: 854.0000 - val_fn: 8.0000 - val_accuracy: 0.9202 - val_precision: 0.7486 - val_recall: 0.9707 - val_auc: 0.9746
# Epoch 9/50
# 677/677 [==============================] - 104s 153ms/step - loss: 0.0744 - tp: 1128.9277 - fp: 492.1136 - tn: 3755.1136 - fn: 55.8215 - accuracy: 0.8960 - precision: 0.6888 - recall: 0.9544 - auc: 0.9653 - val_loss: 0.1577 - val_tp: 269.0000 - val_fp: 72.0000 - val_tn: 871.0000 - val_fn: 4.0000 - val_accuracy: 0.9375 - val_precision: 0.7889 - val_recall: 0.9853 - val_auc: 0.9808
# Epoch 10/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0636 - tp: 1136.5147 - fp: 414.4705 - tn: 3835.0324 - fn: 45.9587 - accuracy: 0.9144 - precision: 0.7276 - recall: 0.9634 - auc: 0.9737 - val_loss: 0.1255 - val_tp: 259.0000 - val_fp: 45.0000 - val_tn: 898.0000 - val_fn: 14.0000 - val_accuracy: 0.9515 - val_precision: 0.8520 - val_recall: 0.9487 - val_auc: 0.9839
# Epoch 11/50
# 677/677 [==============================] - 102s 151ms/step - loss: 0.0595 - tp: 1162.8009 - fp: 371.7788 - tn: 3855.6445 - fn: 41.7522 - accuracy: 0.9217 - precision: 0.7532 - recall: 0.9648 - auc: 0.9783 - val_loss: 0.1095 - val_tp: 259.0000 - val_fp: 37.0000 - val_tn: 906.0000 - val_fn: 14.0000 - val_accuracy: 0.9581 - val_precision: 0.8750 - val_recall: 0.9487 - val_auc: 0.9870
# Epoch 12/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0499 - tp: 1162.1947 - fp: 292.5413 - tn: 3939.1637 - fn: 38.0767 - accuracy: 0.9387 - precision: 0.8013 - recall: 0.9641 - auc: 0.9833 - val_loss: 0.1119 - val_tp: 262.0000 - val_fp: 44.0000 - val_tn: 899.0000 - val_fn: 11.0000 - val_accuracy: 0.9548 - val_precision: 0.8562 - val_recall: 0.9597 - val_auc: 0.9883
# Epoch 13/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0451 - tp: 1158.5546 - fp: 263.3791 - tn: 3977.0885 - fn: 32.9543 - accuracy: 0.9420 - precision: 0.8023 - recall: 0.9708 - auc: 0.9862 - val_loss: 0.1323 - val_tp: 273.0000 - val_fp: 64.0000 - val_tn: 879.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9474 - val_precision: 0.8101 - val_recall: 1.0000 - val_auc: 0.9915
# Epoch 14/50
# 677/677 [==============================] - 103s 153ms/step - loss: 0.0383 - tp: 1171.2861 - fp: 224.6873 - tn: 4006.7714 - fn: 29.2316 - accuracy: 0.9542 - precision: 0.8411 - recall: 0.9755 - auc: 0.9897 - val_loss: 0.1493 - val_tp: 271.0000 - val_fp: 71.0000 - val_tn: 872.0000 - val_fn: 2.0000 - val_accuracy: 0.9400 - val_precision: 0.7924 - val_recall: 0.9927 - val_auc: 0.9883
# Epoch 15/50
# 677/677 [==============================] - 105s 156ms/step - loss: 0.0341 - tp: 1161.1962 - fp: 185.0103 - tn: 4064.8112 - fn: 20.9587 - accuracy: 0.9589 - precision: 0.8504 - recall: 0.9809 - auc: 0.9901 - val_loss: 0.0915 - val_tp: 272.0000 - val_fp: 34.0000 - val_tn: 909.0000 - val_fn: 1.0000 - val_accuracy: 0.9712 - val_precision: 0.8889 - val_recall: 0.9963 - val_auc: 0.9943
# Epoch 16/50
# 677/677 [==============================] - 103s 153ms/step - loss: 0.0266 - tp: 1201.9912 - fp: 153.0324 - tn: 4059.0383 - fn: 17.9145 - accuracy: 0.9697 - precision: 0.8901 - recall: 0.9868 - auc: 0.9941 - val_loss: 0.0750 - val_tp: 270.0000 - val_fp: 27.0000 - val_tn: 916.0000 - val_fn: 3.0000 - val_accuracy: 0.9753 - val_precision: 0.9091 - val_recall: 0.9890 - val_auc: 0.9949
# Epoch 17/50
# 677/677 [==============================] - 104s 153ms/step - loss: 0.0264 - tp: 1165.6711 - fp: 134.7920 - tn: 4109.0914 - fn: 22.4218 - accuracy: 0.9687 - precision: 0.8878 - recall: 0.9795 - auc: 0.9947 - val_loss: 0.0603 - val_tp: 272.0000 - val_fp: 19.0000 - val_tn: 924.0000 - val_fn: 1.0000 - val_accuracy: 0.9836 - val_precision: 0.9347 - val_recall: 0.9963 - val_auc: 0.9962
# Epoch 18/50
# 677/677 [==============================] - 104s 153ms/step - loss: 0.0232 - tp: 1165.5162 - fp: 125.7168 - tn: 4121.6622 - fn: 19.0811 - accuracy: 0.9725 - precision: 0.8983 - recall: 0.9848 - auc: 0.9954 - val_loss: 0.0585 - val_tp: 273.0000 - val_fp: 19.0000 - val_tn: 924.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9844 - val_precision: 0.9349 - val_recall: 1.0000 - val_auc: 0.9963
# Epoch 19/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0200 - tp: 1163.3909 - fp: 103.8024 - tn: 4149.4086 - fn: 15.3746 - accuracy: 0.9782 - precision: 0.9172 - recall: 0.9871 - auc: 0.9960 - val_loss: 0.1036 - val_tp: 273.0000 - val_fp: 36.0000 - val_tn: 907.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9704 - val_precision: 0.8835 - val_recall: 1.0000 - val_auc: 0.9956
# Epoch 20/50
# 677/677 [==============================] - 107s 158ms/step - loss: 0.0184 - tp: 1189.0354 - fp: 94.2625 - tn: 4134.8776 - fn: 13.8009 - accuracy: 0.9790 - precision: 0.9233 - recall: 0.9881 - auc: 0.9971 - val_loss: 0.0348 - val_tp: 273.0000 - val_fp: 12.0000 - val_tn: 931.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9901 - val_precision: 0.9579 - val_recall: 1.0000 - val_auc: 0.9992
# Epoch 21/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0162 - tp: 1196.3673 - fp: 82.2655 - tn: 4140.9440 - fn: 12.3997 - accuracy: 0.9819 - precision: 0.9341 - recall: 0.9896 - auc: 0.9977 - val_loss: 0.0493 - val_tp: 273.0000 - val_fp: 19.0000 - val_tn: 924.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9844 - val_precision: 0.9349 - val_recall: 1.0000 - val_auc: 0.9982
# Epoch 22/50
# 677/677 [==============================] - 105s 155ms/step - loss: 0.0133 - tp: 1183.4395 - fp: 72.0029 - tn: 4166.3392 - fn: 10.1947 - accuracy: 0.9835 - precision: 0.9372 - recall: 0.9915 - auc: 0.9982 - val_loss: 0.0152 - val_tp: 272.0000 - val_fp: 5.0000 - val_tn: 938.0000 - val_fn: 1.0000 - val_accuracy: 0.9951 - val_precision: 0.9819 - val_recall: 0.9963 - val_auc: 0.9998
# Epoch 23/50
# 677/677 [==============================] - 104s 154ms/step - loss: 0.0125 - tp: 1177.8879 - fp: 66.1622 - tn: 4176.6047 - fn: 11.3215 - accuracy: 0.9858 - precision: 0.9475 - recall: 0.9897 - auc: 0.9990 - val_loss: 0.0169 - val_tp: 273.0000 - val_fp: 6.0000 - val_tn: 937.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9951 - val_precision: 0.9785 - val_recall: 1.0000 - val_auc: 0.9998
# Epoch 24/50
# 677/677 [==============================] - 105s 156ms/step - loss: 0.0164 - tp: 1183.3953 - fp: 53.1622 - tn: 4182.9794 - fn: 12.4395 - accuracy: 0.9867 - precision: 0.9537 - recall: 0.9869 - auc: 0.9965 - val_loss: 0.0104 - val_tp: 273.0000 - val_fp: 4.0000 - val_tn: 939.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9967 - val_precision: 0.9856 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 25/50
# 677/677 [==============================] - 103s 153ms/step - loss: 0.0103 - tp: 1179.0737 - fp: 60.6106 - tn: 4181.7743 - fn: 10.5177 - accuracy: 0.9882 - precision: 0.9548 - recall: 0.9927 - auc: 0.9992 - val_loss: 0.0300 - val_tp: 273.0000 - val_fp: 11.0000 - val_tn: 932.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9910 - val_precision: 0.9613 - val_recall: 1.0000 - val_auc: 0.9992
# Epoch 26/50
# 677/677 [==============================] - 105s 155ms/step - loss: 0.0107 - tp: 1170.8407 - fp: 48.8378 - tn: 4204.3687 - fn: 7.9292 - accuracy: 0.9887 - precision: 0.9565 - recall: 0.9928 - auc: 0.9987 - val_loss: 0.0054 - val_tp: 272.0000 - val_fp: 1.0000 - val_tn: 942.0000 - val_fn: 1.0000 - val_accuracy: 0.9984 - val_precision: 0.9963 - val_recall: 0.9963 - val_auc: 1.0000
# Epoch 27/50
# 677/677 [==============================] - 104s 153ms/step - loss: 0.0079 - tp: 1179.5900 - fp: 39.7330 - tn: 4204.1268 - fn: 8.5265 - accuracy: 0.9908 - precision: 0.9656 - recall: 0.9933 - auc: 0.9997 - val_loss: 0.0494 - val_tp: 271.0000 - val_fp: 22.0000 - val_tn: 921.0000 - val_fn: 2.0000 - val_accuracy: 0.9803 - val_precision: 0.9249 - val_recall: 0.9927 - val_auc: 0.9985
# Epoch 28/50
# 677/677 [==============================] - 105s 155ms/step - loss: 0.0078 - tp: 1165.8451 - fp: 31.9322 - tn: 4224.0413 - fn: 10.1578 - accuracy: 0.9920 - precision: 0.9697 - recall: 0.9923 - auc: 0.9995 - val_loss: 0.0033 - val_tp: 273.0000 - val_fp: 1.0000 - val_tn: 942.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9992 - val_precision: 0.9964 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 29/50
# 677/677 [==============================] - 104s 153ms/step - loss: 0.0045 - tp: 1190.4159 - fp: 29.5973 - tn: 4208.2094 - fn: 3.7537 - accuracy: 0.9938 - precision: 0.9756 - recall: 0.9966 - auc: 0.9999 - val_loss: 0.0014 - val_tp: 273.0000 - val_fp: 0.0000e+00 - val_tn: 943.0000 - val_fn: 0.0000e+00 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 30/50
# 677/677 [==============================] - 103s 153ms/step - loss: 0.0060 - tp: 1197.1490 - fp: 18.4602 - tn: 4210.7360 - fn: 5.6313 - accuracy: 0.9954 - precision: 0.9849 - recall: 0.9945 - auc: 0.9992 - val_loss: 0.0017 - val_tp: 273.0000 - val_fp: 1.0000 - val_tn: 942.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.9992 - val_precision: 0.9964 - val_recall: 1.0000 - val_auc: 1.0000

# %%
# !cp  "/content/Pneumothorax/chexnet_model_new.h5" "/content/drive/MyDrive/Self Case Study 2/DATASET/chexnet_model_new.h5"

# %%
acc = history.history['accuracy']
loss = history.history['loss']
auc = history.history['auc']
precision = history.history['precision']
recall = history.history['recall']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
val_auc = history.history['val_auc']
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']

# %%
history = final_new_model.fit(
    dtrain, 
    epochs=5, # training for smaller epochs at a time because kernel is getting disconnected very easily.
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    
    #Giving the class weights here:
    class_weight=class_weight)
# Out:
# Epoch 1/5
# 677/677 [==============================] - 1263s 2s/step - loss: 0.2367 - tp: 380.5206 - fp: 859.6431 - tn: 3379.7847 - fn: 812.0280 - accuracy: 0.7035 - precision: 0.2748 - recall: 0.2494 - auc: 0.5775 - val_loss: 0.6265 - val_tp: 148.0000 - val_fp: 219.0000 - val_tn: 724.0000 - val_fn: 125.0000 - val_accuracy: 0.7171 - val_precision: 0.4033 - val_recall: 0.5421 - val_auc: 0.7705
# Epoch 2/5
# 677/677 [==============================] - 235s 348ms/step - loss: 0.2292 - tp: 785.6239 - fp: 1495.6313 - tn: 2731.5885 - fn: 419.1327 - accuracy: 0.6460 - precision: 0.3437 - recall: 0.6467 - auc: 0.7108 - val_loss: 0.5943 - val_tp: 173.0000 - val_fp: 234.0000 - val_tn: 709.0000 - val_fn: 100.0000 - val_accuracy: 0.7253 - val_precision: 0.4251 - val_recall: 0.6337 - val_auc: 0.7852
# Epoch 3/5
# 677/677 [==============================] - 178s 263ms/step - loss: 0.2206 - tp: 826.7050 - fp: 1494.6239 - tn: 2742.4499 - fn: 368.1976 - accuracy: 0.6597 - precision: 0.3524 - recall: 0.6768 - auc: 0.7383 - val_loss: 0.5703 - val_tp: 182.0000 - val_fp: 243.0000 - val_tn: 700.0000 - val_fn: 91.0000 - val_accuracy: 0.7253 - val_precision: 0.4282 - val_recall: 0.6667 - val_auc: 0.7919
# Epoch 4/5
# 677/677 [==============================] - 174s 257ms/step - loss: 0.2174 - tp: 861.9602 - fp: 1545.6711 - tn: 2692.6534 - fn: 331.6917 - accuracy: 0.6460 - precision: 0.3532 - recall: 0.7287 - auc: 0.7399 - val_loss: 0.5562 - val_tp: 190.0000 - val_fp: 253.0000 - val_tn: 690.0000 - val_fn: 83.0000 - val_accuracy: 0.7237 - val_precision: 0.4289 - val_recall: 0.6960 - val_auc: 0.7981
# Epoch 5/5
# 677/677 [==============================] - 173s 256ms/step - loss: 0.2124 - tp: 881.5059 - fp: 1552.6504 - tn: 2676.8614 - fn: 320.9587 - accuracy: 0.6541 - precision: 0.3579 - recall: 0.7295 - auc: 0.7554 - val_loss: 0.5501 - val_tp: 205.0000 - val_fp: 285.0000 - val_tn: 658.0000 - val_fn: 68.0000 - val_accuracy: 0.7097 - val_precision: 0.4184 - val_recall: 0.7509 - val_auc: 0.8029

# %%
acc = history.history['accuracy']
loss = history.history['loss']
auc = history.history['auc']
precision = history.history['precision']
recall = history.history['recall']

val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
val_auc = history.history['val_auc']
val_precision = history.history['val_precision']
val_recall = history.history['val_recall']

# %%
print("Metric Values after Training first 5 Epochs : \n")
print('Train Accuracy : ', acc)
print('Train Loss : ', loss)
print('Train AUC : ', auc)
print('Train Precision : ', precision)
print('Train Recall : ', recall)
print('Train Val_Accuracy : ', val_acc)
print('Train Val_Loss : ', val_loss)
print('Train Val_Auc : ', val_auc)
print('Train Val_Precision : ', val_precision)
print('Train Val_Recall : ', val_recall)
print("==========================================")
# Out:
# Metric Values after Training first 5 Epochs :
#
# Train Accuracy :  [0.670236349105835, 0.6407865285873413, 0.6487259864807129, 0.6531572937965393, 0.654634416103363]
# Train Loss :  [0.23398947715759277, 0.22710101306438446, 0.22053559124469757, 0.2157195657491684, 0.2124169021844864]
# Train AUC :  [0.6354421973228455, 0.7209659814834595, 0.7459319233894348, 0.7512601613998413, 0.7627031207084656]
# Train Precision :  [0.31549471616744995, 0.34471920132637024, 0.356234610080719, 0.36011478304862976, 0.36686867475509644]
# Train Recall :  [0.424979031085968, 0.6828559637069702, 0.7228464484214783, 0.7345317602157593, 0.749484121799469]
# Train Val_Accuracy :  [0.7171052694320679, 0.7253289222717285, 0.7253289222717285, 0.7236841917037964, 0.7097039222717285]
# Train Val_Loss :  [0.626529335975647, 0.594288170337677, 0.5703458189964294, 0.5562014579772949, 0.5501455068588257]
# Train Val_Auc :  [0.7704893350601196, 0.7852287292480469, 0.7918633222579956, 0.7981055974960327, 0.8029378056526184]
# Train Val_Precision :  [0.40326976776123047, 0.42506143450737, 0.4282352924346924, 0.42889389395713806, 0.4183673560619354]
# Train Val_Recall :  [0.5421245694160461, 0.6336996555328369, 0.6666666865348816, 0.6959707140922546, 0.7509157657623291]
# ==========================================

# %% [markdown]
# Loading the modified weights and training for the next few epochs.

# %%
final_new_model.load_weights("chexnet_model.h5")

# %%
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
history_epoch_5to9 = final_new_model.fit(
    dtrain, 
    epochs=10, # training for smaller epochs at a time because kernel is getting disconnected very easily.
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    class_weight=class_weight)
# Out:
# Epoch 1/10
# 677/677 [==============================] - 227s 303ms/step - loss: 0.2085 - tp: 1077.9572 - fp: 1820.3584 - tn: 3365.7950 - fn: 383.8658 - accuracy: 0.6687 - precision: 0.3718 - recall: 0.7382 - auc: 0.7714 - val_loss: 0.5378 - val_tp: 206.0000 - val_fp: 277.0000 - val_tn: 666.0000 - val_fn: 67.0000 - val_accuracy: 0.7171 - val_precision: 0.4265 - val_recall: 0.7546 - val_auc: 0.8081
# Epoch 2/10
# 677/677 [==============================] - 223s 330ms/step - loss: 0.2057 - tp: 881.1681 - fp: 1490.8746 - tn: 2751.9233 - fn: 308.0103 - accuracy: 0.6625 - precision: 0.3654 - recall: 0.7388 - auc: 0.7671 - val_loss: 0.5175 - val_tp: 200.0000 - val_fp: 240.0000 - val_tn: 703.0000 - val_fn: 73.0000 - val_accuracy: 0.7426 - val_precision: 0.4545 - val_recall: 0.7326 - val_auc: 0.8124
# Epoch 3/10
# 677/677 [==============================] - 223s 330ms/step - loss: 0.2051 - tp: 862.1018 - fp: 1434.6814 - tn: 2797.7257 - fn: 337.4676 - accuracy: 0.6704 - precision: 0.3730 - recall: 0.7116 - auc: 0.7669 - val_loss: 0.5322 - val_tp: 216.0000 - val_fp: 301.0000 - val_tn: 642.0000 - val_fn: 57.0000 - val_accuracy: 0.7056 - val_precision: 0.4178 - val_recall: 0.7912 - val_auc: 0.8158
# Epoch 4/10
# 677/677 [==============================] - 211s 313ms/step - loss: 0.1999 - tp: 868.1726 - fp: 1419.8009 - tn: 2828.8599 - fn: 315.1431 - accuracy: 0.6739 - precision: 0.3750 - recall: 0.7421 - auc: 0.7810 - val_loss: 0.5153 - val_tp: 211.0000 - val_fp: 265.0000 - val_tn: 678.0000 - val_fn: 62.0000 - val_accuracy: 0.7311 - val_precision: 0.4433 - val_recall: 0.7729 - val_auc: 0.8192
# Epoch 5/10
# 677/677 [==============================] - 204s 301ms/step - loss: 0.1987 - tp: 834.4631 - fp: 1377.2035 - tn: 2880.9558 - fn: 339.3540 - accuracy: 0.6786 - precision: 0.3668 - recall: 0.6994 - auc: 0.7697 - val_loss: 0.5023 - val_tp: 207.0000 - val_fp: 248.0000 - val_tn: 695.0000 - val_fn: 66.0000 - val_accuracy: 0.7418 - val_precision: 0.4549 - val_recall: 0.7582 - val_auc: 0.8217
# Epoch 6/10
# 677/677 [==============================] - 203s 299ms/step - loss: 0.2002 - tp: 884.3850 - fp: 1397.2670 - tn: 2815.8982 - fn: 334.4263 - accuracy: 0.6793 - precision: 0.3877 - recall: 0.7224 - auc: 0.7798 - val_loss: 0.4975 - val_tp: 207.0000 - val_fp: 245.0000 - val_tn: 698.0000 - val_fn: 66.0000 - val_accuracy: 0.7442 - val_precision: 0.4580 - val_recall: 0.7582 - val_auc: 0.8245
# Epoch 7/10
# 677/677 [==============================] - 203s 299ms/step - loss: 0.1971 - tp: 871.8820 - fp: 1352.7861 - tn: 2871.2434 - fn: 336.0649 - accuracy: 0.6907 - precision: 0.3944 - recall: 0.7170 - auc: 0.7858 - val_loss: 0.5072 - val_tp: 217.0000 - val_fp: 267.0000 - val_tn: 676.0000 - val_fn: 56.0000 - val_accuracy: 0.7344 - val_precision: 0.4483 - val_recall: 0.7949 - val_auc: 0.8266
# Epoch 8/10
# 677/677 [==============================] - 201s 297ms/step - loss: 0.1944 - tp: 881.2124 - fp: 1344.1342 - tn: 2891.8732 - fn: 314.7566 - accuracy: 0.6953 - precision: 0.3943 - recall: 0.7400 - auc: 0.7891 - val_loss: 0.4957 - val_tp: 212.0000 - val_fp: 250.0000 - val_tn: 693.0000 - val_fn: 61.0000 - val_accuracy: 0.7442 - val_precision: 0.4589 - val_recall: 0.7766 - val_auc: 0.8282
# Epoch 9/10
# 253/677 [==========>...................] - ETA: 1:32 - loss: 0.1965 - tp: 307.5613 - fp: 493.1028 - tn: 1094.9012 - fn: 136.4348 - accuracy: 0.6906 - precision: 0.3859 - recall: 0.6957 - auc: 0.7784

# %%
acc = history_epoch_5to9.history['accuracy']
loss = history_epoch_5to9.history['loss']
auc = history_epoch_5to9.history['auc']
precision = history_epoch_5to9.history['precision']
recall = history_epoch_5to9.history['recall']

val_acc = history_epoch_5to9.history['val_accuracy']
val_loss = history_epoch_5to9.history['val_loss']
val_auc = history_epoch_5to9.history['val_auc']
val_precision = history_epoch_5to9.history['val_precision']
val_recall = history_epoch_5to9.history['val_recall']

# %% [markdown]
# Loading the model again:

# %%
final_new_model.load_weights("chexnet_model.h5")

# %%
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
history_epoch_10to14 = final_new_model.fit(
    dtrain, 
    epochs=5, # training for smaller epochs at a time because kernel is getting disconnected very easily.
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    class_weight=class_weight)
# Out:
# Epoch 1/5
# 677/677 [==============================] - 1739s 3s/step - loss: 0.1708 - tp: 960.7670 - fp: 1158.4425 - tn: 3080.4322 - fn: 232.3348 - accuracy: 0.7477 - precision: 0.4556 - recall: 0.8089 - auc: 0.8422 - val_loss: 0.5226 - val_tp: 224.0000 - val_fp: 295.0000 - val_tn: 648.0000 - val_fn: 49.0000 - val_accuracy: 0.7171 - val_precision: 0.4316 - val_recall: 0.8205 - val_auc: 0.8397
# Epoch 2/5
# 677/677 [==============================] - 1630s 2s/step - loss: 0.1686 - tp: 973.1593 - fp: 1146.4528 - tn: 3097.7920 - fn: 214.5723 - accuracy: 0.7421 - precision: 0.4499 - recall: 0.8233 - auc: 0.8470 - val_loss: 0.5181 - val_tp: 222.0000 - val_fp: 288.0000 - val_tn: 655.0000 - val_fn: 51.0000 - val_accuracy: 0.7212 - val_precision: 0.4353 - val_recall: 0.8132 - val_auc: 0.8480
# Epoch 3/5
# 677/677 [==============================] - 1764s 3s/step - loss: 0.1660 - tp: 965.9100 - fp: 1115.3791 - tn: 3131.8142 - fn: 218.8732 - accuracy: 0.7501 - precision: 0.4582 - recall: 0.8191 - auc: 0.8552 - val_loss: 0.5079 - val_tp: 223.0000 - val_fp: 274.0000 - val_tn: 669.0000 - val_fn: 50.0000 - val_accuracy: 0.7336 - val_precision: 0.4487 - val_recall: 0.8168 - val_auc: 0.8526
# Epoch 4/5
# 677/677 [==============================] - 1709s 3s/step - loss: 0.1616 - tp: 948.1490 - fp: 1032.3761 - tn: 3227.3068 - fn: 224.1445 - accuracy: 0.7649 - precision: 0.4720 - recall: 0.8134 - auc: 0.8622 - val_loss: 0.5036 - val_tp: 224.0000 - val_fp: 272.0000 - val_tn: 671.0000 - val_fn: 49.0000 - val_accuracy: 0.7360 - val_precision: 0.4516 - val_recall: 0.8205 - val_auc: 0.8557
# Epoch 5/5
# 677/677 [==============================] - 1759s 3s/step - loss: 0.1625 - tp: 967.4823 - fp: 1014.8319 - tn: 3219.8555 - fn: 229.8068 - accuracy: 0.7662 - precision: 0.4809 - recall: 0.8066 - auc: 0.8622 - val_loss: 0.4855 - val_tp: 219.0000 - val_fp: 240.0000 - val_tn: 703.0000 - val_fn: 54.0000 - val_accuracy: 0.7582 - val_precision: 0.4771 - val_recall: 0.8022 - val_auc: 0.8581

# %%
acc += history_epoch_10to14.history['accuracy']
loss += history_epoch_10to14.history['loss']
auc += history_epoch_10to14.history['auc']
precision += history_epoch_10to14.history['precision']
recall += history_epoch_10to14.history['recall']

val_acc += history_epoch_10to14.history['val_accuracy']
val_loss += history_epoch_10to14.history['val_loss']
val_auc += history_epoch_10to14.history['val_auc']
val_precision += history_epoch_10to14.history['val_precision']
val_recall += history_epoch_10to14.history['val_recall']

# %% [markdown]
# Loading the model again:

# %%
final_new_model.load_weights("chexnet_model.h5")

# %%
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
history_epoch_19to24 = final_new_model.fit(
    dtrain, 
    epochs=5, # training for longer results in a better model - but timed out on kernels
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    class_weight=class_weight)
# Out:
# Epoch 1/5
# 677/677 [==============================] - 2388s 3s/step - loss: 0.1617 - tp: 963.2596 - fp: 998.9882 - tn: 3239.3496 - fn: 230.3791 - accuracy: 0.7670 - precision: 0.4852 - recall: 0.8071 - auc: 0.8632 - val_loss: 0.5018 - val_tp: 229.0000 - val_fp: 271.0000 - val_tn: 672.0000 - val_fn: 44.0000 - val_accuracy: 0.7410 - val_precision: 0.4580 - val_recall: 0.8388 - val_auc: 0.8598
# Epoch 2/5
# 677/677 [==============================] - 2341s 3s/step - loss: 0.1559 - tp: 963.5516 - fp: 979.7581 - tn: 3269.9602 - fn: 218.7065 - accuracy: 0.7784 - precision: 0.4907 - recall: 0.8206 - auc: 0.8734 - val_loss: 0.4909 - val_tp: 224.0000 - val_fp: 246.0000 - val_tn: 697.0000 - val_fn: 49.0000 - val_accuracy: 0.7574 - val_precision: 0.4766 - val_recall: 0.8205 - val_auc: 0.8615
# Epoch 3/5
# 677/677 [==============================] - 2268s 3s/step - loss: 0.1561 - tp: 961.8746 - fp: 976.4233 - tn: 3275.4794 - fn: 218.1991 - accuracy: 0.7778 - precision: 0.4883 - recall: 0.8239 - auc: 0.8706 - val_loss: 0.4826 - val_tp: 223.0000 - val_fp: 234.0000 - val_tn: 709.0000 - val_fn: 50.0000 - val_accuracy: 0.7664 - val_precision: 0.4880 - val_recall: 0.8168 - val_auc: 0.8624
# Epoch 4/5
# 677/677 [==============================] - 2265s 3s/step - loss: 0.1559 - tp: 968.0280 - fp: 942.0192 - tn: 3298.8584 - fn: 223.0708 - accuracy: 0.7856 - precision: 0.5048 - recall: 0.8163 - auc: 0.8735 - val_loss: 0.4888 - val_tp: 229.0000 - val_fp: 242.0000 - val_tn: 701.0000 - val_fn: 44.0000 - val_accuracy: 0.7648 - val_precision: 0.4862 - val_recall: 0.8388 - val_auc: 0.8635
# Epoch 5/5
# 677/677 [==============================] - 2337s 3s/step - loss: 0.1564 - tp: 956.9926 - fp: 949.2227 - tn: 3308.2153 - fn: 217.5457 - accuracy: 0.7825 - precision: 0.4952 - recall: 0.8188 - auc: 0.8694 - val_loss: 0.4864 - val_tp: 227.0000 - val_fp: 240.0000 - val_tn: 703.0000 - val_fn: 46.0000 - val_accuracy: 0.7648 - val_precision: 0.4861 - val_recall: 0.8315 - val_auc: 0.8643

# %%
acc += history_epoch_19to24.history['accuracy']
loss += history_epoch_19to24.history['loss']
auc += history_epoch_19to24.history['auc']
precision += history_epoch_19to24.history['precision']
recall += history_epoch_19to24.history['recall']

val_acc += history_epoch_19to24.history['val_accuracy']
val_loss += history_epoch_19to24.history['val_loss']
val_auc += history_epoch_19to24.history['val_auc']
val_precision += history_epoch_19to24.history['val_precision']
val_recall += history_epoch_19to24.history['val_recall']

# %% [markdown]
# Loading the model again:

# %%
final_new_model.load_weights("chexnet_model.h5")

# %%
final_new_model.compile(optimizer=optim,loss='binary_crossentropy',metrics=[METRICS])

# %%
history_epoch_25to30 = final_new_model.fit(
    dtrain, 
    epochs=5, # training for longer results in a better model - but timed out on kernels
    verbose=1,
    callbacks=[checkpoint, lr_reducer,early_stop],
    steps_per_epoch=weighted_steps_per_epoch,
    validation_data=dvalid,
    class_weight=class_weight)
# Out:
# Epoch 1/5
# 677/677 [==============================] - 2372s 3s/step - loss: 0.1560 - tp: 1194.6504 - fp: 1199.6740 - tn: 3987.2080 - fn: 266.4440 - accuracy: 0.7772 - precision: 0.4962 - recall: 0.8199 - auc: 0.8700 - val_loss: 0.4721 - val_tp: 220.0000 - val_fp: 224.0000 - val_tn: 719.0000 - val_fn: 53.0000 - val_accuracy: 0.7722 - val_precision: 0.4955 - val_recall: 0.8059 - val_auc: 0.8649
# Epoch 2/5
# 677/677 [==============================] - 2283s 3s/step - loss: 0.1534 - tp: 995.3894 - fp: 928.5206 - tn: 3297.2920 - fn: 210.7743 - accuracy: 0.7915 - precision: 0.5189 - recall: 0.8285 - auc: 0.8786 - val_loss: 0.4665 - val_tp: 217.0000 - val_fp: 219.0000 - val_tn: 724.0000 - val_fn: 56.0000 - val_accuracy: 0.7738 - val_precision: 0.4977 - val_recall: 0.7949 - val_auc: 0.8654
# Epoch 3/5
# 677/677 [==============================] - 2276s 3s/step - loss: 0.1568 - tp: 965.7935 - fp: 929.7537 - tn: 3307.9543 - fn: 228.4749 - accuracy: 0.7839 - precision: 0.5041 - recall: 0.8025 - auc: 0.8685 - val_loss: 0.4705 - val_tp: 220.0000 - val_fp: 224.0000 - val_tn: 719.0000 - val_fn: 53.0000 - val_accuracy: 0.7722 - val_precision: 0.4955 - val_recall: 0.8059 - val_auc: 0.8660
# Epoch 4/5
# 677/677 [==============================] - 2290s 3s/step - loss: 0.1533 - tp: 969.2729 - fp: 927.9248 - tn: 3314.0369 - fn: 220.7419 - accuracy: 0.7887 - precision: 0.5079 - recall: 0.8175 - auc: 0.8755 - val_loss: 0.4880 - val_tp: 228.0000 - val_fp: 251.0000 - val_tn: 692.0000 - val_fn: 45.0000 - val_accuracy: 0.7566 - val_precision: 0.4760 - val_recall: 0.8352 - val_auc: 0.8666
# Epoch 5/5
# 677/677 [==============================] - 2262s 3s/step - loss: 0.1506 - tp: 961.6519 - fp: 929.9867 - tn: 3327.9971 - fn: 212.3407 - accuracy: 0.7874 - precision: 0.5026 - recall: 0.8293 - auc: 0.8799 - val_loss: 0.4729 - val_tp: 222.0000 - val_fp: 227.0000 - val_tn: 716.0000 - val_fn: 51.0000 - val_accuracy: 0.7714 - val_precision: 0.4944 - val_recall: 0.8132 - val_auc: 0.8672

# %%
acc += history_epoch_25to30.history['accuracy']
loss += history_epoch_25to30.history['loss']
auc += history_epoch_25to30.history['auc']
precision += history_epoch_25to30.history['precision']
recall += history_epoch_25to30.history['recall']

val_acc += history_epoch_25to30.history['val_accuracy']
val_loss += history_epoch_25to30.history['val_loss']
val_auc += history_epoch_25to30.history['val_auc']
val_precision += history_epoch_25to30.history['val_precision']
val_recall += history_epoch_25to30.history['val_recall']

# %%
print("Metric Values after Training Next 28 Epochs : \n")
print('Train Accuracy : ', acc)
print('Train Loss : ', loss)
print('Train AUC : ', auc)
print('Train Precision : ', precision)
print('Train Recall : ', recall)
print('Train Val_Accuracy : ', val_acc)
print('Train Val_Loss : ', val_loss)
print('Train Val_Auc : ', val_auc)
print('Train Val_Precision : ', val_precision)
print('Train Val_Recall : ', val_recall)
print("==========================================")
# Out:
# Metric Values after Training Next 28 Epochs :
#
# Train Accuracy :  [0.670236349105835, 0.6407865285873413, 0.6487259864807129, 0.6531572937965393, 0.654634416103363, 0.6687, 0.6625, 0.6704, 0.6739, 0.6786, 0.6793, 0.6907, 0.6953, 0.7477, 0.7421, 0.7501, 0.7649, 0.7662, 0.7742798924446106, 0.7805576324462891, 0.7800959944725037, 0.7859120965003967, 0.7851735353469849, 0.7798804640769958, 0.7884047031402588, 0.7884970307350159, 0.7894202470779419, 0.7894202470779419]
# Train Loss :  [0.23398947715759277, 0.22710101306438446, 0.22053559124469757, 0.2157195657491684, 0.2124169021844864, 0.2085, 0.2057, 0.2051, 0.1999, 0.1987, 0.2002, 0.1971, 0.1944, 0.1708, 0.1686, 0.166, 0.1616, 0.1625, 0.16077667474746704, 0.15837281942367554, 0.15744410455226898, 0.15684916079044342, 0.15705318748950958, 0.1564360409975052, 0.15412388741970062, 0.15498390793800354, 0.15514113008975983, 0.15270574390888214]
# Train AUC :  [0.6354421973228455, 0.7209659814834595, 0.7459319233894348, 0.7512601613998413, 0.7627031207084656, 0.7714, 0.7671, 0.7669, 0.781, 0.7697, 0.7798, 0.7858, 0.7891, 0.8422, 0.847, 0.8552, 0.8622, 0.8622, 0.866681694984436, 0.8711723685264587, 0.8716376423835754, 0.8733247518539429, 0.8709509372711182, 0.8709070086479187, 0.8771941661834717, 0.8744946122169495, 0.8744576573371887, 0.8775568008422852]
# Train Precision :  [0.31549471616744995, 0.34471920132637024, 0.356234610080719, 0.36011478304862976, 0.36686867475509644, 0.3718, 0.3654, 0.373, 0.375, 0.3668, 0.3877, 0.3944, 0.3943, 0.4556, 0.4499, 0.4582, 0.472, 0.4809, 0.4955729842185974, 0.5030769109725952, 0.5014055967330933, 0.5119418501853943, 0.5079406499862671, 0.5010380744934082, 0.5148925185203552, 0.5149136781692505, 0.5171690583229065, 0.5136268138885498]
# Train Recall :  [0.424979031085968, 0.6828559637069702, 0.7228464484214783, 0.7345317602157593, 0.749484121799469, 0.7382, 0.7388, 0.7116, 0.7421, 0.6994, 0.7224, 0.717, 0.74, 0.8089, 0.8233, 0.8191, 0.8134, 0.8066, 0.8128630518913269, 0.8171595335006714, 0.8198913335800171, 0.8179178833961487, 0.8170017004013062, 0.8162344694137573, 0.8259243965148926, 0.8182952404022217, 0.8179933428764343, 0.8218029141426086]
# Train Val_Accuracy :  [0.7171052694320679, 0.7253289222717285, 0.7253289222717285, 0.7236841917037964, 0.7097039222717285, 0.7171, 0.7426, 0.7056, 0.7311, 0.7418, 0.7442, 0.7344, 0.7442, 0.7171, 0.7212, 0.7336, 0.736, 0.7582, 0.7409539222717285, 0.7574012875556946, 0.7664473652839661, 0.7648026347160339, 0.7648026347160339, 0.7722039222717285, 0.7738487124443054, 0.7722039222717285, 0.7565789222717285, 0.7713815569877625]
# Train Val_Loss :  [0.626529335975647, 0.594288170337677, 0.5703458189964294, 0.5562014579772949, 0.5501455068588257, 0.5378, 0.5175, 0.5322, 0.5153, 0.5023, 0.4975, 0.5072, 0.4957, 0.5226, 0.5181, 0.5079, 0.5036, 0.4855, 0.5017846822738647, 0.4909161925315857, 0.4826260209083557, 0.48875463008880615, 0.4864003658294678, 0.4721059203147888, 0.4664538502693176, 0.47046881914138794, 0.487995445728302, 0.4728621542453766]
# Train Val_Auc :  [0.7704893350601196, 0.7852287292480469, 0.7918633222579956, 0.7981055974960327, 0.8029378056526184, 0.8081, 0.8124, 0.8158, 0.8192, 0.8217, 0.8245, 0.8266, 0.8282, 0.8397, 0.848, 0.8526, 0.8557, 0.8581, 0.8598134517669678, 0.8614836931228638, 0.8623538017272949, 0.8634628057479858, 0.8642669320106506, 0.8598134517669678, 0.8614836931228638, 0.8623538017272949, 0.8634628057479858, 0.8642669320106506]
# Train Val_Precision :  [0.40326976776123047, 0.42506143450737, 0.4282352924346924, 0.42889389395713806, 0.4183673560619354, 0.4265, 0.4545, 0.4178, 0.4433, 0.4549, 0.458, 0.4483, 0.4589, 0.4316, 0.4353, 0.4487, 0.4516, 0.4771, 0.4580000042915344, 0.47659575939178467, 0.4879649877548218, 0.48619958758354187, 0.4860813617706299, 0.4954954981803894, 0.49770641326904297, 0.4954954981803894, 0.4759916365146637, 0.4944320619106293]
# Train Val_Recall :  [0.5421245694160461, 0.6336996555328369, 0.6666666865348816, 0.6959707140922546, 0.7509157657623291, 0.7546, 0.7326, 0.7912, 0.7729, 0.7582, 0.7582, 0.7949, 0.7766, 0.8205, 0.8132, 0.8168, 0.8205, 0.8022, 0.8388278484344482, 0.8205128312110901, 0.8168498277664185, 0.8388278484344482, 0.831501841545105, 0.8058608174324036, 0.7948718070983887, 0.8058608174324036, 0.8351648449897766, 0.8131868243217468]
# ==========================================

# %% [markdown]
# ***Evaluating the Final Trained Model :***

# %%
import sklearn
from sklearn import metrics
from sklearn.metrics import confusion_matrix,precision_recall_curve,average_precision_score,accuracy_score

# %%
#Plotting the metrics:

plt.figure(figsize=(15, 15))

#Plotting the Accuracy:
plt.subplot(3, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.xlabel('Epoch')
plt.title('Training and Validation Accuracy')

#Plotting the Loss:
plt.subplot(3, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')

#Plotting the AUC:
plt.subplot(3, 2, 3)#3,2,1
plt.plot(auc, label='Training AUC')
plt.plot(val_auc, label='Validation AUC')
plt.legend(loc='lower right')
plt.ylabel('AUC')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation AUC')
plt.xlabel('Epoch')

#Plotting the Precision:
plt.subplot(3, 2, 4)
plt.plot(precision, label='Training Precision')
plt.plot(val_precision, label='Validation Precision')
plt.legend(loc='upper right')
plt.ylabel('Precision')
plt.ylim([0,1.0])
plt.title('Training and Validation Precision')
plt.xlabel('Epoch')

#Plotting the Recall:
plt.subplot(3, 2, 5)
plt.plot(recall, label='Training Recall')
plt.plot(val_recall, label='Validation Recall')
plt.legend(loc='lower right')
plt.ylabel('Recall')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Recall')
plt.xlabel('Epoch')

#Showing all the graphs:
plt.show()

# %% [markdown]
# Getting the original Train and Valid dataset without the augmentations and class labels:

# %%
test_decoder = build_decoder(with_labels=False, target_size=(256, 256))

train_features = build_dataset(
    trainPath, bsize=BATCH_SIZE, repeat=False, 
    shuffle=False, augment=False, cache=False, 
    decode_fn=test_decoder
)

valid_features = build_dataset(
    validPath, bsize=BATCH_SIZE, repeat=False, 
    shuffle=False, augment=False, cache=False, 
    decode_fn=test_decoder
)

# %%
train_features, valid_features
# Out:
# (<PrefetchDataset shapes: (None, 256, 256, 3), types: tf.float32>,
#  <PrefetchDataset shapes: (None, 256, 256, 3), types: tf.float32>)

# %% [markdown]
# Getting the predict probabilities on Valid Dataset:

# %%
valid_predictions_baseline = final_new_model.predict(valid_features, batch_size=16)

# %%
train_predictions_baseline = final_new_model.predict(train_features, batch_size=16)

# %% [markdown]
# Getting the Metrics on the Valid Dataset:

# %%
valid_baseline_results = final_new_model.evaluate(dvalid,batch_size=16, verbose=0)

# %%
val_precision = round((valid_baseline_results[6]),5)
val_recall = round((valid_baseline_results[7]),5)
val_loss = round((valid_baseline_results[0]),5)
val_auc = round((valid_baseline_results[8]),5)
print('METRIC VALUES FOR VALID DATASET : \n')
print('PRECISION : ', val_precision)
print('RECALL : ', val_recall)
print('LOSS : ', val_loss)
print('AUC : ', val_auc)
# Out:
# METRIC VALUES FOR VALID DATASET :
#
# PRECISION :  0.98556
# RECALL :  1.0
# LOSS :  0.01043
# AUC :  0.99998

# %%
valid_baseline_results
# Out:
# [0.010427027940750122,
#  273.0,
#  4.0,
#  939.0,
#  0.0,
#  0.9967105388641357,
#  0.9855595827102661,
#  1.0,
#  0.9999767541885376]

# %% [markdown]
# ***Plotting the Graphs:***

# %% [markdown]
# Plotting the ROC Curve :

# %%
#https://www.tensorflow.org/tutorials/structured_data/imbalanced_data

def plot_roc(name, labels, predictions):
  fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)
  auc = round(metrics.auc(fp, tp),3)
  
  plt.figure(figsize=(8, 8))
  plt.plot(100*fp, 100*tp, label=name+" = " +str(auc), linewidth=2)
  plt.xlabel('False positives [%]')
  plt.ylabel('True positives [%]')
  plt.grid(True)
  plt.title("ROC Curve")
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
#Plotting the ROC Curve on CV Dataset:
plot_roc("CV Baseline", validLabels, valid_predictions_baseline)
plt.legend(loc='lower right')

# %% [markdown]
# we got a AUC Score of 0.894 on the CV Dataset.

# %% [markdown]
# Plotting the Confusion Matrix:

# %% [markdown]
# We took the threshold at 0.5 and observed these values for the metrics.

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  tn = cm[0][0]
  fn = cm[1][0]
  fp = cm[0][1]
  tp = cm[1][1]

  sensitivity = round((tp/(tp+fn)),3)
  specificity = round((tn/(tn+fp)),3)
  accuracy = round(((tp + tn)/(tp+tn+fp+fn)),3)
  PPV = round((tp/(tp + fp)),3)
  NPV = round((tn/(tn + fn)),3)
  print('Total Records Detected : ', labels.shape[0])
  print('Total Pneumothorax Cases : ', np.sum(cm[1]))
  print("=====================================")
  print('True Negatives : ', tn)
  print('False Positives : ', fp)
  print('False Negatives : ', fn)
  print('True Positives : ', tp)
  print("=====================================")
  print('Accuracy : ', accuracy)
  print('PPV : ', PPV)
  print('NPV : ', NPV)
  print('Sensitivity : ', sensitivity)
  print('Specificity : ', specificity)
  print("=====================================")

  return tn,fn,fp,tp,sensitivity,specificity,accuracy,PPV,NPV

# %%
tn,fn,fp,tp,sensitivity,specificity,accuracy,PPV,NPV = plot_cm(validLabels, valid_predictions_baseline)
# Out:
# Total Records Detected :  1205
# Total Pneumothorax Cases :  267
# =====================================
# True Negatives :  850
# False Positives :  88
# False Negatives :  80
# True Positives :  187
# =====================================
# Accuracy :  0.861
# PPV :  0.68
# NPV :  0.914
# Sensitivity :  0.7
# Specificity :  0.906
# =====================================

# %% [markdown]
# Sensitivity and Specificity are two of the most prominent metrics that are used to measure diagnostics tests.
#
# ***Sensitivity*** (TRUE POSITIVE RATE) is the probability that the model outputs positive given that the case is actually positive. It shows what portion of the positive class got correctly classified.
#
# This is also the Recall.

# %% [markdown]
# ***Specificity*** (TRUE NEGATIVE RATE) is the probability that the model outputs negative given that the case is actually negative. It would mean determining the proportion of healthy people who were correctly identified by the model.

# %% [markdown]
# Positive predictive value (***PPV***) is the probability that people with a positive prediction truly have the disease.
#
# So, PPV of 0.532 means that if a person is predicted to have pneumothorax there is 53.4% probability that he actually have the disease.
#
# This is also the Precision.

# %% [markdown]
# Negative predictive value (***NPV***) is the probability that people with a negative prediction truly don't have the disease.
#
# So, NPV of 0.953 means that if a person is predicted to not have pneumothorax there is 95.3% probability that he doesnt actually have the disease.

# %% [markdown]
# ***Sensitivity*** and ***NPV*** are the most important metric values. Since we are dealing with medical data, we have to ***minimise the False Negative*** as the situation where the patient has the disease (ie true label = positive) but the model predicts him to be safe (ie predicted label = negative) can prove to be disastrous. We also need to ***maximise True Postive***.
#
# So we want majority of the postive class to be correctly predicted. Hence, we need a high Sensitivity (TPR). Also , we need high NPV that shows that if the model predicts the person to be healthy, he is actually healthy.

# %% [markdown]
# Plotting the Precision_Recall Curve :

# %%
def plot_precision_recall_curve(name, labels, predictions):
  
  class_precision, class_recall, _ = precision_recall_curve(labels, predictions)
  average_precision = round((average_precision_score(labels, predictions)),3)

  plt.figure(figsize=(8, 8))
  plt.plot(100*class_recall, 100*class_precision, label=name +" = "+ str(average_precision), linewidth=2)
  plt.xlabel('Recall [%]')
  plt.ylabel('Precision [%]')
  #plt.xlim([-0.5,20])
  #plt.ylim([80,100.5])
  plt.grid(True)
  plt.legend()
  plt.title("Precision-Recalll Curve")
  ax = plt.gca()
  ax.set_aspect('equal')

# %%
plot_precision_recall_curve("CV Baseline", validLabels, valid_predictions_baseline)

# %% [markdown]
# We got an Average Precision Score of 0.69 on CV Dataset.

# %% [markdown]
# The ***Precision-Recall curve*** (PRC) shows the trade-off between precision and recall.
#
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate.
#
# High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %% [markdown]
# Saving all the metric values in a dataframe:

# %%
saved_loss = round((valid_baseline_results[0]),5)

# %%
data = [{'Values' : accuracy}, {'Values' : val_precision}, {'Values' : val_recall}, {'Values' : sensitivity}, 
        {'Values' : specificity}, {'Values' : PPV}, {'Values' : NPV}, {'Values' : saved_loss}]

labels = ['Accuracy', 'Precision', 'Recall','Sensitivity (Recall)', 'Specificity', 'PPV (Precision)', 'NPV', 'LOSS']
classification_metricValues_df = pd.DataFrame(data, index =labels)

# %%
classification_metricValues_df
# Out:
#                        Values
# Accuracy              0.86100
# Precision             0.98556
# Recall                1.00000
# Sensitivity (Recall)  0.70000
# Specificity           0.90600
# PPV (Precision)       0.68000
# NPV                   0.91400
# LOSS                  0.01043

# %%
#Saving the metric df in disk:
classification_metricValues_df.to_csv('/content/drive/MyDrive/Self Case Study 2/DATASET/classification_metricValues_df_new.csv')

# %% [markdown]
# ***Checking the Model on the Test Data given:***

# %% [markdown]
# Building the Test Dataset without Augmentations:

# %%
test_decoder = build_decoder(with_labels=False, target_size=(256, 256))

dtest = build_dataset(
    imagePath_test, bsize=BATCH_SIZE, repeat=False, 
    shuffle=False, augment=False, cache=False, 
    decode_fn=test_decoder
)

# %%
dtest
# Out:
# <PrefetchDataset shapes: (None, 256, 256, 3), types: tf.float32>

# %% [markdown]
# Reading the Test CSV file:

# %%
submission_df = pd.read_csv('/content/drive/MyDrive/Self Case Study 2/DATASET/Test Dataset/stage_2_sample_submission.csv')

# %%
submission_df.head(2)
# Out:
#         ImageId  EncodedPixels
# 0  ID_c68e114ba             -1
# 1  ID_b5a797789             -1

# %%
#Using the Model to predict the Class Label (NOT MASK):

submission_df['Pneumothorax_Classification'] = final_new_model.predict(dtest, verbose=1)
submission_df.to_csv('/content/drive/MyDrive/Self Case Study 2/DATASET/Test Dataset/Pneumothorax_Classification_Submission_new.csv', index=False)
submission_df.head(2)
# Out:
# 201/201 [==============================] - 9s 42ms/step
#         ImageId  EncodedPixels  Pneumothorax_Classification
# 0  ID_c68e114ba             -1                 7.935724e-08
# 1  ID_b5a797789             -1                 2.585854e-04

# %%
submission_df.tail(10)
# Out:
#            ImageId  EncodedPixels  Pneumothorax_Classification
# 3195  ID_0f5f33d71             -1                 9.928751e-01
# 3196  ID_e42b91d9a             -1                 9.709342e-01
# 3197  ID_bd4fa896c             -1                 7.881337e-02
# 3198  ID_293b74bdf             -1                 5.949005e-05
# 3199  ID_74441d7a9             -1                 6.459855e-01
# 3200  ID_a9cc917b4             -1                 4.487242e-05
# 3201  ID_5dc70172e             -1                 2.613478e-06
# 3202  ID_f1b5e5378             -1                 2.429514e-05
# 3203  ID_ba7f28dac             -1                 3.086227e-07
# 3204  ID_77ab447a1             -1                 9.998751e-01

# %% [markdown]
# We have used the classification model to predict the probability of the class label.
#
# We will now create the segmentation model that will predict the mask.

# %% [markdown]
# Segment

# %%
#from keras import backend as K
#from tf.keras.backend as K
from keras import backend as K

# %%
#https://www.kaggle.com/meaninglesslives/nested-unet-with-efficientnet-encoder/notebook

# %%
2) build loss
3) build unet

# %%
if tf.test.is_gpu_available(cuda_only=True):
  print('working on gpu')
else:
  print('warning: working on cpu')
# print(tf.__version__)
# print(keras.__version__)

print("Tensorflow:",tf.__version__)
print("Keras:",keras.__version__)
# Out:
# WARNING:tensorflow:From <ipython-input-25-fdbdf1bb57a1>:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# working on gpu
# Tensorflow: 2.4.1
# Keras: 2.4.3

# %%
final_train_df.head(2)
# Out:
#                                              ImageId  ... Target
# 0  1.2.276.0.7230010.3.1.4.8323329.6904.151787520...  ...      0
# 1  1.2.276.0.7230010.3.1.4.8323329.13666.15178752...  ...      1
#
# [2 rows x 6 columns]

# %%
target = final_train_df['Target']

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Cv = train_test_split(final_train_df, stratify=target, test_size=0.1, random_state=42)

print(X_Train.shape)
print(X_Cv.shape)
# Out:
# (10842, 6)
# (1205, 6)

# %%
X_Train.head(2)
# Out:
#                                                  ImageId  ... Target
# 10907  1.2.276.0.7230010.3.1.4.8323329.10459.15178752...  ...      0
# 10005  1.2.276.0.7230010.3.1.4.8323329.12105.15178752...  ...      0
#
# [2 rows x 6 columns]

# %%
import random

# %%
#https://www.kaggle.com/danofer/ranzcr-chexnet-starter
#https://www.tensorflow.org/tutorials/images/data_augmentation

def read_image(x):
    file_bytes = tf.io.read_file(x)
    img = tf.image.decode_png(file_bytes, channels=3)
    #img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.cast(img, tf.float32) / 255.0
    #img = tf.transpose(img, [2,0,1])
    print(img)
    return img

def read_mask(x):
    file_bytes = tf.io.read_file(x)
    mask = tf.image.decode_png(file_bytes, channels=1)
    #mask = tf.image.convert_image_dtype(mask, tf.float32)
    mask = tf.cast(mask, tf.float32) / 255.0
    #mask = tf.transpose(mask, [2,0,1])
    print(mask)
    return mask

def augmenter(x,y, augment):
    img = read_image(x)
    #img = tf.transpose(img, [2,0,1])
    

    mask = read_mask(y)
    #mask = tf.transpose(mask, [2,0,1])

    if augment == True:
        number = random.randint(1,5)
        seed = (1, 5)
        if number == 1:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_contrast(img,0.2, 0.5,seed)

            mask = tf.image.stateless_random_flip_left_right(mask,seed)
            mask = tf.image.stateless_random_contrast(mask,0.2, 0.5,seed)

        if number == 2:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_brightness(img, 0.2,seed)

            mask = tf.image.stateless_random_flip_left_right(mask,seed)
            mask = tf.image.stateless_random_contrast(mask,0.2, 0.5,seed)

        if number == 3:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.stateless_random_saturation(img, 0.2, 0.5,seed)

            mask = tf.image.stateless_random_flip_left_right(mask,seed)
            mask = tf.image.stateless_random_contrast(mask,0.2, 0.5,seed)

        if number == 4:
            img = tf.image.stateless_random_flip_up_down(img,seed)
            img = tf.image.stateless_random_hue(img, 0.2,seed)

            mask = tf.image.stateless_random_flip_left_right(mask,seed)
            mask = tf.image.stateless_random_contrast(mask,0.2, 0.5,seed)

        if number == 5:
            img = tf.image.stateless_random_flip_left_right(img,seed)
            img = tf.image.adjust_gamma(img, 0.2)

            mask = tf.image.stateless_random_flip_left_right(mask,seed)
            mask = tf.image.stateless_random_contrast(mask,0.2, 0.5,seed)
      

    return img,mask

# %%
#https://www.kaggle.com/danofer/ranzcr-chexnet-starter
#https://www.tensorflow.org/tutorials/images/data_augmentation

def build_dataset(image_paths, mask_paths = None, bsize=32, cache=True,cache_dir="",
                  augment=True, repeat=True, shuffle=1024):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)

    '''if augment_fn is None:
        augment_fn = augmenter(labels is not None)'''
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = image_paths if mask_paths is None else (image_paths, mask_paths)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    #dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(lambda x,y: augmenter(x,y,augment), num_parallel_calls=AUTO)
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    
    return dset

# %%
trainPath, trainLabels = X_Train['ImagePath_Png'], X_Train['MaskPath']
validPath, validLabels = X_Cv['ImagePath_Png'], X_Cv['MaskPath']

# %%
print(f"Images: {len(trainPath)} - Masks: {len(trainLabels)}")
print(f"Images: {len(validPath)} - Masks: {len(validLabels)}")
# Out:
# Images: 10842 - Masks: 10842
# Images: 1205 - Masks: 1205

# %%
trainPath[0]
# Out:
# 'Train Dataset/siim/train_png_images/1.2.276.0.7230010.3.1.4.8323329.6904.1517875201.850819.png'

# %%
dtrain = build_dataset(
    trainPath, trainLabels, bsize=16, cache_dir='Kaggle1/tf_cache'
)

dvalid = build_dataset(
    validPath, validLabels, bsize=16, 
    repeat=False, shuffle=False, augment=False,cache_dir='Kaggle1/tf_cache'
)
# Out:
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)

# %%
dtrain, dvalid
# Out:
# (<PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>,
#  <PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>)

# %%
dtrain, dvalid
# Out:
# (<PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>,
#  <PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>)

# %%
def dice_coef(y_true, y_pred, smooth=1.):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
                K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    
    
def DiceBCELoss(y_true, y_pred):    
       
    #flatten label and prediction tensors
    # inputs = K.flatten(inputs)
    # targets = K.flatten(targets)
    
    BCE =  binary_crossentropy(y_true, y_pred)   
    dice_loss = 1 - dice_coef(y_true, y_pred, smooth=1)
    Dice_BCE = BCE + dice_loss
    
    return Dice_BCE

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras import backend as K

# %%
BATCH_SIZE = 16

# %%
inputs = Input((256, 256, 3))

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (inputs)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(64, (3, 3), activation='relu', padding='same') (c5)
p5 = MaxPooling2D(pool_size=(2, 2)) (c5)

c55 = Conv2D(128, (3, 3), activation='relu', padding='same') (p5)
c55 = Conv2D(128, (3, 3), activation='relu', padding='same') (c55)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c55)
u6 = concatenate([u6, c5])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u71 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u71 = concatenate([u71, c4])
c71 = Conv2D(32, (3, 3), activation='relu', padding='same') (u71)
c61 = Conv2D(32, (3, 3), activation='relu', padding='same') (c71)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c61)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss=DiceBCELoss, metrics=[dice_coef])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 8)  224         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 8)  584         conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 8)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 16) 1168        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 2320        conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   36928       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 128)    73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 128)    147584      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 64)   32832       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 128)  0           conv2d_transpose[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 64)   73792       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 32)   8224        conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 96)   0           conv2d_transpose_1[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 32)   27680       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   4128        conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 2064        conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 256, 256, 8)  520         conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 16) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 8)  1160        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 8)  584         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 1)  9           conv2d_21[0][0]
# ==================================================================================================
# Total params: 600,729
# Trainable params: 600,729
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import datetime

# Define optimizer
optim = tf.keras.optimizers.Adam(0.0001)

filepath= "best_UnetModel.hdf5"

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_dice_coef', 
                             verbose=1, save_best_only=True, mode='max',restore_best_weights=True)

#Callback for the ReduceLROnPlateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_dice_coef", patience=3, min_lr=1e-6, mode='max')


#Callback to stop training if the metric value doesnt change for 6 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_dice_coef', min_delta=0.0001, patience=6, mode='max',restore_best_weights=True)

callback_list = [checkpoint,lr_reducer,early_stop]

weighted_train_steps_per_epoch = 10842//16 
weighted_val_steps_per_epoch = 1205 // 16

# %%
weighted_train_steps_per_epoch, weighted_val_steps_per_epoch
# Out:
# (677, 75)

# %%
len(trainPath) // BATCH_SIZE 
len(validPath) // BATCH_SIZE
# Out:
# 10842

# %%
from tensorflow.keras.losses import binary_crossentropy
model.compile(optimizer=optim, loss=DiceBCELoss, metrics=[dice_coef])
history_epoch1to10 = model.fit(dtrain,
                    validation_data=dvalid,
                    epochs=10, 
                    verbose=1, 
                    callbacks=callback_list,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/10
# 677/677 [==============================] - 76s 81ms/step - loss: 1.3069 - dice_coef: 0.0576 - val_loss: 0.8100 - val_dice_coef: 0.1902
#
# Epoch 00001: val_dice_coef improved from -inf to 0.19015, saving model to best_UnetModel.hdf5
# Epoch 2/10
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8360 - dice_coef: 0.1644 - val_loss: 0.7918 - val_dice_coef: 0.2084
#
# Epoch 00002: val_dice_coef improved from 0.19015 to 0.20843, saving model to best_UnetModel.hdf5
# Epoch 3/10
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8316 - dice_coef: 0.1687 - val_loss: 0.7917 - val_dice_coef: 0.2085
#
# Epoch 00003: val_dice_coef improved from 0.20843 to 0.20851, saving model to best_UnetModel.hdf5
# Epoch 4/10
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8186 - dice_coef: 0.1817 - val_loss: 0.7964 - val_dice_coef: 0.2038
#
# Epoch 00004: val_dice_coef did not improve from 0.20851
# Epoch 5/10
# 677/677 [==============================] - 55s 81ms/step - loss: 0.8169 - dice_coef: 0.1834 - val_loss: 0.7935 - val_dice_coef: 0.2066
#
# Epoch 00005: val_dice_coef did not improve from 0.20851
# Epoch 6/10
# 677/677 [==============================] - 56s 82ms/step - loss: 0.8207 - dice_coef: 0.1795 - val_loss: 0.7917 - val_dice_coef: 0.2084
#
# Epoch 00006: val_dice_coef did not improve from 0.20851
# Epoch 7/10
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8267 - dice_coef: 0.1736 - val_loss: 0.7916 - val_dice_coef: 0.2085
#
# Epoch 00007: val_dice_coef improved from 0.20851 to 0.20852, saving model to best_UnetModel.hdf5
# Epoch 8/10
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8021 - dice_coef: 0.1981 - val_loss: 0.7918 - val_dice_coef: 0.2084
#
# Epoch 00008: val_dice_coef did not improve from 0.20852

# %%
loss = history_epoch1to10.history['loss']
dice_coef = history_epoch1to10.history['dice_coef']
val_loss = history_epoch1to10.history['val_loss']
val_dice_coef = history_epoch1to10.history['val_dice_coef']

# %%
print("Metric Values after Training first 10 Epochs : \n")

print('Train Loss : ', loss)
print('Train Dice_Coef : ', dice_coef)
print('Train Val_Loss : ', val_loss)
print('Train Val_Dice_Coef : ', val_dice_coef)
print("==========================================")
# Out:
# Metric Values after Training first 10 Epochs :
#
# Train Loss :  [1.021809697151184, 0.8382865786552429, 0.8351612687110901, 0.8250738978385925, 0.8291898369789124, 0.8282560706138611, 0.8336790204048157, 0.8281585574150085]
# Train Dice_Coef :  [0.12068336457014084, 0.16216745972633362, 0.16515180468559265, 0.17526064813137054, 0.17109276354312897, 0.17198024690151215, 0.16655264794826508, 0.17206865549087524]
# Train Val_Loss :  [0.8100226521492004, 0.7917596101760864, 0.7916564345359802, 0.7963843941688538, 0.7935426235198975, 0.7917043566703796, 0.7916339635848999, 0.7917922735214233]
# Train Val_Dice_Coef :  [0.19015316665172577, 0.20842860639095306, 0.20850683748722076, 0.2037537395954132, 0.2065993696451187, 0.20844417810440063, 0.20851503312587738, 0.2083553820848465]
# ==========================================

# %%
model.load_weights("best_UnetModel.hdf5")
callback_list1 = [checkpoint]

# %%
model.compile(optimizer=optim, loss=DiceBCELoss, metrics=[dice_coef])
history_epoch11to50 = model.fit(dtrain,
                    validation_data=dvalid,
                    epochs=40, 
                    verbose=1, 
                    callbacks=callback_list1,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/40
# 677/677 [==============================] - 63s 83ms/step - loss: 0.8278 - dice_coef: 0.1724 - val_loss: 0.7918 - val_dice_coef: 0.2084
#
# Epoch 00001: val_dice_coef did not improve from 0.20852
# Epoch 2/40
# 677/677 [==============================] - 56s 83ms/step - loss: 0.8247 - dice_coef: 0.1755 - val_loss: 0.7917 - val_dice_coef: 0.2085
#
# Epoch 00002: val_dice_coef did not improve from 0.20852
# Epoch 3/40
# 677/677 [==============================] - 58s 85ms/step - loss: 0.8339 - dice_coef: 0.1664 - val_loss: 0.7913 - val_dice_coef: 0.2089
#
# Epoch 00003: val_dice_coef improved from 0.20852 to 0.20889, saving model to best_UnetModel.hdf5
# Epoch 4/40
# 677/677 [==============================] - 61s 90ms/step - loss: 0.8088 - dice_coef: 0.1914 - val_loss: 0.7917 - val_dice_coef: 0.2085
#
# Epoch 00004: val_dice_coef did not improve from 0.20889
# Epoch 5/40
# 677/677 [==============================] - 57s 84ms/step - loss: 0.8357 - dice_coef: 0.1645 - val_loss: 0.7916 - val_dice_coef: 0.2086
#
# Epoch 00005: val_dice_coef did not improve from 0.20889
# Epoch 6/40
# 677/677 [==============================] - 57s 85ms/step - loss: 0.8241 - dice_coef: 0.1761 - val_loss: 0.7915 - val_dice_coef: 0.2086
#
# Epoch 00006: val_dice_coef did not improve from 0.20889
# Epoch 7/40
# 677/677 [==============================] - 57s 84ms/step - loss: 0.8259 - dice_coef: 0.1743 - val_loss: 0.7912 - val_dice_coef: 0.2090
#
# Epoch 00007: val_dice_coef improved from 0.20889 to 0.20895, saving model to best_UnetModel.hdf5
# Epoch 8/40
# 677/677 [==============================] - 55s 82ms/step - loss: 0.8191 - dice_coef: 0.1811 - val_loss: 0.7911 - val_dice_coef: 0.2090
#
# Epoch 00008: val_dice_coef improved from 0.20895 to 0.20901, saving model to best_UnetModel.hdf5
# Epoch 9/40
# 677/677 [==============================] - 56s 82ms/step - loss: 0.8286 - dice_coef: 0.1716 - val_loss: 0.7913 - val_dice_coef: 0.2089
#
# Epoch 00009: val_dice_coef did not improve from 0.20901
# Epoch 10/40
# 677/677 [==============================] - 56s 82ms/step - loss: 0.8424 - dice_coef: 0.1579 - val_loss: 0.7914 - val_dice_coef: 0.2088
#
# Epoch 00010: val_dice_coef did not improve from 0.20901
# Epoch 11/40
# 677/677 [==============================] - 57s 84ms/step - loss: 0.8286 - dice_coef: 0.1717 - val_loss: 0.7912 - val_dice_coef: 0.2089
#
# Epoch 00011: val_dice_coef did not improve from 0.20901
# Epoch 12/40
# 677/677 [==============================] - 56s 82ms/step - loss: 0.8282 - dice_coef: 0.1720 - val_loss: 0.7913 - val_dice_coef: 0.2089
#
# Epoch 00012: val_dice_coef did not improve from 0.20901
# Epoch 13/40
# 677/677 [==============================] - 56s 82ms/step - loss: 0.8186 - dice_coef: 0.1816 - val_loss: 0.7912 - val_dice_coef: 0.2090
#
# Epoch 00013: val_dice_coef did not improve from 0.20901
# Epoch 14/40
# 677/677 [==============================] - 55s 81ms/step - loss: 0.8208 - dice_coef: 0.1794 - val_loss: 0.7912 - val_dice_coef: 0.2089
#
# Epoch 00014: val_dice_coef did not improve from 0.20901
# Epoch 15/40
# 677/677 [==============================] - 56s 83ms/step - loss: 0.8285 - dice_coef: 0.1717 - val_loss: 0.7911 - val_dice_coef: 0.2091
#
# Epoch 00015: val_dice_coef improved from 0.20901 to 0.20909, saving model to best_UnetModel.hdf5
# Epoch 16/40
# 677/677 [==============================] - 56s 83ms/step - loss: 0.8365 - dice_coef: 0.1637 - val_loss: 0.7912 - val_dice_coef: 0.2090
#
# Epoch 00016: val_dice_coef did not improve from 0.20909
# Epoch 17/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8173 - dice_coef: 0.1830 - val_loss: 0.7912 - val_dice_coef: 0.2089
#
# Epoch 00017: val_dice_coef did not improve from 0.20909
# Epoch 18/40
# 677/677 [==============================] - 53s 78ms/step - loss: 0.8066 - dice_coef: 0.1936 - val_loss: 0.7912 - val_dice_coef: 0.2089
#
# Epoch 00018: val_dice_coef did not improve from 0.20909
# Epoch 19/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8202 - dice_coef: 0.1800 - val_loss: 0.7910 - val_dice_coef: 0.2092
#
# Epoch 00019: val_dice_coef improved from 0.20909 to 0.20919, saving model to best_UnetModel.hdf5
# Epoch 20/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8122 - dice_coef: 0.1880 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00020: val_dice_coef did not improve from 0.20919
# Epoch 21/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8144 - dice_coef: 0.1858 - val_loss: 0.7912 - val_dice_coef: 0.2089
#
# Epoch 00021: val_dice_coef did not improve from 0.20919
# Epoch 22/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8330 - dice_coef: 0.1672 - val_loss: 0.7911 - val_dice_coef: 0.2091
#
# Epoch 00022: val_dice_coef did not improve from 0.20919
# Epoch 23/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8400 - dice_coef: 0.1602 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00023: val_dice_coef did not improve from 0.20919
# Epoch 24/40
# 677/677 [==============================] - 55s 81ms/step - loss: 0.8280 - dice_coef: 0.1722 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00024: val_dice_coef did not improve from 0.20919
# Epoch 25/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8322 - dice_coef: 0.1680 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00025: val_dice_coef did not improve from 0.20919
# Epoch 26/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8293 - dice_coef: 0.1709 - val_loss: 0.7909 - val_dice_coef: 0.2092
#
# Epoch 00026: val_dice_coef improved from 0.20919 to 0.20923, saving model to best_UnetModel.hdf5
# Epoch 27/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8318 - dice_coef: 0.1684 - val_loss: 0.7910 - val_dice_coef: 0.2092
#
# Epoch 00027: val_dice_coef did not improve from 0.20923
# Epoch 28/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8190 - dice_coef: 0.1812 - val_loss: 0.7910 - val_dice_coef: 0.2092
#
# Epoch 00028: val_dice_coef did not improve from 0.20923
# Epoch 29/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8231 - dice_coef: 0.1771 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00029: val_dice_coef did not improve from 0.20923
# Epoch 30/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8221 - dice_coef: 0.1781 - val_loss: 0.7911 - val_dice_coef: 0.2091
#
# Epoch 00030: val_dice_coef did not improve from 0.20923
# Epoch 31/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8148 - dice_coef: 0.1854 - val_loss: 0.7912 - val_dice_coef: 0.2090
#
# Epoch 00031: val_dice_coef did not improve from 0.20923
# Epoch 32/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8315 - dice_coef: 0.1687 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00032: val_dice_coef did not improve from 0.20923
# Epoch 33/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8278 - dice_coef: 0.1724 - val_loss: 0.7910 - val_dice_coef: 0.2092
#
# Epoch 00033: val_dice_coef did not improve from 0.20923
# Epoch 34/40
# 677/677 [==============================] - 54s 79ms/step - loss: 0.8098 - dice_coef: 0.1904 - val_loss: 0.7909 - val_dice_coef: 0.2093
#
# Epoch 00034: val_dice_coef improved from 0.20923 to 0.20928, saving model to best_UnetModel.hdf5
# Epoch 35/40
# 677/677 [==============================] - 53s 78ms/step - loss: 0.8303 - dice_coef: 0.1699 - val_loss: 0.7909 - val_dice_coef: 0.2092
#
# Epoch 00035: val_dice_coef did not improve from 0.20928
# Epoch 36/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8109 - dice_coef: 0.1893 - val_loss: 0.7910 - val_dice_coef: 0.2092
#
# Epoch 00036: val_dice_coef did not improve from 0.20928
# Epoch 37/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8240 - dice_coef: 0.1762 - val_loss: 0.7909 - val_dice_coef: 0.2093
#
# Epoch 00037: val_dice_coef did not improve from 0.20928
# Epoch 38/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8164 - dice_coef: 0.1838 - val_loss: 0.7910 - val_dice_coef: 0.2091
#
# Epoch 00038: val_dice_coef did not improve from 0.20928
# Epoch 39/40
# 677/677 [==============================] - 54s 80ms/step - loss: 0.8155 - dice_coef: 0.1847 - val_loss: 0.7909 - val_dice_coef: 0.2092
#
# Epoch 00039: val_dice_coef did not improve from 0.20928
# Epoch 40/40
# 677/677 [==============================] - 53s 79ms/step - loss: 0.8253 - dice_coef: 0.1749 - val_loss: 0.7909 - val_dice_coef: 0.2093
#
# Epoch 00040: val_dice_coef did not improve from 0.20928

# %%
loss = history_epoch11to50.history['loss']
dice_coef = history_epoch11to50.history['dice_coef']
val_loss = history_epoch11to50.history['val_loss']
val_dice_coef = history_epoch11to50.history['val_dice_coef']

# %%
#Plotting the metrics:

plt.figure(figsize=(20, 5))

#Plotting the Accuracy:
plt.subplot(1, 2, 1)
plt.plot(dice_coef, label='Training Dice_Coef')
plt.plot(val_dice_coef, label='Validation Dice_Coef')
plt.legend(loc='lower right')
plt.ylabel('Dice_Coef')
#plt.ylim([min(plt.ylim()),1])
plt.xlabel('Epoch')
plt.title('Training and Validation Dice Coef')

#Plotting the Loss:
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('LOSS')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
# !cp  "/content/Pneumothorax/best_UnetModel.hdf5" "/content/drive/MyDrive/Self Case Study 2/DATASET/best_UnetModel.hdf5"

# %%
# !cp "/content/drive/MyDrive/Self Case Study 2/DATASET/Train Dataset/siim/final_train_data.csv" "/content/Pneumothorax/Train_Dataset/siim/"

# %%
#!rm -rf /content/Pneumothorax/Train_Dataset/siim/test_dicom_images/test_dicom_images

# %%
smooth = 1.
dropout_rate = 0.5

# %%
from tensorflow.keras.regularizers import l2
def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'relu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

def Nest_Net(img_rows, img_cols, color_type=3, num_class=1, deep_supervision=False):

    nb_filter = [32,64,128,256,512]
    act = 'relu'

    bn_axis = 3
    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')

    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPool2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPool2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    up1_2 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up12', padding='same')(conv2_1)
    conv1_2 = concatenate([up1_2, conv1_1], name='merge12', axis=bn_axis)
    conv1_2 = standard_unit(conv1_2, stage='12', nb_filter=nb_filter[0])

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPool2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    up2_2 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up22', padding='same')(conv3_1)
    conv2_2 = concatenate([up2_2, conv2_1], name='merge22', axis=bn_axis)
    conv2_2 = standard_unit(conv2_2, stage='22', nb_filter=nb_filter[1])

    up1_3 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up13', padding='same')(conv2_2)
    conv1_3 = concatenate([up1_3, conv1_1, conv1_2], name='merge13', axis=bn_axis)
    conv1_3 = standard_unit(conv1_3, stage='13', nb_filter=nb_filter[0])

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPool2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    up3_2 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up32', padding='same')(conv4_1)
    conv3_2 = concatenate([up3_2, conv3_1], name='merge32', axis=bn_axis)
    conv3_2 = standard_unit(conv3_2, stage='32', nb_filter=nb_filter[2])

    up2_3 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up23', padding='same')(conv3_2)
    conv2_3 = concatenate([up2_3, conv2_1, conv2_2], name='merge23', axis=bn_axis)
    conv2_3 = standard_unit(conv2_3, stage='23', nb_filter=nb_filter[1])

    up1_4 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up14', padding='same')(conv2_3)
    conv1_4 = concatenate([up1_4, conv1_1, conv1_2, conv1_3], name='merge14', axis=bn_axis)
    conv1_4 = standard_unit(conv1_4, stage='14', nb_filter=nb_filter[0])

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1, conv3_2], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1, conv2_2, conv2_3], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1, conv1_2, conv1_3, conv1_4], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    nestnet_output_1 = Conv2D(num_class, (1, 1), activation='sigmoid', name='output_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_2)
    nestnet_output_2 = Conv2D(num_class, (1, 1), activation='sigmoid', name='output_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_3)
    nestnet_output_3 = Conv2D(num_class, (1, 1), activation='sigmoid', name='output_3', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_4)
    nestnet_output_4 = Conv2D(num_class, (1, 1), activation='sigmoid', name='output_4', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    if deep_supervision:
        model = Model(img_input, [nestnet_output_1,nestnet_output_2,nestnet_output_3,nestnet_output_4])
    else:
        model = Model(img_input, [nestnet_output_4])
    
    return model

# %%
import datetime
from tensorflow.keras.optimizers import Adam
# Define optimizer
adam = Adam(lr = 0.05, epsilon = 0.1)

filepath= "best_nestedUnetModel_new.hdf5"

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_dice_coef', 
                             verbose=1, save_best_only=True, mode='max',restore_best_weights=True)

#Callback for the ReduceLROnPlateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_dice_coef", patience=3, min_lr=1e-6, mode='max')


#Callback to stop training if the metric value doesnt change for 6 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_dice_coef', min_delta=0.0001, patience=6, mode='max',restore_best_weights=True)

callback_list_new = [checkpoint,lr_reducer,early_stop]
callback_list1 = [checkpoint,lr_reducer]
callback_list_new1 = [checkpoint]
weighted_train_steps_per_epoch = 10842//16 
weighted_val_steps_per_epoch = 1205 // 16

# %%
def dice_coef(y_true, y_pred, smooth=1.):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (
                K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    
    
def DiceBCELoss(y_true, y_pred):    
       
    #flatten label and prediction tensors
    # inputs = K.flatten(inputs)
    # targets = K.flatten(targets)
    
    BCE =  binary_crossentropy(y_true, y_pred)   
    dice_loss = 1 - dice_coef(y_true, y_pred, smooth=1)
    Dice_BCE = BCE + dice_loss
    
    return Dice_BCE

# %%
from tensorflow import reduce_sum
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, Conv2DTranspose, MaxPool2D, Dropout, concatenate, Flatten
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import train_test_split

# %%
# get an instance of the model
nested_unet_model = Nest_Net(256, 256, color_type=3, num_class=1, deep_supervision=False)
nested_unet_model.compile(optimizer=adam, loss=DiceBCELoss, metrics=[dice_coef])

# %%
nested_unet_model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv11_1 (Conv2D)               (None, 256, 256, 32) 896         main_input[0][0]
# __________________________________________________________________________________________________
# dp11_1 (Dropout)                (None, 256, 256, 32) 0           conv11_1[0][0]
# __________________________________________________________________________________________________
# conv11_2 (Conv2D)               (None, 256, 256, 32) 9248        dp11_1[0][0]
# __________________________________________________________________________________________________
# dp11_2 (Dropout)                (None, 256, 256, 32) 0           conv11_2[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 128, 128, 32) 0           dp11_2[0][0]
# __________________________________________________________________________________________________
# conv21_1 (Conv2D)               (None, 128, 128, 64) 18496       pool1[0][0]
# __________________________________________________________________________________________________
# dp21_1 (Dropout)                (None, 128, 128, 64) 0           conv21_1[0][0]
# __________________________________________________________________________________________________
# conv21_2 (Conv2D)               (None, 128, 128, 64) 36928       dp21_1[0][0]
# __________________________________________________________________________________________________
# dp21_2 (Dropout)                (None, 128, 128, 64) 0           conv21_2[0][0]
# __________________________________________________________________________________________________
# pool2 (MaxPooling2D)            (None, 64, 64, 64)   0           dp21_2[0][0]
# __________________________________________________________________________________________________
# conv31_1 (Conv2D)               (None, 64, 64, 128)  73856       pool2[0][0]
# __________________________________________________________________________________________________
# dp31_1 (Dropout)                (None, 64, 64, 128)  0           conv31_1[0][0]
# __________________________________________________________________________________________________
# conv31_2 (Conv2D)               (None, 64, 64, 128)  147584      dp31_1[0][0]
# __________________________________________________________________________________________________
# dp31_2 (Dropout)                (None, 64, 64, 128)  0           conv31_2[0][0]
# __________________________________________________________________________________________________
# pool3 (MaxPooling2D)            (None, 32, 32, 128)  0           dp31_2[0][0]
# __________________________________________________________________________________________________
# conv41_1 (Conv2D)               (None, 32, 32, 256)  295168      pool3[0][0]
# __________________________________________________________________________________________________
# dp41_1 (Dropout)                (None, 32, 32, 256)  0           conv41_1[0][0]
# __________________________________________________________________________________________________
# conv41_2 (Conv2D)               (None, 32, 32, 256)  590080      dp41_1[0][0]
# __________________________________________________________________________________________________
# dp41_2 (Dropout)                (None, 32, 32, 256)  0           conv41_2[0][0]
# __________________________________________________________________________________________________
# pool4 (MaxPooling2D)            (None, 16, 16, 256)  0           dp41_2[0][0]
# __________________________________________________________________________________________________
# conv51_1 (Conv2D)               (None, 16, 16, 512)  1180160     pool4[0][0]
# __________________________________________________________________________________________________
# dp51_1 (Dropout)                (None, 16, 16, 512)  0           conv51_1[0][0]
# __________________________________________________________________________________________________
# conv51_2 (Conv2D)               (None, 16, 16, 512)  2359808     dp51_1[0][0]
# __________________________________________________________________________________________________
# dp51_2 (Dropout)                (None, 16, 16, 512)  0           conv51_2[0][0]
# __________________________________________________________________________________________________
# up42 (Conv2DTranspose)          (None, 32, 32, 256)  524544      dp51_2[0][0]
# __________________________________________________________________________________________________
# merge42 (Concatenate)           (None, 32, 32, 512)  0           up42[0][0]
#                                                                  dp41_2[0][0]
# __________________________________________________________________________________________________
# up32 (Conv2DTranspose)          (None, 64, 64, 128)  131200      dp41_2[0][0]
# __________________________________________________________________________________________________
# conv42_1 (Conv2D)               (None, 32, 32, 256)  1179904     merge42[0][0]
# __________________________________________________________________________________________________
# merge32 (Concatenate)           (None, 64, 64, 256)  0           up32[0][0]
#                                                                  dp31_2[0][0]
# __________________________________________________________________________________________________
# up22 (Conv2DTranspose)          (None, 128, 128, 64) 32832       dp31_2[0][0]
# __________________________________________________________________________________________________
# dp42_1 (Dropout)                (None, 32, 32, 256)  0           conv42_1[0][0]
# __________________________________________________________________________________________________
# conv32_1 (Conv2D)               (None, 64, 64, 128)  295040      merge32[0][0]
# __________________________________________________________________________________________________
# merge22 (Concatenate)           (None, 128, 128, 128 0           up22[0][0]
#                                                                  dp21_2[0][0]
# __________________________________________________________________________________________________
# up12 (Conv2DTranspose)          (None, 256, 256, 32) 8224        dp21_2[0][0]
# __________________________________________________________________________________________________
# conv42_2 (Conv2D)               (None, 32, 32, 256)  590080      dp42_1[0][0]
# __________________________________________________________________________________________________
# dp32_1 (Dropout)                (None, 64, 64, 128)  0           conv32_1[0][0]
# __________________________________________________________________________________________________
# conv22_1 (Conv2D)               (None, 128, 128, 64) 73792       merge22[0][0]
# __________________________________________________________________________________________________
# merge12 (Concatenate)           (None, 256, 256, 64) 0           up12[0][0]
#                                                                  dp11_2[0][0]
# __________________________________________________________________________________________________
# dp42_2 (Dropout)                (None, 32, 32, 256)  0           conv42_2[0][0]
# __________________________________________________________________________________________________
# conv32_2 (Conv2D)               (None, 64, 64, 128)  147584      dp32_1[0][0]
# __________________________________________________________________________________________________
# dp22_1 (Dropout)                (None, 128, 128, 64) 0           conv22_1[0][0]
# __________________________________________________________________________________________________
# conv12_1 (Conv2D)               (None, 256, 256, 32) 18464       merge12[0][0]
# __________________________________________________________________________________________________
# up33 (Conv2DTranspose)          (None, 64, 64, 128)  131200      dp42_2[0][0]
# __________________________________________________________________________________________________
# dp32_2 (Dropout)                (None, 64, 64, 128)  0           conv32_2[0][0]
# __________________________________________________________________________________________________
# conv22_2 (Conv2D)               (None, 128, 128, 64) 36928       dp22_1[0][0]
# __________________________________________________________________________________________________
# dp12_1 (Dropout)                (None, 256, 256, 32) 0           conv12_1[0][0]
# __________________________________________________________________________________________________
# merge33 (Concatenate)           (None, 64, 64, 384)  0           up33[0][0]
#                                                                  dp31_2[0][0]
#                                                                  dp32_2[0][0]
# __________________________________________________________________________________________________
# dp22_2 (Dropout)                (None, 128, 128, 64) 0           conv22_2[0][0]
# __________________________________________________________________________________________________
# up23 (Conv2DTranspose)          (None, 128, 128, 64) 32832       dp32_2[0][0]
# __________________________________________________________________________________________________
# conv12_2 (Conv2D)               (None, 256, 256, 32) 9248        dp12_1[0][0]
# __________________________________________________________________________________________________
# conv33_1 (Conv2D)               (None, 64, 64, 128)  442496      merge33[0][0]
# __________________________________________________________________________________________________
# merge23 (Concatenate)           (None, 128, 128, 192 0           up23[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
# __________________________________________________________________________________________________
# dp12_2 (Dropout)                (None, 256, 256, 32) 0           conv12_2[0][0]
# __________________________________________________________________________________________________
# up13 (Conv2DTranspose)          (None, 256, 256, 32) 8224        dp22_2[0][0]
# __________________________________________________________________________________________________
# dp33_1 (Dropout)                (None, 64, 64, 128)  0           conv33_1[0][0]
# __________________________________________________________________________________________________
# conv23_1 (Conv2D)               (None, 128, 128, 64) 110656      merge23[0][0]
# __________________________________________________________________________________________________
# merge13 (Concatenate)           (None, 256, 256, 96) 0           up13[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
# __________________________________________________________________________________________________
# conv33_2 (Conv2D)               (None, 64, 64, 128)  147584      dp33_1[0][0]
# __________________________________________________________________________________________________
# dp23_1 (Dropout)                (None, 128, 128, 64) 0           conv23_1[0][0]
# __________________________________________________________________________________________________
# conv13_1 (Conv2D)               (None, 256, 256, 32) 27680       merge13[0][0]
# __________________________________________________________________________________________________
# dp33_2 (Dropout)                (None, 64, 64, 128)  0           conv33_2[0][0]
# __________________________________________________________________________________________________
# conv23_2 (Conv2D)               (None, 128, 128, 64) 36928       dp23_1[0][0]
# __________________________________________________________________________________________________
# dp13_1 (Dropout)                (None, 256, 256, 32) 0           conv13_1[0][0]
# __________________________________________________________________________________________________
# up24 (Conv2DTranspose)          (None, 128, 128, 64) 32832       dp33_2[0][0]
# __________________________________________________________________________________________________
# dp23_2 (Dropout)                (None, 128, 128, 64) 0           conv23_2[0][0]
# __________________________________________________________________________________________________
# conv13_2 (Conv2D)               (None, 256, 256, 32) 9248        dp13_1[0][0]
# __________________________________________________________________________________________________
# merge24 (Concatenate)           (None, 128, 128, 256 0           up24[0][0]
#                                                                  dp21_2[0][0]
#                                                                  dp22_2[0][0]
#                                                                  dp23_2[0][0]
# __________________________________________________________________________________________________
# dp13_2 (Dropout)                (None, 256, 256, 32) 0           conv13_2[0][0]
# __________________________________________________________________________________________________
# up14 (Conv2DTranspose)          (None, 256, 256, 32) 8224        dp23_2[0][0]
# __________________________________________________________________________________________________
# conv24_1 (Conv2D)               (None, 128, 128, 64) 147520      merge24[0][0]
# __________________________________________________________________________________________________
# merge14 (Concatenate)           (None, 256, 256, 128 0           up14[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
# __________________________________________________________________________________________________
# dp24_1 (Dropout)                (None, 128, 128, 64) 0           conv24_1[0][0]
# __________________________________________________________________________________________________
# conv14_1 (Conv2D)               (None, 256, 256, 32) 36896       merge14[0][0]
# __________________________________________________________________________________________________
# conv24_2 (Conv2D)               (None, 128, 128, 64) 36928       dp24_1[0][0]
# __________________________________________________________________________________________________
# dp14_1 (Dropout)                (None, 256, 256, 32) 0           conv14_1[0][0]
# __________________________________________________________________________________________________
# dp24_2 (Dropout)                (None, 128, 128, 64) 0           conv24_2[0][0]
# __________________________________________________________________________________________________
# conv14_2 (Conv2D)               (None, 256, 256, 32) 9248        dp14_1[0][0]
# __________________________________________________________________________________________________
# up15 (Conv2DTranspose)          (None, 256, 256, 32) 8224        dp24_2[0][0]
# __________________________________________________________________________________________________
# dp14_2 (Dropout)                (None, 256, 256, 32) 0           conv14_2[0][0]
# __________________________________________________________________________________________________
# merge15 (Concatenate)           (None, 256, 256, 160 0           up15[0][0]
#                                                                  dp11_2[0][0]
#                                                                  dp12_2[0][0]
#                                                                  dp13_2[0][0]
#                                                                  dp14_2[0][0]
# __________________________________________________________________________________________________
# conv15_1 (Conv2D)               (None, 256, 256, 32) 46112       merge15[0][0]
# __________________________________________________________________________________________________
# dp15_1 (Dropout)                (None, 256, 256, 32) 0           conv15_1[0][0]
# __________________________________________________________________________________________________
# conv15_2 (Conv2D)               (None, 256, 256, 32) 9248        dp15_1[0][0]
# __________________________________________________________________________________________________
# dp15_2 (Dropout)                (None, 256, 256, 32) 0           conv15_2[0][0]
# __________________________________________________________________________________________________
# output_4 (Conv2D)               (None, 256, 256, 1)  33          dp15_2[0][0]
# ==================================================================================================
# Total params: 9,042,177
# Trainable params: 9,042,177
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
nested_Unet_history = nested_unet_model.fit(dtrain,
                    validation_data=dvalid,
                    epochs=30, 
                    verbose=1, 
                    callbacks=callback_list_new,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/30
# 677/677 [==============================] - 300s 433ms/step - loss: 1.7348 - dice_coef: 0.1066 - val_loss: 1.4751 - val_dice_coef: 0.2096
#
# Epoch 00001: val_dice_coef improved from -inf to 0.20957, saving model to best_nestedUnetModel_new.hdf5
# Epoch 2/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.4895 - dice_coef: 0.1789 - val_loss: 1.4055 - val_dice_coef: 0.2096
#
# Epoch 00002: val_dice_coef did not improve from 0.20957
# Epoch 3/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.4245 - dice_coef: 0.1732 - val_loss: 1.3351 - val_dice_coef: 0.2096
#
# Epoch 00003: val_dice_coef did not improve from 0.20957
# Epoch 4/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.3642 - dice_coef: 0.1639 - val_loss: 1.2694 - val_dice_coef: 0.2096
#
# Epoch 00004: val_dice_coef did not improve from 0.20957
# Epoch 5/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.2904 - dice_coef: 0.1873 - val_loss: 1.2631 - val_dice_coef: 0.2096
#
# Epoch 00005: val_dice_coef did not improve from 0.20957
# Epoch 6/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.3070 - dice_coef: 0.1644 - val_loss: 1.2569 - val_dice_coef: 0.2096
#
# Epoch 00006: val_dice_coef did not improve from 0.20957
# Epoch 7/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.2888 - dice_coef: 0.1763 - val_loss: 1.2507 - val_dice_coef: 0.2096
#
# Epoch 00007: val_dice_coef did not improve from 0.20957

# %%
# !cp  "/content/Pneumothorax/best_nestedUnetModel_new.hdf5" "/content/drive/MyDrive/Self Case Study 2/DATASET/best_nestedUnetModel_new.hdf5"

# %%
loss = nested_Unet_history.history['loss']
dice_coef = nested_Unet_history.history['dice_coef']
val_loss = nested_Unet_history.history['val_loss']
val_dice_coef = nested_Unet_history.history['val_dice_coef']

# %%
nested_Unet_history1 = nested_unet_model.fit(dtrain,
                    validation_data=dvalid,
                    epochs=30, 
                    verbose=1, 
                    callbacks=callback_list_new1,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/30
# 677/677 [==============================] - 295s 432ms/step - loss: 1.5125 - dice_coef: 0.1725 - val_loss: 1.4741 - val_dice_coef: 0.2096
#
# Epoch 00001: val_dice_coef improved from -inf to 0.20957, saving model to best_nestedUnetModel_new.hdf5
# Epoch 2/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5146 - dice_coef: 0.1694 - val_loss: 1.4731 - val_dice_coef: 0.2096
#
# Epoch 00002: val_dice_coef did not improve from 0.20957
# Epoch 3/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5157 - dice_coef: 0.1674 - val_loss: 1.4722 - val_dice_coef: 0.2096
#
# Epoch 00003: val_dice_coef did not improve from 0.20957
# Epoch 4/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5142 - dice_coef: 0.1679 - val_loss: 1.4712 - val_dice_coef: 0.2096
#
# Epoch 00004: val_dice_coef did not improve from 0.20957
# Epoch 5/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5060 - dice_coef: 0.1751 - val_loss: 1.4703 - val_dice_coef: 0.2096
#
# Epoch 00005: val_dice_coef did not improve from 0.20957
# Epoch 6/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5155 - dice_coef: 0.1647 - val_loss: 1.4694 - val_dice_coef: 0.2096
#
# Epoch 00006: val_dice_coef did not improve from 0.20957
# Epoch 7/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5042 - dice_coef: 0.1750 - val_loss: 1.4685 - val_dice_coef: 0.2096
#
# Epoch 00007: val_dice_coef did not improve from 0.20957
# Epoch 8/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5107 - dice_coef: 0.1676 - val_loss: 1.4676 - val_dice_coef: 0.2096
#
# Epoch 00008: val_dice_coef did not improve from 0.20957
# Epoch 9/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5049 - dice_coef: 0.1725 - val_loss: 1.4666 - val_dice_coef: 0.2096
#
# Epoch 00009: val_dice_coef did not improve from 0.20957
# Epoch 10/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5179 - dice_coef: 0.1586 - val_loss: 1.4657 - val_dice_coef: 0.2096
#
# Epoch 00010: val_dice_coef did not improve from 0.20957
# Epoch 11/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5107 - dice_coef: 0.1649 - val_loss: 1.4648 - val_dice_coef: 0.2096
#
# Epoch 00011: val_dice_coef did not improve from 0.20957
# Epoch 12/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5118 - dice_coef: 0.1628 - val_loss: 1.4639 - val_dice_coef: 0.2096
#
# Epoch 00012: val_dice_coef did not improve from 0.20957
# Epoch 13/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5040 - dice_coef: 0.1697 - val_loss: 1.4630 - val_dice_coef: 0.2096
#
# Epoch 00013: val_dice_coef did not improve from 0.20957
# Epoch 14/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.4958 - dice_coef: 0.1770 - val_loss: 1.4621 - val_dice_coef: 0.2096
#
# Epoch 00014: val_dice_coef did not improve from 0.20957
# Epoch 15/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5059 - dice_coef: 0.1660 - val_loss: 1.4611 - val_dice_coef: 0.2096
#
# Epoch 00015: val_dice_coef did not improve from 0.20957
# Epoch 16/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5051 - dice_coef: 0.1658 - val_loss: 1.4602 - val_dice_coef: 0.2096
#
# Epoch 00016: val_dice_coef did not improve from 0.20957
# Epoch 17/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5113 - dice_coef: 0.1588 - val_loss: 1.4593 - val_dice_coef: 0.2096
#
# Epoch 00017: val_dice_coef did not improve from 0.20957
# Epoch 18/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5007 - dice_coef: 0.1684 - val_loss: 1.4584 - val_dice_coef: 0.2096
#
# Epoch 00018: val_dice_coef did not improve from 0.20957
# Epoch 19/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5012 - dice_coef: 0.1670 - val_loss: 1.4575 - val_dice_coef: 0.2096
#
# Epoch 00019: val_dice_coef did not improve from 0.20957
# Epoch 20/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5067 - dice_coef: 0.1606 - val_loss: 1.4566 - val_dice_coef: 0.2096
#
# Epoch 00020: val_dice_coef did not improve from 0.20957
# Epoch 21/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.5006 - dice_coef: 0.1658 - val_loss: 1.4557 - val_dice_coef: 0.2096
#
# Epoch 00021: val_dice_coef did not improve from 0.20957
# Epoch 22/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.5071 - dice_coef: 0.1584 - val_loss: 1.4548 - val_dice_coef: 0.2096
#
# Epoch 00022: val_dice_coef did not improve from 0.20957
# Epoch 23/30
# 677/677 [==============================] - 292s 432ms/step - loss: 1.4966 - dice_coef: 0.1680 - val_loss: 1.4539 - val_dice_coef: 0.2096
#
# Epoch 00023: val_dice_coef did not improve from 0.20957
# Epoch 24/30
# 677/677 [==============================] - 293s 433ms/step - loss: 1.5025 - dice_coef: 0.1612 - val_loss: 1.4530 - val_dice_coef: 0.2096
#
# Epoch 00024: val_dice_coef did not improve from 0.20957
# Epoch 25/30
# 677/677 [==============================] - 293s 433ms/step - loss: 1.4993 - dice_coef: 0.1634 - val_loss: 1.4521 - val_dice_coef: 0.2096
#
# Epoch 00025: val_dice_coef did not improve from 0.20957
# Epoch 26/30
# 677/677 [==============================] - 293s 433ms/step - loss: 1.4896 - dice_coef: 0.1722 - val_loss: 1.4512 - val_dice_coef: 0.2096
#
# Epoch 00026: val_dice_coef did not improve from 0.20957
# Epoch 27/30
# 677/677 [==============================] - 293s 433ms/step - loss: 1.4951 - dice_coef: 0.1659 - val_loss: 1.4503 - val_dice_coef: 0.2096
#
# Epoch 00027: val_dice_coef did not improve from 0.20957
# Epoch 28/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.4907 - dice_coef: 0.1693 - val_loss: 1.4494 - val_dice_coef: 0.2096
#
# Epoch 00028: val_dice_coef did not improve from 0.20957
# Epoch 29/30
# 677/677 [==============================] - 293s 432ms/step - loss: 1.4887 - dice_coef: 0.1705 - val_loss: 1.4486 - val_dice_coef: 0.2096
#
# Epoch 00029: val_dice_coef did not improve from 0.20957
# Epoch 30/30
# 677/677 [==============================] - 293s 433ms/step - loss: 1.4978 - dice_coef: 0.1606 - val_loss: 1.4477 - val_dice_coef: 0.2096
#
# Epoch 00030: val_dice_coef did not improve from 0.20957

# %%
# !cp  "/content/Pneumothorax/best_nestedUnetModel_new.hdf5" "/content/drive/MyDrive/Self Case Study 2/DATASET/best_nestedUnetModel_new.hdf5"

# %%
loss = nested_Unet_history1.history['loss']
dice_coef = nested_Unet_history1.history['dice_coef']
val_loss = nested_Unet_history1.history['val_loss']
val_dice_coef = nested_Unet_history1.history['val_dice_coef']

# %%
#Plotting the metrics:

plt.figure(figsize=(20, 5))

#Plotting the Dice_Coef:
plt.subplot(1, 2, 1)
plt.plot(dice_coef, label='Training Dice_Coef')
plt.plot(val_dice_coef, label='Validation Dice_Coef')
plt.legend(loc='lower right')
plt.ylabel('Dice_Coef')
#plt.ylim([min(plt.ylim()),1])
plt.xlabel('Epoch')
plt.title('Training and Validation Dice Coef')

#Plotting the Loss:
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('LOSS')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')

# %%
nested_Unet_history = nested_unet_model.fit(dtrain,
                    validation_data=dvalid,
                    epochs=40, 
                    verbose=1, 
                    callbacks=callback_list1,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/40
# 677/677 [==============================] - 315s 447ms/step - loss: 4.7329 - output_1_loss: 1.0707 - output_2_loss: 1.0413 - output_3_loss: 0.9056 - output_4_loss: 0.9897 - output_1_dice_coef: 4.3964e-04 - output_2_dice_coef: 0.0129 - output_3_dice_coef: 0.1247 - output_4_dice_coef: 0.1274 - val_loss: 4.1332 - val_output_1_loss: 0.9922 - val_output_2_loss: 0.7912 - val_output_3_loss: 0.7938 - val_output_4_loss: 0.8580 - val_output_1_dice_coef: 0.0079 - val_output_2_dice_coef: 0.2096 - val_output_3_dice_coef: 0.2096 - val_output_4_dice_coef: 0.2096
# WARNING:tensorflow:Can save best model only with val_dice_coef available, skipping.
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_dice_coef` which is not available. Available metrics are: loss,output_1_loss,output_2_loss,output_3_loss,output_4_loss,output_1_dice_coef,output_2_dice_coef,output_3_dice_coef,output_4_dice_coef,val_loss,val_output_1_loss,val_output_2_loss,val_output_3_loss,val_output_4_loss,val_output_1_dice_coef,val_output_2_dice_coef,val_output_3_dice_coef,val_output_4_dice_coef,lr
# Epoch 2/40
# 123/677 [====>.........................] - ETA: 4:00 - loss: 4.1964 - output_1_loss: 1.0025 - output_2_loss: 0.8375 - output_3_loss: 0.8141 - output_4_loss: 0.8471 - output_1_dice_coef: 4.6367e-04 - output_2_dice_coef: 0.1631 - output_3_dice_coef: 0.1881 - output_4_dice_coef: 0.1930
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-177-84df8cd9491e> in <module>()
#       5                     callbacks=callback_list1,
#       6                     steps_per_epoch=weighted_train_steps_per_epoch,
# ----> 7                     validation_steps=1205 // 16)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1103               logs = tmp_logs  # No error, now safe to assign to logs.
#    1104               end_step = step + data_handler.step_increment
# -> 1105               callbacks.on_train_batch_end(end_step, logs)
#    1106               if self.stop_training:
#    1107                 break
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     452     """
#     453     if self._should_call_train_batch_hooks:
# --> 454       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     455
#     456   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     294       self._call_batch_begin_hook(mode, batch, logs)
#     295     elif hook == 'end':
# --> 296       self._call_batch_end_hook(mode, batch, logs)
#     297     else:
#     298       raise ValueError('Unrecognized hook: {}'.format(hook))
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354       hook = getattr(callback, hook_name)
#     355       if getattr(callback, '_supports_tf_logs', False):
# --> 356         hook(batch, logs)
#     357       else:
#     358         if numpy_logs is None:  # Only convert once.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1018
#    1019   def on_train_batch_end(self, batch, logs=None):
# -> 1020     self._batch_update_progbar(batch, logs)
#    1021
#    1022   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1082     if self.verbose == 1:
#    1083       # Only block async when verbose = 1.
# -> 1084       logs = tf_utils.to_numpy_or_python_type(logs)
#    1085       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1086
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     508   def _to_single_numpy_or_python_type(t):
#     509     if isinstance(t, ops.Tensor):
# --> 510       x = t.numpy()
#     511       return x.item() if np.ndim(x) == 0 else x
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1069     """
#    1070     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1073
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1035   def _numpy(self):
#    1036     try:
# -> 1037       return self._numpy_internal()
#    1038     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
dtrain = build_dataset(
    trainPath, trainLabels, bsize=16, cache_dir='Kaggle2/tf_cache'
)

dvalid = build_dataset(
    validPath, validLabels, bsize=16, 
    repeat=False, shuffle=False, augment=False,cache_dir='Kaggle2/tf_cache'
)
# Out:
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)

# %%
# !cp  -r "/content/Pneumothorax/Kaggle1" "/content/drive/MyDrive/Self Case Study 2/DATASET/Kaggle1"

# %%
1) Deep Supervision = True 
2) Deal with 4 outputs
3) Nested Unet with RestNet50 and weighted loss
4) Predict unet and unet++ (w & w/o weights) for masks and dice_coef
5) Unet++ with weighted loss 
6) find the weights
7) mask2rle for kaggle
8) build the pipeline with clasification and segmentation

# %%
dtrain_noAug = build_dataset(
    trainPath, trainLabels, bsize=16, augment=False, cache_dir='Kaggle2/tf_cache'
)

dvalid_noAug = build_dataset(
    validPath, validLabels, bsize=16, 
    repeat=False, shuffle=False, augment=False,cache_dir='Kaggle2/tf_cache'
)
# Out:
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)
# Tensor("truediv:0", shape=(None, None, 3), dtype=float32)
# Tensor("truediv_1:0", shape=(None, None, 1), dtype=float32)

# %%
dtrain_noAug,dvalid_noAug
# Out:
# (<PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>,
#  <PrefetchDataset shapes: ((None, None, None, 3), (None, None, None, 1)), types: (tf.float32, tf.float32)>)

# %%
def w_bce( y_true, y_pred, weight1=4.  , weight0=1. ) :
    """
    This gives weighted Binary Cross Entropy
    -----------------------------------------
    y_true: Ground truth values
    y_pred: Predicted values
    weight1: value to be penalized for class 1
    weight0: value to be penalized for class 0
    ------------------------------------------
    """
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    y_true = K.clip(y_true, K.epsilon(), 1-K.epsilon())
    y_pred = K.clip(y_pred, K.epsilon(), 1-K.epsilon())
    logloss = -(y_true * K.log(y_pred) * weight1 + (1 - y_true) * K.log(1 - y_pred) * weight0 )
    return K.mean(logloss, axis=-1)


def w_dice_coef(y_true, y_pred, w_0=1., w_1=4.):
    """
    ref: 

    This gives weighted Dice Coefficient
    -------------------------------------
    y_true: Ground truth values
    y_pred: Predicted values
    -------------------------------------
    """
    # mean = 0.21649066
    # w_1 = 1/mean**2
    # w_0 = 1/(1-mean)**2
    y_true_f_1 = K.flatten(y_true)
    y_pred_f_1 = K.flatten(y_pred)
    y_true_f_0 = K.flatten(1-y_true)
    y_pred_f_0 = K.flatten(1-y_pred)

    intersection_0 = K.sum(y_true_f_0 * y_pred_f_0)
    intersection_1 = K.sum(y_true_f_1 * y_pred_f_1)

    return (2 * (w_0 * intersection_0 + w_1 * intersection_1) / 
            ((w_0 * (K.sum(y_true_f_0) + K.sum(y_pred_f_0))) + (w_1 * (K.sum(y_true_f_1) + K.sum(y_pred_f_1)))))
    
smooth = 1.
def w_bce_dice_loss(y_true, y_pred):
    """
    Combined dice and binary cross entropy loss
    """
    return w_bce(y_true, y_pred, weight1=4. , weight0=1.) + (1 - w_dice_coef(y_true, y_pred, w_0=1., w_1=4.))

# %%
import datetime
from tensorflow.keras.optimizers import Adam
# Define optimizer
adam = Adam(lr = 0.05, epsilon = 0.1)

filepath= "best_nestedUnetModel_noAug.hdf5"

checkpoint = ModelCheckpoint(filepath=filepath, monitor='val_w_dice_coef', 
                             verbose=1, save_best_only=True, mode='max',restore_best_weights=True)

#Callback for the ReduceLROnPlateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_w_dice_coef", patience=3, min_lr=1e-6, mode='max')


#Callback to stop training if the metric value doesnt change for 6 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_w_dice_coef', min_delta=0.0001, patience=6, mode='max',restore_best_weights=True)

callback_list_new_noAug = [checkpoint,lr_reducer,early_stop]
callback_list1 = [checkpoint,lr_reducer]
callback_list_new1_noAug = [checkpoint]
weighted_train_steps_per_epoch = 10842//16 
weighted_val_steps_per_epoch = 1205 // 16

# %%
# get an instance of the model
nested_unet_model_noAug = Nest_Net(256, 256, color_type=3, num_class=1, deep_supervision=False)
nested_unet_model_noAug.compile(optimizer=adam, loss=w_bce_dice_loss,  metrics=[w_dice_coef])

# %%
nested_Unet_history_noAug = nested_unet_model_noAug.fit(dtrain,
                    validation_data=dvalid,
                    epochs=30, 
                    verbose=1, 
                    callbacks=callback_list_new_noAug,
                    steps_per_epoch=weighted_train_steps_per_epoch,
                    validation_steps=1205 // 16)
# Out:
# Epoch 1/30
# 677/677 [==============================] - 301s 433ms/step - loss: 0.8126 - w_dice_coef: 0.9911 - val_loss: 0.7182 - val_w_dice_coef: 0.9759
#
# Epoch 00001: val_w_dice_coef improved from -inf to 0.97591, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 2/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.6667 - w_dice_coef: 0.9999 - val_loss: 0.6312 - val_w_dice_coef: 0.9879
#
# Epoch 00002: val_w_dice_coef improved from 0.97591 to 0.98789, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 3/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.5963 - w_dice_coef: 0.9999 - val_loss: 0.5502 - val_w_dice_coef: 0.9953
#
# Epoch 00003: val_w_dice_coef improved from 0.98789 to 0.99533, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 4/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.5269 - w_dice_coef: 0.9999 - val_loss: 0.4804 - val_w_dice_coef: 0.9983
#
# Epoch 00004: val_w_dice_coef improved from 0.99533 to 0.99829, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 5/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.4629 - w_dice_coef: 1.0000 - val_loss: 0.4199 - val_w_dice_coef: 0.9993
#
# Epoch 00005: val_w_dice_coef improved from 0.99829 to 0.99931, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 6/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.4056 - w_dice_coef: 1.0000 - val_loss: 0.3671 - val_w_dice_coef: 0.9997
#
# Epoch 00006: val_w_dice_coef improved from 0.99931 to 0.99968, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 7/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.3548 - w_dice_coef: 1.0000 - val_loss: 0.3208 - val_w_dice_coef: 0.9998
#
# Epoch 00007: val_w_dice_coef improved from 0.99968 to 0.99984, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 8/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.3102 - w_dice_coef: 1.0000 - val_loss: 0.2803 - val_w_dice_coef: 0.9999
#
# Epoch 00008: val_w_dice_coef improved from 0.99984 to 0.99990, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 9/30
# 677/677 [==============================] - 294s 434ms/step - loss: 0.2711 - w_dice_coef: 1.0000 - val_loss: 0.2450 - val_w_dice_coef: 0.9999
#
# Epoch 00009: val_w_dice_coef improved from 0.99990 to 0.99994, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 10/30
# 677/677 [==============================] - 294s 434ms/step - loss: 0.2370 - w_dice_coef: 1.0000 - val_loss: 0.2140 - val_w_dice_coef: 1.0000
#
# Epoch 00010: val_w_dice_coef improved from 0.99994 to 0.99995, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 11/30
# 677/677 [==============================] - 294s 434ms/step - loss: 0.2071 - w_dice_coef: 1.0000 - val_loss: 0.1870 - val_w_dice_coef: 1.0000
#
# Epoch 00011: val_w_dice_coef improved from 0.99995 to 0.99996, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 12/30
# 677/677 [==============================] - 293s 434ms/step - loss: 0.1810 - w_dice_coef: 1.0000 - val_loss: 0.1634 - val_w_dice_coef: 1.0000
#
# Epoch 00012: val_w_dice_coef improved from 0.99996 to 0.99996, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 13/30
# 677/677 [==============================] - 294s 434ms/step - loss: 0.1582 - w_dice_coef: 1.0000 - val_loss: 0.1428 - val_w_dice_coef: 1.0000
#
# Epoch 00013: val_w_dice_coef improved from 0.99996 to 0.99997, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 14/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.1424 - w_dice_coef: 1.0000 - val_loss: 0.1409 - val_w_dice_coef: 1.0000
#
# Epoch 00014: val_w_dice_coef improved from 0.99997 to 0.99997, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 15/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.1405 - w_dice_coef: 1.0000 - val_loss: 0.1391 - val_w_dice_coef: 1.0000
#
# Epoch 00015: val_w_dice_coef improved from 0.99997 to 0.99997, saving model to best_nestedUnetModel_noAug.hdf5
# Epoch 16/30
# 677/677 [==============================] - 293s 433ms/step - loss: 0.1386 - w_dice_coef: 1.0000 - val_loss: 0.1372 - val_w_dice_coef: 1.0000
#
# Epoch 00016: val_w_dice_coef improved from 0.99997 to 0.99997, saving model to best_nestedUnetModel_noAug.hdf5

# %%
# !cp  "/content/Pneumothorax/best_nestedUnetModel_noAug.hdf5" "/content/drive/MyDrive/Self Case Study 2/DATASET/best_nestedUnetModel_noAug.hdf5"

# %%
loss = nested_Unet_history_noAug.history['loss']
w_dice_coef = nested_Unet_history_noAug.history['w_dice_coef']
val_loss = nested_Unet_history_noAug.history['val_loss']
val_w_dice_coef = nested_Unet_history_noAug.history['val_w_dice_coef']

# %%
#Plotting the metrics:

plt.figure(figsize=(20, 5))

#Plotting the Dice_Coef:
plt.subplot(1, 2, 1)
plt.plot(w_dice_coef, label='Training Weighted_Dice_Coef')
plt.plot(val_w_dice_coef, label='Validation Weighted_Dice_Coef')
plt.legend(loc='lower right')
plt.ylabel('Weighted_Dice_Coef')
#plt.ylim([min(plt.ylim()),1])
plt.xlabel('Epoch')
plt.title('Training and Validation Weighted_Dice Coef')

#Plotting the Loss:
plt.subplot(1, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('LOSS')
#plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')
